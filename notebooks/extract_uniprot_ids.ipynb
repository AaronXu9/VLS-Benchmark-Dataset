# %% [markdown]
# # Extract and Convert System IDs to UniProt IDs
#
# This notebook loads the annotation_table_filtered.parquet file and converts system IDs to UniProt IDs.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ## Load the Parquet File

# %%
# Load the annotation table
df = pd.read_parquet('data/annotation_table_filtered.parquet')

print(f"Shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")
print(f"\nFirst few rows:")
df.head()
# Out:
# Shape: (114537, 743)
#
# Columns: ['entry_pdb_id', 'entry_release_date', 'entry_oligomeric_state', 'entry_determination_method', 'entry_keywords', 'entry_pH', 'entry_resolution', 'entry_validation_resolution', 'entry_validation_rfree', 'entry_validation_r', 'entry_validation_clashscore', 'entry_validation_percent_rama_outliers', 'entry_validation_percent_rota_outliers', 'entry_validation_data_completeness', 'entry_validation_percent_RSRZ_outliers', 'entry_validation_atom_count', 'entry_validation_molprobity', 'entry_validation_mean_b_factor', 'entry_validation_median_b_factor', 'entry_validation_pdbx_resolution', 'entry_validation_pdbx_reflns_resolution', 'entry_validation_meanI_over_sigI_obs', 'entry_validation_r_minus_rfree', 'entry_pass_validation_criteria', 'system_biounit_id', 'system_protein_chains_asym_id', 'system_id_no_biounit', 'system_ligand_chains', 'system_num_pocket_residues', 'system_proper_num_pocket_residues', 'system_num_interactions', 'system_proper_num_interactions', 'system_num_unique_interactions', 'system_proper_num_unique_interactions', 'system_num_covalent_ligands', 'system_proper_num_covalent_ligands', 'system_id', 'system_type', 'system_has_kinase_inhibitor', 'system_has_binding_affinity', 'system_num_protein_chains', 'system_proper_num_protein_chains', 'system_num_ligand_chains', 'system_proper_num_ligand_chains', 'system_num_crystal_contacted_residues', 'system_num_atoms_with_crystal_contacts', 'system_num_heavy_atoms', 'system_num_resolved_heavy_atoms', 'system_ligand_max_qed', 'system_ligand_max_molecular_weight', 'system_proper_ligand_max_molecular_weight', 'system_num_unresolved_heavy_atoms', 'system_fraction_atoms_with_crystal_contacts', 'system_pocket_CATH', 'system_pocket_SCOP2B', 'system_pocket_Pfam', 'system_pocket_UniProt', 'system_pocket_ECOD', 'system_pocket_ECOD_t_name', 'system_ligand_validation_num_residues', 'system_ligand_validation_num_processed_residues', 'system_ligand_validation_percent_processed_residues', 'system_ligand_validation_average_rsr', 'system_ligand_validation_average_rsrz', 'system_ligand_validation_average_rscc', 'system_ligand_validation_average_occupancy', 'system_ligand_validation_percent_rsr_under_threshold', 'system_ligand_validation_percent_rscc_over_threshold', 'system_ligand_validation_percent_occupancy_over_threshold', 'system_ligand_validation_average_b_factor', 'system_ligand_validation_unknown_residue_count', 'system_ligand_validation_atom_count', 'system_ligand_validation_heavy_atom_count', 'system_ligand_validation_num_unresolved_heavy_atoms', 'system_ligand_validation_max_alt_count', 'system_ligand_validation_percent_outliers_geometry', 'system_ligand_validation_percent_outliers_density', 'system_ligand_validation_percent_outliers_chirality', 'system_ligand_validation_percent_outliers_clashes', 'system_pocket_validation_num_residues', 'system_pocket_validation_num_processed_residues', 'system_pocket_validation_percent_processed_residues', 'system_pocket_validation_average_rsr', 'system_pocket_validation_average_rsrz', 'system_pocket_validation_average_rscc', 'system_pocket_validation_average_occupancy', 'system_pocket_validation_percent_rsr_under_threshold', 'system_pocket_validation_percent_rscc_over_threshold', 'system_pocket_validation_percent_occupancy_over_threshold', 'system_pocket_validation_average_b_factor', 'system_pocket_validation_unknown_residue_count', 'system_pocket_validation_atom_count', 'system_pocket_validation_heavy_atom_count', 'system_pocket_validation_num_unresolved_heavy_atoms', 'system_pocket_validation_max_alt_count', 'system_pocket_validation_percent_outliers_geometry', 'system_pocket_validation_percent_outliers_density', 'system_pocket_validation_percent_outliers_chirality', 'system_pocket_validation_percent_outliers_clashes', 'system_pass_validation_criteria', 'system_protein_chains_auth_id', 'system_protein_chains_entity_id', 'system_protein_chains_length', 'system_protein_chains_num_unresolved_residues', 'system_protein_chains_validation_num_r ...
#
# First few rows:
#   entry_pdb_id entry_release_date entry_oligomeric_state  \
# 0         8grd         2022-09-01                dimeric
# 1         2grj         2006-04-24              monomeric
# 2         2grj         2006-04-24              monomeric
# 3         2grj         2006-04-24              monomeric
# 4         2grj         2006-04-24              monomeric
#
#   entry_determination_method  entry_keywords entry_pH  entry_resolution  \
# 0          X-RAY DIFFRACTION  OXIDOREDUCTASE      5.1             2.699
# 1          X-RAY DIFFRACTION     TRANSFERASE      5.2             2.600
# 2          X-RAY DIFFRACTION     TRANSFERASE      5.2             2.600
# 3          X-RAY DIFFRACTION     TRANSFERASE      5.2             2.600
# 4          X-RAY DIFFRACTION     TRANSFERASE      5.2             2.600
#
#    entry_validation_resolution  entry_validation_rfree  entry_validation_r  \
# 0                          2.7                  0.2418               0.194
# 1                          2.6                  0.2400               0.190
# 2                          2.6                  0.2400               0.190
# 3                          2.6                  0.2400               0.190
# 4                          2.6                  0.2400               0.190
#
#    ...  system_ligand_has_fragment  system_ligand_has_oligo  \
# 0  ...                       False                    False
# 1  ...                       False                    False
# 2  ...                       False                    False
# 3  ...                       False                    False
# 4  ...                       False                    False
#
#    system_ligand_has_artifact  system_ligand_has_other  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
#
#    system_ligand_has_covalent  system_ligand_has_invalid  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
#
#    system_ligand_has_ion  system_protein_chains_total_length  \
# 0                  False                                 691
# 1                  False                                 192
# 2                  False                                 192
# 3                  False                                 192
# 4                  False                                 192
#
#    system_unique_ccd_codes  system_proper_unique_ccd_codes
# 0                      ADP                             ADP
# 1                      ADP                             ADP
# 2                      ADP                             ADP
# 3                      ADP                             ADP
# 4                      ADP                             ADP
#
# [5 rows x 743 columns]

# %% [markdown]
# ## Extract System IDs

# %%
# Get unique system IDs
system_ids = df['system_id'].unique()

print(f"Total unique system IDs: {len(system_ids)}")
print(f"\nSample system IDs:")
print(system_ids[:10])
# Out:
# Total unique system IDs: 104106
#
# Sample system IDs:
# ['8grd__1__1.A_1.B__1.D' '2grj__1__1.A__1.I' '2grj__2__1.B__1.K'
#  '2grj__3__1.C__1.N' '2grj__4__1.D__1.P' '2grj__5__1.E__1.T'
#  '2grj__6__1.F__1.V' '2grj__7__1.G__1.X' '2grj__8__1.H__1.AA'
#  '4grb__1__1.A__1.C']

# %% [markdown]
# ## Convert System ID to UniProt ID
#
# System IDs in PLINDER typically contain PDB codes. We'll extract the PDB ID and map it to UniProt IDs.

# %% [markdown]
# ## Understanding PLINDER System IDs
#
# PLINDER system IDs have the format: `<PDB ID>__<assembly>__<receptor chain>__<ligand chain>`
#
# Example: `7eek__1__1.A__1.I`
# - PDB ID: `7eek`
# - Assembly: `1`
# - Receptor chain: `1.A` (assembly 1, chain A)
# - Ligand chain: `1.I` (assembly 1, chain I)
#
# **Important**: We need to map the **specific receptor chain** to its UniProt ID, not just the PDB ID!
# A PDB structure can have multiple chains with different proteins.

# %%
def parse_plinder_system_id(system_id):
    """
    Parse PLINDER system ID into components.
    Format: <PDB ID>__<assembly>__<receptor chain>__<ligand chain>
    
    Example: 7eek__1__1.A__1.I
    Returns: {
        'pdb_id': '7eek',
        'assembly': '1',
        'receptor_chain': '1.A',
        'ligand_chain': '1.I',
        'receptor_chain_only': 'A',  # Just the chain letter
        'assembly_id': '1'
    }
    """
    parts = system_id.split('__')
    
    if len(parts) == 4:
        pdb_id, assembly, receptor_chain, ligand_chain = parts
        # Extract just the chain letter (after the dot)
        receptor_chain_only = receptor_chain.split('.')[-1] if '.' in receptor_chain else receptor_chain
        
        return {
            'pdb_id': pdb_id.lower(),
            'assembly': assembly,
            'receptor_chain': receptor_chain,
            'ligand_chain': ligand_chain,
            'receptor_chain_only': receptor_chain_only,
            'assembly_id': assembly
        }
    else:
        # Fallback for non-standard format
        return {
            'pdb_id': system_id.split('__')[0].lower() if '__' in system_id else system_id.lower(),
            'assembly': None,
            'receptor_chain': None,
            'ligand_chain': None,
            'receptor_chain_only': None,
            'assembly_id': None
        }

# Test parsing
sample_system_ids = df['system_id'].head(10).tolist()
print("Parsing PLINDER system IDs:\n")
for sys_id in sample_system_ids[:5]:
    parsed = parse_plinder_system_id(sys_id)
    print(f"{sys_id}")
    print(f"  → PDB: {parsed['pdb_id']}, Receptor Chain: {parsed['receptor_chain_only']}, Ligand Chain: {parsed['ligand_chain']}")
    print()
# Out:
# Parsing PLINDER system IDs:
#
# 8grd__1__1.A_1.B__1.D
#   → PDB: 8grd, Receptor Chain: B, Ligand Chain: 1.D
#
# 2grj__1__1.A__1.I
#   → PDB: 2grj, Receptor Chain: A, Ligand Chain: 1.I
#
# 2grj__2__1.B__1.K
#   → PDB: 2grj, Receptor Chain: B, Ligand Chain: 1.K
#
# 2grj__3__1.C__1.N
#   → PDB: 2grj, Receptor Chain: C, Ligand Chain: 1.N
#
# 2grj__4__1.D__1.P
#   → PDB: 2grj, Receptor Chain: D, Ligand Chain: 1.P

# %%
# Parse all system IDs and extract components
parsed_data = df['system_id'].apply(parse_plinder_system_id)

df['pdb_id'] = parsed_data.apply(lambda x: x['pdb_id'])
df['receptor_chain'] = parsed_data.apply(lambda x: x['receptor_chain_only'])
df['ligand_chain'] = parsed_data.apply(lambda x: x['ligand_chain'])
df['assembly_id'] = parsed_data.apply(lambda x: x['assembly_id'])

print(f"Sample parsed data:")
print(df[['system_id', 'pdb_id', 'receptor_chain', 'ligand_chain']].head(10))
# Out:
# Sample parsed data:
#                system_id pdb_id receptor_chain ligand_chain
# 0  8grd__1__1.A_1.B__1.D   8grd              B          1.D
# 1      2grj__1__1.A__1.I   2grj              A          1.I
# 2      2grj__2__1.B__1.K   2grj              B          1.K
# 3      2grj__3__1.C__1.N   2grj              C          1.N
# 4      2grj__4__1.D__1.P   2grj              D          1.P
# 5      2grj__5__1.E__1.T   2grj              E          1.T
# 6      2grj__6__1.F__1.V   2grj              F          1.V
# 7      2grj__7__1.G__1.X   2grj              G          1.X
# 8     2grj__8__1.H__1.AA   2grj              H         1.AA
# 9      4grb__1__1.A__1.C   4grb              A          1.C

# %%
# Get unique PDB ID + Chain combinations (what we actually need to map)
unique_pdb_chain_combos = df[['pdb_id', 'receptor_chain']].drop_duplicates()
print(f"Total unique PDB ID + Chain combinations: {len(unique_pdb_chain_combos)}")
print(f"Total unique PDB IDs: {df['pdb_id'].nunique()}")
print(f"\nFirst 20 PDB ID + Chain combinations:")
print(unique_pdb_chain_combos.head(20))
# Out:
# Total unique PDB ID + Chain combinations: 67487
# Total unique PDB IDs: 39436
#
# First 20 PDB ID + Chain combinations:
#    pdb_id receptor_chain
# 0    8grd              B
# 1    2grj              A
# 2    2grj              B
# 3    2grj              C
# 4    2grj              D
# 5    2grj              E
# 6    2grj              F
# 7    2grj              G
# 8    2grj              H
# 9    4grb              A
# 10   8grw              B
# 12   6gra              A
# 13   3grr              A
# 14   5grn              A
# 15   1grn              B
# 16   4gra              A
# 17   4gra              B
# 18   6gri              C
# 20   3gr7              A
# 21   3gr7              B

# %% [markdown]
# ## Map PDB ID + Chain to UniProt IDs (Chain-Specific Mapping)
#
# **Key difference**: We need to map specific chains to their UniProt IDs, not just the PDB ID.
#
# The RCSB API provides chain-specific UniProt mappings.

# %%
import requests
import time
from collections import defaultdict

def map_pdb_chain_to_uniprot(pdb_id, chain_id):
    """
    Map PDB ID + specific chain to UniProt accessions using RCSB PDB API.
    
    This is the CORRECT way to map PLINDER systems to ChEMBL!
    
    Parameters:
    -----------
    pdb_id : str
        4-letter PDB code
    chain_id : str
        Chain identifier (e.g., 'A', 'B')
    
    Returns:
    --------
    list : UniProt IDs for this specific chain
    """
    url = f"https://data.rcsb.org/rest/v1/core/polymer_entity/{pdb_id.upper()}/{chain_id.upper()}"
    
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            data = response.json()
            uniprot_ids = []
            
            # Check for UniProt accessions in the polymer entity data
            if 'rcsb_polymer_entity_container_identifiers' in data:
                identifiers = data['rcsb_polymer_entity_container_identifiers']
                if 'uniprot_ids' in identifiers:
                    uniprot_ids = identifiers['uniprot_ids']
            
            return list(set(uniprot_ids))
    except Exception as e:
        pass
    
    # Fallback: try the old endpoint
    try:
        url = f"https://data.rcsb.org/rest/v1/core/uniprot/{pdb_id.upper()}"
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            data = response.json()
            uniprot_ids = []
            
            for entry in data:
                # Filter by chain ID
                if 'rcsb_uniprot_container_identifiers' in entry:
                    chain_ids = entry.get('rcsb_uniprot_container_identifiers', {}).get('auth_asym_id')
                    if chain_ids and chain_id.upper() in [c.upper() for c in chain_ids]:
                        if 'rcsb_uniprot_protein' in entry:
                            uniprot_info = entry['rcsb_uniprot_protein']
                            if 'name' in uniprot_info:
                                uniprot_ids.append(uniprot_info['name']['value'])
            
            return list(set(uniprot_ids))
    except Exception as e:
        pass
    
    return []

def map_pdb_chain_to_uniprot_verbose(pdb_id, chain_id, verbose=False):
    """
    Map PDB ID + chain to UniProt accessions with optional verbose output.
    """
    if verbose:
        print(f"Mapping {pdb_id.upper()} chain {chain_id} → UniProt...")
    
    uniprot_ids = map_pdb_chain_to_uniprot(pdb_id, chain_id)
    
    if uniprot_ids:
        if verbose:
            print(f"  ✓ Found {len(uniprot_ids)} UniProt ID(s): {', '.join(uniprot_ids)}")
        return {
            'pdb_id': pdb_id.upper(),
            'chain_id': chain_id,
            'uniprot_ids': uniprot_ids,
            'method': 'RCSB_chain_specific'
        }
    else:
        if verbose:
            print(f"  ✗ No UniProt mapping found")
        return {
            'pdb_id': pdb_id.upper(),
            'chain_id': chain_id,
            'uniprot_ids': [],
            'method': None
        }

print("Chain-specific mapping functions loaded.")
# Out:
# Chain-specific mapping functions loaded.

# %%
# Test chain-specific mapping on a few examples
test_examples = unique_pdb_chain_combos.head(5)

print("Testing PDB + Chain to UniProt mapping:\n")
for idx, row in test_examples.iterrows():
    pdb_id = row['pdb_id']
    chain_id = row['receptor_chain']
    result = map_pdb_chain_to_uniprot_verbose(pdb_id, chain_id, verbose=True)
    time.sleep(0.3)  # Rate limiting
# Out:
# Testing PDB + Chain to UniProt mapping:
#
# Mapping 8GRD chain B → UniProt...
#   ✗ No UniProt mapping found
#   ✗ No UniProt mapping found
# Mapping 2GRJ chain A → UniProt...
# Mapping 2GRJ chain A → UniProt...
#   ✗ No UniProt mapping found
#   ✗ No UniProt mapping found
# Mapping 2GRJ chain B → UniProt...
# Mapping 2GRJ chain B → UniProt...
#   ✗ No UniProt mapping found
#   ✗ No UniProt mapping found
# Mapping 2GRJ chain C → UniProt...
# Mapping 2GRJ chain C → UniProt...
#   ✗ No UniProt mapping found
#   ✗ No UniProt mapping found
# Mapping 2GRJ chain D → UniProt...
# Mapping 2GRJ chain D → UniProt...
#   ✗ No UniProt mapping found
#   ✗ No UniProt mapping found

# %% [markdown]
# ## Map All PDB + Chain Combinations to UniProt IDs
#
# This creates a **chain-specific** mapping that correctly associates each receptor chain with its UniProt ID.

# %%
# Map all unique PDB + Chain combinations to UniProt
import json

# Try to load existing progress
progress_file = 'data/pdb_chain_to_uniprot_mapping_progress.json'
if Path(progress_file).exists():
    with open(progress_file, 'r') as f:
        pdb_chain_to_uniprot_mapping = json.load(f)
    print(f"Loaded {len(pdb_chain_to_uniprot_mapping)} existing mappings from {progress_file}")
else:
    pdb_chain_to_uniprot_mapping = {}
    print("Starting fresh mapping...")

print(f"Mapping {len(unique_pdb_chain_combos)} PDB + Chain combinations to UniProt...\n")

for i, (idx, row) in enumerate(unique_pdb_chain_combos.iterrows(), 1):
    pdb_id = row['pdb_id']
    chain_id = row['receptor_chain']
    key = f"{pdb_id}_{chain_id}"
    
    # Skip if already mapped
    if key in pdb_chain_to_uniprot_mapping:
        continue
    
    if i % 10 == 0:
        print(f"Progress: {i}/{len(unique_pdb_chain_combos)}")
    
    result = map_pdb_chain_to_uniprot_verbose(pdb_id, chain_id, verbose=False)
    pdb_chain_to_uniprot_mapping[key] = result['uniprot_ids']
    
    # Save progress every 20 entries
    if i % 20 == 0:
        with open(progress_file, 'w') as f:
            json.dump(pdb_chain_to_uniprot_mapping, f, indent=2)
        print(f"  ✓ Progress saved ({len(pdb_chain_to_uniprot_mapping)} mappings)")
    
    time.sleep(0.3)  # Rate limiting

# Final save
with open(progress_file, 'w') as f:
    json.dump(pdb_chain_to_uniprot_mapping, f, indent=2)
print(f"\n✓ Final progress saved to {progress_file}")

print(f"\nMapping complete!")
print(f"Total PDB+Chain combinations mapped: {len(pdb_chain_to_uniprot_mapping)}")
print(f"Combinations with UniProt IDs: {sum(1 for uniprots in pdb_chain_to_uniprot_mapping.values() if uniprots)}")
print(f"Combinations without UniProt IDs: {sum(1 for uniprots in pdb_chain_to_uniprot_mapping.values() if not uniprots)}")
# Out:
# Starting fresh mapping...
# Mapping 67487 PDB + Chain combinations to UniProt...
#
# Progress: 10/67487
# Progress: 10/67487
# Progress: 20/67487
#   ✓ Progress saved (20 mappings)
# Progress: 20/67487
#   ✓ Progress saved (20 mappings)
# Progress: 30/67487
# Progress: 30/67487
# Progress: 40/67487
#   ✓ Progress saved (40 mappings)
# Progress: 40/67487
#   ✓ Progress saved (40 mappings)
# Progress: 50/67487
# Progress: 50/67487
# Progress: 60/67487
#   ✓ Progress saved (60 mappings)
# Progress: 60/67487
#   ✓ Progress saved (60 mappings)
# Progress: 70/67487
# Progress: 70/67487
# Progress: 80/67487
#   ✓ Progress saved (80 mappings)
# Progress: 80/67487
#   ✓ Progress saved (80 mappings)
# Progress: 90/67487
# Progress: 90/67487
# Progress: 100/67487
#   ✓ Progress saved (100 mappings)
# Progress: 100/67487
#   ✓ Progress saved (100 mappings)
# Progress: 110/67487
# Progress: 110/67487
# Progress: 120/67487
#   ✓ Progress saved (120 mappings)
# Progress: 120/67487
#   ✓ Progress saved (120 mappings)
# Progress: 130/67487
# Progress: 130/67487
# Progress: 140/67487
#   ✓ Progress saved (140 mappings)
# Progress: 140/67487
#   ✓ Progress saved (140 mappings)
# Progress: 150/67487
# Progress: 150/67487
# Progress: 160/67487
#   ✓ Progress saved (160 mappings)
# Progress: 160/67487
#   ✓ Progress saved (160 mappings)
# Progress: 170/67487
# Progress: 170/67487
# Progress: 180/67487
#   ✓ Progress saved (180 mappings)
# Progress: 180/67487
#   ✓ Progress saved (180 mappings)
# Progress: 190/67487
# Progress: 190/67487
# Progress: 200/67487
#   ✓ Progress saved (200 mappings)
# Progress: 200/67487
#   ✓ Progress saved (200 mappings)
# Progress: 210/67487
# Progress: 210/67487
# Progress: 220/67487
#   ✓ Progress saved (220 mappings)
# Progress: 220/67487
#   ✓ Progress saved (220 mappings)
# Progress: 230/67487
# Progress: 230/67487
# Progress: 240/67487
#   ✓ Progress saved (240 mappings)
# Progress: 240/67487
#   ✓ Progress saved (240 mappings)
# Progress: 250/67487
# Progress: 250/67487
# Progress: 260/67487
#   ✓ Progress saved (260 mappings)
# Progress: 260/67487
#   ✓ Progress saved (260 mappings)
# Progress: 270/67487
# Progress: 270/67487
# Progress: 280/67487
#   ✓ Progress saved (280 mappings)
# Progress: 280/67487
#   ✓ Progress saved (280 mappings)
# Progress: 290/67487
# Progress: 290/67487
# Progress: 300/67487
#   ✓ Progress saved (300 mappings)
# Progress: 300/67487
#   ✓ Progress saved (300 mappings)
# Progress: 310/67487
# Progress: 310/67487
# Progress: 320/67487
#   ✓ Progress saved (320 mappings)
# Progress: 320/67487
#   ✓ Progress saved (320 mappings)
# Progress: 330/67487
# Progress: 330/67487
# Progress: 340/67487
#   ✓ Progress saved (340 mappings)
# Progress: 340/67487
#   ✓ Progress saved (340 mappings)
# Progress: 350/67487
# Progress: 350/67487
# Progress: 360/67487
#   ✓ Progress saved (360 mappings)
# Progress: 360/67487
#   ✓ Progress saved (360 mappings)
# Progress: 370/67487
# Progress: 370/67487
# Progress: 380/67487
# Progress: 380/67487
#   ✓ Progress saved (380 mappings)
#   ✓ Progress saved (380 mappings)
# Progress: 390/67487
# Progress: 390/67487
# Progress: 400/67487
# Progress: 400/67487
#   ✓ Progress saved (400 mappings)
#   ✓ Progress saved (400 mappings)
# Progress: 410/67487
# Progress: 410/67487
# Progress: 420/67487
# Progress: 420/67487
#   ✓ Progress saved (420 mappings)
#   ✓ Progress saved (420 mappings)
# Progress: 430/67487
# Progress: 430/67487
# Progress: 440/67487
# Progress: 440/67487
#   ✓ Progress saved (440 mappings)
#   ✓ Progress saved (440 mappings)
# Progress: 450/67487
# Progress: 450/67487
# Progress: 460/67487
# Progress: 460/67487
#   ✓ Progress saved (460 mappings)
#   ✓ Progress saved (460 mappings)
# Progress: 470/67487
# Progress: 470/67487
# Progress: 480/67487
# Progress: 480/67487
#   ✓ Progress saved (480 mappings)
#   ✓ Progress saved (480 mappings)
# Progress: 490/67487
# Progress: 490/67487
# Progress: 500/67487
#   ✓ Progress saved (500 mappings)
# Progress: 500/67487
#   ✓ Progress saved (500 mappings)
# Progress: 510/67487
# Progress: 510/67487
# Progress: 520/67487
#   ✓ Progress saved (520 mappings)
# Progress: 520/67487
#   ✓ Progress saved (520 mappings)
# Progress: 530/67487
# Progress: 530/67487
# Progress: 540/67487
#   ✓ Progress saved (540 mappings)
# Progress: 540/67487
#   ✓ Progress saved (540 mappings)
# Progress: 550/67487
# Progress: 550/67487
# Progress: 560/67487
#   ✓ Progress saved (560 mappings)
# Progress: 560/67487
#   ✓ Progress saved (560 mappings)
# Progress: 570/67487
# Progress: 570/67487
# Progress: 580/67487
#   ✓ Progress saved (580 mappings)
# Progress: 580/67487
#   ✓ Progress saved (580 mappings)
# Progress: 590/67487
# Progress: 590/67487
# Progress: 600/67487
#   ✓ Progress saved (600 mappings)
# Progress: 600/67487
#   ✓ Progress saved (600 mappings)
# Progress: 610/67487
# Progress: 610/67487
# Progress: 620/67487
#   ✓ Progress saved (620 mappings)
# Progress: 620/67487
#   ✓ Progress saved (620 mappings)
# Progress: 630/67487
# Progress: 630/67487
# Progress: 640/67487
#   ✓ Progress saved (640 mappings)
# Progress: 640/67487
#   ✓ Progress saved (640 mappings)
# Progress: 650/67487
# Progress: 650/67487
# Progress: 660/67487
#   ✓ Progress saved (660 mappings)
# Progress: 660/67487
#   ✓ Progress saved (660 mappings)
# Progress: 670/67487
# Progress: 670/67487
# Progress: 680/67487
#   ✓ Progress saved (680 mappings)
# Progress: 680/67487
#   ✓ Progress saved (680 mappings)
# Progress: 690/67487
# Progress: 690/67487
# Progress: 700/67487
#   ✓ Progress saved (700 mappings)
# Progress: 700/67487
#   ✓ Progress saved (700 mappings)
# Progress: 710/67487
# Progress: 710/67487
# Progress: 720/67487
#   ✓ Progress saved (720 mappings)
# Progress: 720/67487
#   ✓ Progress saved (720 mappings)
# Progress: 730/67487
# Progress: 730/67487
# Progress: 740/67487
# Progress: 740/67487
#   ✓ Progress saved (740 mappings)
#   ✓ Progress saved (740 mappings)
# Progress: 750/67487
# Progress: 750/67487
# Progress: 760/67487
# Progress: 760/67487
#   ✓ Progress saved (760 mappings)
#   ✓ Progress saved (760 mappings)
# Progress: 770/67487
# Progress: 770/67487
# Progress: 780/67487
# Progress: 780/67487
#   ✓ Progress saved (780 mappings)
#   ✓ Progress saved (780 mappings)
# Progress: 790/67487
# Progress: 790/67487
# Progress: 800/67487
# Progress: 800/67487
#   ✓ Progress saved (800 mappings)
#   ✓ Progress saved (800 mappings)
# Progress: 810/67487
# Progress: 810/67487
# Progress: 820/67487
# Progress: 820/67487
#   ✓ Progress saved (820 mappings)
#   ✓ Progress saved (820 mappings)
# Progress: 830/67487
# Progress: 830/67487
# Progress: 840/67487
#   ✓ Progress saved (840 mappings)
# Progress: 850/67487
# Progress: 860/67487
#   ✓ Progress saved (860 mappings)
# Progress: 870/67487
# Progress: 880/67487
#   ✓ Progress saved (880 mappings)
# Progress: 890/67487
# Progress: 900/67487
#   ✓ Progress saved (900 mappings)
# Progress: 910/67487
# Progress: 920/67487
#   ✓ Progress saved (920 mappings)
# Progress: 930/67487
# Progress: 940/67487
#   ✓ Progress saved (940 mappings)
# Progress: 950/67487
# Progress: 960/67487
#   ✓ Progress saved (960 mappings)
# Progress: 970/67487
# Progress: 980/67487
#   ✓ Progress saved (980 mappings)
# Progress: 990/67487
# Progress: 1000/67487
#   ✓ Progress saved (1000 mappings)
# Progress: 1010/67487
# Progress: 1020/67487
#   ✓ Progress saved (1020 mappings)
# Progress: 1030/67487
# Progress: 1040/67487
#   ✓ Progress saved (1040 mappings)
# Progress: 1050/67487
# Progress: 1060/67487
#   ✓ Progress saved (1060 mappings)
# Progress: 1070/67487
# Progress: 1080/67487
#   ✓ Progress saved (1080 mappings)
# Progress: 1090/67487
# Progress: 1100/67487
#   ✓ Progress saved (1100 mappings)
# Progress: 1110/67487
# Progress: 1120/67487
#   ✓ Progress saved (1120 mappings)
# Progress: 1130/67487
# Progress: 1140/67487
#   ✓ Progress saved (1140 mappings)
# Progress: 1150/67487
# Progress: 1160/67487
#   ✓ Progress saved (1160 mappings)
# Progress: 1170/67487
# Progress: 1180/67487
#   ✓ Progress saved (1180 mappings)
# Progress: 1190/67487
# Progress: 1200/67487
#   ✓ Progress saved (1200 mappings)
# Progress: 1210/67487
# Progress: 1220/67487
#   ✓ Progress saved (1220 mappings)
# Progress: 1230/67487
# Progress: 1240/67487
#   ✓ Progress saved (1240 mappings)
# Progress: 1250/67487
# Progress: 1260/67487
#   ✓ Progress saved (1260 mappings)
# Progress: 1270/67487
# Progress: 1280/67487
#   ✓ Progress saved (1280 mappings)
# Progress: 1290/67487
# Progress: 1300/67487
#   ✓ Progress saved (1300 mappings)
# Progress: 1310/67487
# Progress: 1320/67487
#   ✓ Progress saved (1320 mappings)
# Progress: 1330/67487
# Progress: 1340/67487
#   ✓ Progress saved (1340 mappings)
# Progress: 1350/67487
# Progress: 1360/67487
#   ✓ Progress saved (1360 mappings)
# Progress: 1370/67487
# Progress: 1380/67487
#   ✓ Progress saved (1380 mappings)
# Progress: 1390/67487
# Progress: 1400/67487
#   ✓ Progress saved (1400 mappings)
# Progress: 1410/67487
# Progress: 1420/67487
#   ✓ Progress saved (1420 mappings)
# Progress: 1430/67487
# Progress: 1440/67487
#   ✓ Progress saved (1440 mappings)
# Progress: 1450/67487
# Progress: 1460/67487
#   ✓ Progress saved (1460 mappings)
# Progress: 1470/67487
# Progress: 1480/67487
#   ✓ Progress saved (1480 mappings)
# Progress: 1490/67487
# Progress: 1500/67487
#   ✓ Progress saved (1500 mappings)
# Progress: 1510/67487
# Progress: 1520/67487
#   ✓ Progress saved (1520 mappings)
# Progress: 1530/67487
# Progress: 1540/67487
#   ✓ Progress saved (1540 mappings)
# Progress: 1550/67487
# Progress: 1560/67487
#   ✓ Progress saved (1560 mappings)
# Progress: 1570/67487
# Progress: 1580/67487
#   ✓ Progress saved (1580 mappings)
# Progress: 1590/67487
# Progress: 1600/67487
#   ✓ Progress saved (1600 mappings)
# Progress: 1610/67487
# Progress: 1620/67487
#   ✓ Progress saved (1620 mappings)
# Progress: 1630/67487
# Progress: 1640/67487
#   ✓ Progress saved (1640 mappings)
# Progress: 1650/67487
# Progress: 1660/67487
#   ✓ Progress saved (1660 mappings)
# Progress: 1670/67487
# Progress: 1680/67487
#   ✓ Progress saved (1680 mappings)
# Progress: 1690/67487
# Progress: 1700/67487
#   ✓ Progress saved (1700 mappings)
# Progress: 1710/67487
# Progress: 1720/67487
#   ✓ Progress saved (1720 mappings)
# Progress: 1730/67487
# Progress: 1740/67487
#   ✓ Progress saved (1740 mappings)
# Progress: 1750/67487
# Progress: 1760/67487
#   ✓ Progress saved (1760 mappings)
# Progress: 1770/67487
# Progress: 1780/67487
#   ✓ Progress saved (1780 mappings)
# Progress: 1790/67487
# Progress: 1800/67487
#   ✓ Progress saved (1800 mappings)
# Progress: 1810/67487
# Progress: 1820/67487
#   ✓ Progress saved (1820 mappings)
# Progress: 1830/67487
# Progress: 1840/67487
#   ✓ Progress saved (1840 mappings)
# Progress: 1850/67487
# Progress: 1860/67487
#   ✓ Progress saved (1860 mappings)
# Progress: 1870/67487
# Progress: 1880/67487
#   ✓ Progress saved (1880 mappings)
# Progress: 1890/67487
# Progress: 1900/67487
#   ✓ Progress saved (1900 mappings)
# Progress: 1910/67487
# Progress: 1920/67487
#   ✓ Progress saved (1920 mappings)
# Progress: 1930/67487
# Progress: 1940/67487
#   ✓ Progress saved (1940 mappings)
# Progress: 1950/67487
# Progress: 1960/67487
#   ✓ Progress saved (1960 mappings)
# Progress: 1970/67487
# Progress: 1980/67487
#   ✓ Progress saved (1980 mappings)
# Progress: 1990/67487
# Progress: 2000/67487
#   ✓ Progress saved (2000 mappings)
# Progress: 2010/67487
# Progress: 2020/67487
#   ✓ Progress saved (2020 mappings)
# Progress: 2030/67487
# Progress: 2040/67487
#   ✓ Progress saved (2040 mappings)
# Progress: 2050/67487
# Progress: 2060/67487
#   ✓ Progress saved (2060 mappings)
# Progress: 2070/67487
# Progress: 2080/67487
#   ✓ Progress saved (2080 mappings)
# Progress: 2090/67487
# Progress: 2100/67487
#   ✓ Progress saved (2100 mappings)
# Progress: 2110/67487
# Progress: 2120/67487
#   ✓ Progress saved (2120 mappings)
# Progress: 2130/67487
# Progress: 2140/67487
#   ✓ Progress saved (2140 mappings)
# Progress: 2150/67487
# Progress: 2160/67487
#   ✓ Progress saved (2160 mappings)
# Progress: 2170/67487
# Progress: 2180/67487
#   ✓ Progress saved (2180 mappings)
# Progress: 2190/67487
# Progress: 2200/67487
#   ✓ Progress saved (2200 mappings)
# Progress: 2210/67487
# Progress: 2220/67487
#   ✓ Progress saved (2220 mappings)
# Progress: 2230/67487
# Progress: 2240/67487
#   ✓ Progress saved (2240 mappings)
# Progress: 2250/67487
# Progress: 2260/67487
#   ✓ Progress saved (2260 mappings)
# Progress: 2270/67487
# Progress: 2280/67487
#   ✓ Progress saved (2280 mappings)
# Progress: 2290/67487
# Progress: 2300/67487
#   ✓ Progress saved (2300 mappings)
# Progress: 2310/67487
# Progress: 2320/67487
#   ✓ Progress saved (2320 mappings)
# Progress: 2330/67487
# Progress: 2340/67487
#   ✓ Progress saved (2340 mappings)
# Progress: 2350/67487
# Progress: 2360/67487
#   ✓ Progress saved (2360 mappings)
# Progress: 2370/67487
# Progress: 2380/67487
#   ✓ Progress saved (2380 mappings)
# Progress: 2390/67487
# Progress: 2400/67487
#   ✓ Progress saved (2400 mappings)
# Progress: 2410/67487
# Progress: 2420/67487
#   ✓ Progress saved (2420 mappings)
# Progress: 2430/67487
# Progress: 2440/67487
#   ✓ Progress saved (2440 mappings)
# Progress: 2450/67487
# Progress: 2460/67487
#   ✓ Progress saved (2460 mappings)
# Progress: 2470/67487
# Progress: 2480/67487
#   ✓ Progress saved (2480 mappings)
# Progress: 2490/67487
# Progress: 2500/67487
#   ✓ Progress saved (2500 mappings)
# Progress: 2510/67487
# Progress: 2520/67487
#   ✓ Progress saved (2520 mappings)
# Progress: 2530/67487
# Progress: 2540/67487
#   ✓ Progress saved (2540 mappings)
# Progress: 2550/67487
# Progress: 2560/67487
#   ✓ Progress saved (2560 mappings)
# Progress: 2570/67487
# Progress: 2580/67487
#   ✓ Progress saved (2580 mappings)
# Progress: 2590/67487
# Progress: 2600/67487
#   ✓ Progress saved (2600 mappings)
# Progress: 2610/67487
# Progress: 2620/67487
#   ✓ Progress saved (2620 mappings)
# Progress: 2630/67487
# Progress: 2640/67487
#   ✓ Progress saved (2640 mappings)
# Progress: 2650/67487
# Progress: 2660/67487
#   ✓ Progress saved (2660 mappings)
# Progress: 2670/67487
# Progress: 2680/67487
#   ✓ Progress saved (2680 mappings)
# Progress: 2690/67487
# Progress: 2700/67487
#   ✓ Progress saved (2700 mappings)
# Progress: 2710/67487
# Progress: 2720/67487
#   ✓ Progress saved (2720 mappings)
# Progress: 2730/67487
# Progress: 2740/67487
#   ✓ Progress saved (2740 mappings)
# Progress: 2750/67487
# Progress: 2760/67487
#   ✓ Progress saved (2760 mappings)
# Progress: 2770/67487
# Progress: 2780/67487
#   ✓ Progress saved (2780 mappings)
# Progress: 2790/67487
# Progress: 2800/67487
#   ✓ Progress saved (2800 mappings)
# Progress: 2810/67487
# Progress: 2820/67487
#   ✓ Progress saved (2820 mappings)
# Progress: 2830/67487
# Progress: 2840/67487
#   ✓ Progress saved (2840 mappings)
# Progress: 2850/67487
# Progress: 2860/67487
#   ✓ Progress saved (2860 mappings)
# Progress: 2870/67487
# Progress: 2880/67487
#   ✓ Progress saved (2880 mappings)
# Progress: 2890/67487
# Progress: 2900/67487
#   ✓ Progress saved (2900 mappings)
# Progress: 2910/67487
# Progress: 2920/67487
#   ✓ Progress saved (2920 mappings)
# Progress: 2930/67487
# Progress: 2940/67487
#   ✓ Progress saved (2940 mappings)
# Progress: 2950/67487
# Progress: 2960/67487
#   ✓ Progress saved (2960 mappings)
# Progress: 2970/67487
# Progress: 2980/67487
#   ✓ Progress saved (2980 mappings)
# Progress: 2990/67487
# Progress: 3000/67487
#   ✓ Progress saved (3000 mappings)
# Progress: 3010/67487
# Progress: 3020/67487
#   ✓ Progress saved (3020 mappings)
# Progress: 3030/67487
# Progress: 3040/67487
#   ✓ Progress saved (3040 mappings)
# Progress: 3050/67487
# Progress: 3060/67487
#   ✓ Progress saved (3060 mappings)
# Progress: 3070/67487
# Progress: 3080/67487
#   ✓ Progress saved (3080 mappings)
# Progress: 3090/67487
# Progress: 3100/67487
#   ✓ Progress saved (3100 mappings)
# Progress: 3110/67487
# Progress: 3120/67487
#   ✓ Progress saved (3120 mappings)
# Progress: 3130/67487
# Progress: 3140/67487
#   ✓ Progress saved (3140 mappings)
# Progress: 3150/67487
# Progress: 3160/67487
#   ✓ Progress saved (3160 mappings)
# Progress: 3170/67487
# Progress: 3180/67487
#   ✓ Progress saved (3180 mappings)
# Progress: 3190/67487
# Progress: 3200/67487
#   ✓ Progress saved (3200 mappings)
# Progress: 3210/67487
# Progress: 3220/67487
#   ✓ Progress saved (3220 mappings)
# Progress: 3230/67487
# Progress: 3240/67487
#   ✓ Progress saved (3240 mappings)
# Progress: 3250/67487
# Progress: 3260/67487
#   ✓ Progress saved (3260 mappings)
# Progress: 3270/67487
# Progress: 3280/67487
#   ✓ Progress saved (3280 mappings)
# Progress: 3290/67487
# Progress: 3300/67487
#   ✓ Progress saved (3300 mappings)
# Progress: 3310/67487
# Progress: 3320/67487
#   ✓ Progress saved (3320 mappings)
# Progress: 3330/67487
# Progress: 3340/67487
#   ✓ Progress saved (3340 mappings)
# Progress: 3350/67487
# Progress: 3360/67487
#   ✓ Progress saved (3360 mappings)
# Progress: 3370/67487
# Progress: 3380/67487
#   ✓ Progress saved (3380 mappings)
# Progress: 3390/67487
# Progress: 3400/67487
#   ✓ Progress saved (3400 mappings)
# Progress: 3410/67487
# Progress: 3420/67487
#   ✓ Progress saved (3420 mappings)
# Progress: 3430/67487
# Progress: 3440/67487
#   ✓ Progress saved (3440 mappings)
# Progress: 3450/67487
# Progress: 3460/67487
#   ✓ Progress saved (3460 mappings)
# Progress: 3470/67487
# Progress: 3480/67487
#   ✓ Progress saved (3480 mappings)
# Progress: 3490/67487
# Progress: 3500/67487
#   ✓ Progress saved (3500 mappings)
# Progress: 3510/67487
# Progress: 3520/67487
#   ✓ Progress saved (3520 mappings)
# Progress: 3530/67487
# Progress: 3540/67487
#   ✓ Progress saved (3540 mappings)
# Progress: 3550/67487
# Progress: 3560/67487
#   ✓ Progress saved (3560 mappings)
# Progress: 3570/67487
# Progress: 3580/67487
#   ✓ Progress saved (3580 mappings)
# Progress: 3590/67487
# Progress: 3600/67487
#   ✓ Progress saved (3600 mappings)
# Progress: 3610/67487
# Progress: 3620/67487
#   ✓ Progress saved (3620 mappings)
# Progress: 3630/67487
# Progress: 3640/67487
#   ✓ Progress saved (3640 mappings)
# Progress: 3650/67487
# Progress: 3660/67487
#   ✓ Progress saved (3660 mappings)
# Progress: 3670/67487
# Progress: 3680/67487
#   ✓ Progress saved (3680 mappings)
# Progress: 3690/67487
# Progress: 3700/67487
#   ✓ Progress saved (3700 mappings)
# Progress: 3710/67487
# Progress: 3720/67487
#   ✓ Progress saved (3720 mappings)
# Progress: 3730/67487
# Progress: 3740/67487
#   ✓ Progress saved (3740 mappings)
# Progress: 3750/67487
# Progress: 3760/67487
#   ✓ Progress saved (3760 mappings)
# Progress: 3770/67487
# Progress: 3780/67487
#   ✓ Progress saved (3780 mappings)
# Progress: 3790/67487
# Progress: 3800/67487
#   ✓ Progress saved (3800 mappings)
# Progress: 3810/67487
# Progress: 3820/67487
#   ✓ Progress saved (3820 mappings)
# Progress: 3830/67487
# Progress: 3840/67487
#   ✓ Progress saved (3840 mappings)
# Progress: 3850/67487
# Progress: 3860/67487
#   ✓ Progress saved (3860 mappings)
# Progress: 3870/67487
# Progress: 3880/67487
#   ✓ Progress saved (3880 mappings)
# Progress: 3890/67487
# Progress: 3900/67487
#   ✓ Progress saved (3900 mappings)
# Progress: 3910/67487
# Progress: 3920/67487
#   ✓ Progress saved (3920 mappings)
# Progress: 3930/67487
# Progress: 3940/67487
#   ✓ Progress saved (3940 mappings)
# Progress: 3950/67487
# Progress: 3960/67487
#   ✓ Progress saved (3960 mappings)
# Progress: 3970/67487
# Progress: 3980/67487
#   ✓ Progress saved (3980 mappings)
# Progress: 3990/67487
# Progress: 4000/67487
#   ✓ Progress saved (4000 mappings)
# Progress: 4010/67487
# Progress: 4020/67487
#   ✓ Progress saved (4020 mappings)
# Progress: 4030/67487
# Progress: 4040/67487
#   ✓ Progress saved (4040 mappings)
# Progress: 4050/67487
# Progress: 4060/67487
#   ✓ Progress saved (4060 mappings)
# Progress: 4070/67487
# Progress: 4080/67487
#   ✓ Progress saved (4080 mappings)
# Progress: 4090/67487
# Progress: 4100/67487
#   ✓ Progress saved (4100 mappings)
# Progress: 4110/67487
# Progress: 4120/67487
#   ✓ Progress saved (4120 mappings)
# Progress: 4130/67487
# Progress: 4140/67487
#   ✓ Progress saved (4140 mappings)
# Progress: 4150/67487
# Progress: 4160/67487
#   ✓ Progress saved (4160 mappings)
# Progress: 4170/67487
# Progress: 4180/67487
#   ✓ Progress saved (4180 mappings)
# Progress: 4190/67487
# Progress: 4200/67487
#   ✓ Progress saved (4200 mappings)
# Progress: 4210/67487
# Progress: 4220/67487
#   ✓ Progress saved (4220 mappings)
# Progress: 4230/67487
# Progress: 4240/67487
#   ✓ Progress saved (4240 mappings)
# Progress: 4250/67487
# Progress: 4260/67487
#   ✓ Progress saved (4260 mappings)
# Progress: 4270/67487
# Progress: 4280/67487
#   ✓ Progress saved (4280 mappings)
# Progress: 4290/67487
# Progress: 4300/67487
#   ✓ Progress saved (4300 mappings)
# Progress: 4310/67487
# Progress: 4320/67487
#   ✓ Progress saved (4320 mappings)
# Progress: 4330/67487
# Progress: 4340/67487
#   ✓ Progress saved (4340 mappings)
# Progress: 4350/67487
# Progress: 4360/67487
#   ✓ Progress saved (4360 mappings)
# Progress: 4370/67487
# Progress: 4380/67487
#   ✓ Progress saved (4380 mappings)
# Progress: 4390/67487
# Progress: 4400/67487
#   ✓ Progress saved (4400 mappings)
# Progress: 4410/67487
# Progress: 4420/67487
#   ✓ Progress saved (4420 mappings)
# Progress: 4430/67487
# Progress: 4440/67487
#   ✓ Progress saved (4440 mappings)
# Progress: 4450/67487
# Progress: 4460/67487
#   ✓ Progress saved (4460 mappings)
# Progress: 4470/67487
# Progress: 4480/67487
#   ✓ Progress saved (4480 mappings)
# Progress: 4490/67487
# Progress: 4500/67487
#   ✓ Progress saved (4500 mappings)
# Progress: 4510/67487
# Progress: 4520/67487
#   ✓ Progress saved (4520 mappings)
# Progress: 4530/67487
# Progress: 4540/67487
#   ✓ Progress saved (4540 mappings)
# Progress: 4550/67487
# Progress: 4560/67487
#   ✓ Progress saved (4560 mappings)
# Progress: 4570/67487
# Progress: 4580/67487
#   ✓ Progress saved (4580 mappings)
# Progress: 4590/67487
# Progress: 4600/67487
#   ✓ Progress saved (4600 mappings)
# Progress: 4610/67487
# Progress: 4620/67487
#   ✓ Progress saved (4620 mappings)
# Progress: 4630/67487
# Progress: 4640/67487
#   ✓ Progress saved (4640 mappings)
# Progress: 4650/67487
# Progress: 4660/67487
#   ✓ Progress saved (4660 mappings)
# Progress: 4670/67487
# Progress: 4680/67487
#   ✓ Progress saved (4680 mappings)
# Progress: 4690/67487
# Progress: 4700/67487
#   ✓ Progress saved (4700 mappings)
# Progress: 4710/67487
# Progress: 4720/67487
#   ✓ Progress saved (4720 mappings)
# Progress: 4730/67487
# Progress: 4740/67487
#   ✓ Progress saved (4740 mappings)
# Progress: 4750/67487
# Progress: 4760/67487
#   ✓ Progress saved (4760 mappings)
# Progress: 4770/67487
# Progress: 4780/67487
#   ✓ Progress saved (4780 mappings)
# Progress: 4790/67487
# Progress: 4800/67487
#   ✓ Progress saved (4800 mappings)
# Progress: 4810/67487
# Progress: 4820/67487
#   ✓ Progress saved (4820 mappings)
# Progress: 4830/67487
# Progress: 4840/67487
#   ✓ Progress saved (4840 mappings)
# Progress: 4850/67487
# Progress: 4860/67487
#   ✓ Progress saved (4860 mappings)
# Progress: 4870/67487
# Progress: 4880/67487
#   ✓ Progress saved (4880 mappings)
# Progress: 4890/67487
# Progress: 4900/67487
#   ✓ Progress saved (4900 mappings)
# Progress: 4910/67487
# Progress: 4920/67487
#   ✓ Progress saved (4920 mappings)
# Progress: 4930/67487
# Progress: 4940/67487
#   ✓ Progress saved (4940 mappings)
# Progress: 4950/67487
# Progress: 4960/67487
#   ✓ Progress saved (4960 mappings)
# Progress: 4970/67487
# Progress: 4980/67487
#   ✓ Progress saved (4980 mappings)
# Progress: 4990/67487
# Progress: 5000/67487
#   ✓ Progress saved (5000 mappings)
# Progress: 5010/67487
# Progress: 5020/67487
#   ✓ Progress saved (5020 mappings)
# Progress: 5030/67487
# Progress: 5040/67487
#   ✓ Progress saved (5040 mappings)
# Progress: 5050/67487
# Progress: 5060/67487
#   ✓ Progress saved (5060 mappings)
# Progress: 5070/67487
# Progress: 5080/67487
#   ✓ Progress saved (5080 mappings)
# Progress: 5090/67487
# Progress: 5100/67487
#   ✓ Progress saved (5100 mappings)
# Progress: 5110/67487
# Progress: 5120/67487
#   ✓ Progress saved (5120 mappings)
# Progress: 5130/67487
# Progress: 5140/67487
#   ✓ Progress saved (5140 mappings)
# Progress: 5150/67487
# Progress: 5160/67487
#   ✓ Progress saved (5160 mappings)
# Progress: 5170/67487
# Progress: 5180/67487
#   ✓ Progress saved (5180 mappings)
# Progress: 5190/67487
# Progress: 5200/67487
#   ✓ Progress saved (5200 mappings)
# Progress: 5210/67487
# Progress: 5220/67487
#   ✓ Progress saved (5220 mappings)
# Progress: 5230/67487
# Progress: 5240/67487
#   ✓ Progress saved (5240 mappings)
# Progress: 5250/67487
# Progress: 5260/67487
#   ✓ Progress saved (5260 mappings)
# Progress: 5270/67487
# Progress: 5280/67487
#   ✓ Progress saved (5280 mappings)
# Progress: 5290/67487
# Progress: 5300/67487
#   ✓ Progress saved (5300 mappings)
# Progress: 5310/67487
# Progress: 5320/67487
#   ✓ Progress saved (5320 mappings)
# Progress: 5330/67487
# Progress: 5340/67487
#   ✓ Progress saved (5340 mappings)
# Progress: 5350/67487
# Progress: 5360/67487
#   ✓ Progress saved (5360 mappings)
# Progress: 5370/67487
# Progress: 5380/67487
#   ✓ Progress saved (5380 mappings)
# Progress: 5390/67487
# Progress: 5400/67487
#   ✓ Progress saved (5400 mappings)
# Progress: 5410/67487
# Progress: 5420/67487
#   ✓ Progress saved (5420 mappings)
# Progress: 5430/67487
# Progress: 5440/67487
#   ✓ Progress saved (5440 mappings)
# Progress: 5450/67487
# Progress: 5460/67487
#   ✓ Progress saved (5460 mappings)
# Progress: 5470/67487
# Progress: 5480/67487
#   ✓ Progress saved (5480 mappings)
# Progress: 5490/67487
# Progress: 5500/67487
#   ✓ Progress saved (5500 mappings)
# Progress: 5510/67487
# Progress: 5520/67487
#   ✓ Progress saved (5520 mappings)
# Progress: 5530/67487
# Progress: 5540/67487
#   ✓ Progress saved (5540 mappings)
# Progress: 5550/67487
# Progress: 5560/67487
#   ✓ Progress saved (5560 mappings)
# Progress: 5570/67487
# Progress: 5580/67487
#   ✓ Progress saved (5580 mappings)
# Progress: 5590/67487
# Progress: 5600/67487
#   ✓ Progress saved (5600 mappings)
# Progress: 5610/67487
# Progress: 5620/67487
#   ✓ Progress saved (5620 mappings)
# Progress: 5630/67487
# Progress: 5640/67487
#   ✓ Progress saved (5640 mappings)
# Progress: 5650/67487
# Progress: 5660/67487
#   ✓ Progress saved (5660 mappings)
# Progress: 5670/67487
# Progress: 5680/67487
#   ✓ Progress saved (5680 mappings)
# Progress: 5690/67487
# Progress: 5700/67487
#   ✓ Progress saved (5700 mappings)
# Progress: 5710/67487
# Progress: 5720/67487
#   ✓ Progress saved (5720 mappings)
# Progress: 5730/67487
# Progress: 5740/67487
#   ✓ Progress saved (5740 mappings)
# Progress: 5750/67487
# Progress: 5760/67487
#   ✓ Progress saved (5760 mappings)
# Progress: 5770/67487
# Progress: 5780/67487
#   ✓ Progress saved (5780 mappings)
# Progress: 5790/67487
# Progress: 5800/67487
#   ✓ Progress saved (5800 mappings)
# Progress: 5810/67487
# Progress: 5820/67487
#   ✓ Progress saved (5820 mappings)
# Progress: 5830/67487
# Progress: 5840/67487
#   ✓ Progress saved (5840 mappings)
# Progress: 5850/67487
# Progress: 5860/67487
#   ✓ Progress saved (5860 mappings)
# Progress: 5870/67487
# Progress: 5880/67487
#   ✓ Progress saved (5880 mappings)
# Progress: 5890/67487
# Progress: 5900/67487
#   ✓ Progress saved (5900 mappings)
# Progress: 5910/67487
# Progress: 5920/67487
#   ✓ Progress saved (5920 mappings)
# Progress: 5930/67487
# Progress: 5940/67487
#   ✓ Progress saved (5940 mappings)
# Progress: 5950/67487
# Progress: 5960/67487
#   ✓ Progress saved (5960 mappings)
# Progress: 5970/67487
# Progress: 5980/67487
#   ✓ Progress saved (5980 mappings)
# Progress: 5990/67487
# Progress: 6000/67487
#   ✓ Progress saved (6000 mappings)
# Progress: 6010/67487
# Progress: 6020/67487
#   ✓ Progress saved (6020 mappings)
# Progress: 6030/67487
# Progress: 6040/67487
#   ✓ Progress saved (6040 mappings)
# Progress: 6050/67487
# Progress: 6060/67487
#   ✓ Progress saved (6060 mappings)
# Progress: 6070/67487
# Progress: 6080/67487
#   ✓ Progress saved (6080 mappings)
# Progress: 6090/67487
# Progress: 6100/67487
#   ✓ Progress saved (6100 mappings)
# Progress: 6110/67487
# Progress: 6120/67487
#   ✓ Progress saved (6120 mappings)
# Progress: 6130/67487
# Progress: 6140/67487
#   ✓ Progress saved (6140 mappings)
# Progress: 6150/67487
# Progress: 6160/67487
#   ✓ Progress saved (6160 mappings)
# Progress: 6170/67487
# Progress: 6180/67487
#   ✓ Progress saved (6180 mappings)
# Progress: 6190/67487
# Progress: 6200/67487
#   ✓ Progress saved (6200 mappings)
# Progress: 6210/67487
# Progress: 6220/67487
#   ✓ Progress saved (6220 mappings)
# Progress: 6230/67487
# Progress: 6240/67487
#   ✓ Progress saved (6240 mappings)
# Progress: 6250/67487
# Progress: 6260/67487
#   ✓ Progress saved (6260 mappings)
# Progress: 6270/67487
# Progress: 6280/67487
#   ✓ Progress saved (6280 mappings)
# Progress: 6290/67487
# Progress: 6300/67487
#   ✓ Progress saved (6300 mappings)
# Progress: 6310/67487
# Progress: 6320/67487
#   ✓ Progress saved (6320 mappings)
# Progress: 6330/67487
# Progress: 6340/67487
#   ✓ Progress saved (6340 mappings)
# Progress: 6350/67487
# Progress: 6360/67487
#   ✓ Progress saved (6360 mappings)
# Progress: 6370/67487
# Progress: 6380/67487
#   ✓ Progress saved (6380 mappings)
# Progress: 6390/67487
# Progress: 6400/67487
#   ✓ Progress saved (6400 mappings)
# Progress: 6410/67487
# Progress: 6420/67487
#   ✓ Progress saved (6420 mappings)
# Progress: 6430/67487
# Progress: 6440/67487
#   ✓ Progress saved (6440 mappings)
# Progress: 6450/67487
# Progress: 6460/67487
#   ✓ Progress saved (6460 mappings)
# Progress: 6470/67487
# Progress: 6480/67487
#   ✓ Progress saved (6480 mappings)
# Progress: 6490/67487
# Progress: 6500/67487
#   ✓ Progress saved (6500 mappings)
# Progress: 6510/67487
# Progress: 6520/67487
#   ✓ Progress saved (6520 mappings)
# Progress: 6530/67487
# Progress: 6540/67487
#   ✓ Progress saved (6540 mappings)
# Progress: 6550/67487
# Progress: 6560/67487
#   ✓ Progress saved (6560 mappings)
# Progress: 6570/67487
# Progress: 6580/67487
#   ✓ Progress saved (6580 mappings)
# Progress: 6590/67487
# Progress: 6600/67487
#   ✓ Progress saved (6600 mappings)
# Progress: 6610/67487
# Progress: 6620/67487
#   ✓ Progress saved (6620 mappings)
# Progress: 6630/67487
# Progress: 6640/67487
#   ✓ Progress saved (6640 mappings)
# Progress: 6650/67487
# Progress: 6660/67487
#   ✓ Progress saved (6660 mappings)
# Progress: 6670/67487
# Progress: 6680/67487
#   ✓ Progress saved (6680 mappings)
# Progress: 6690/67487
# Progress: 6700/67487
#   ✓ Progress saved (6700 mappings)
# Progress: 6710/67487
# Progress: 6720/67487
#   ✓ Progress saved (6720 mappings)
# Progress: 6730/67487
# Progress: 6740/67487
#   ✓ Progress saved (6740 mappings)
# Progress: 6750/67487
# Progress: 6760/67487
#   ✓ Progress saved (6760 mappings)
# Progress: 6770/67487
# Progress: 6780/67487
#   ✓ Progress saved (6780 mappings)
# Progress: 6790/67487
# Progress: 6800/67487
#   ✓ Progress saved (6800 mappings)
# Progress: 6810/67487
# Progress: 6820/67487
#   ✓ Progress saved (6820 mappings)
# Progress: 6830/67487
# Progress: 6840/67487
#   ✓ Progress saved (6840 mappings)
# Progress: 6850/67487
# Progress: 6860/67487
#   ✓ Progress saved (6860 mappings)
# Progress: 6870/67487
# Progress: 6880/67487
#   ✓ Progress saved (6880 mappings)
# Progress: 6890/67487
# Progress: 6900/67487
#   ✓ Progress saved (6900 mappings)
# Progress: 6910/67487
# Progress: 6920/67487
#   ✓ Progress saved (6920 mappings)
# Progress: 6930/67487
# Progress: 6940/67487
#   ✓ Progress saved (6940 mappings)
# Progress: 6950/67487
# Progress: 6960/67487
#   ✓ Progress saved (6960 mappings)
# Progress: 6970/67487
# Progress: 6980/67487
#   ✓ Progress saved (6980 mappings)
# Progress: 6990/67487
# Progress: 7000/67487
#   ✓ Progress saved (7000 mappings)
# Progress: 7010/67487
# Progress: 7020/67487
#   ✓ Progress saved (7020 mappings)
# Progress: 7030/67487
# Progress: 7040/67487
#   ✓ Progress saved (7040 mappings)
# Progress: 7050/67487
# Progress: 7060/67487
#   ✓ Progress saved (7060 mappings)
# Progress: 7070/67487
# Progress: 7080/67487
#   ✓ Progress saved (7080 mappings)
# Progress: 7090/67487
# Progress: 7100/67487
#   ✓ Progress saved (7100 mappings)
# Progress: 7110/67487
# Progress: 7120/67487
#   ✓ Progress saved (7120 mappings)
# Progress: 7130/67487
# Progress: 7140/67487
#   ✓ Progress saved (7140 mappings)
# Progress: 7150/67487
# Progress: 7160/67487
#   ✓ Progress saved (7160 mappings)
# Progress: 7170/67487
# Progress: 7180/67487
#   ✓ Progress saved (7180 mappings)
# Progress: 7190/67487
# Progress: 7200/67487
#   ✓ Progress saved (7200 mappings)
# Progress: 7210/67487
# Progress: 7220/67487
#   ✓ Progress saved (7220 mappings)
# Progress: 7230/67487
# Progress: 7240/67487
#   ✓ Progress saved (7240 mappings)
# Progress: 7250/67487
# Progress: 7260/67487
#   ✓ Progress saved (7260 mappings)
# Progress: 7270/67487
# Progress: 7280/67487
#   ✓ Progress saved (7280 mappings)
# Progress: 7290/67487
# Progress: 7300/67487
#   ✓ Progress saved (7300 mappings)
# Progress: 7310/67487
# Progress: 7320/67487
#   ✓ Progress saved (7320 mappings)
# Progress: 7330/67487
# Progress: 7340/67487
#   ✓ Progress saved (7340 mappings)
# Progress: 7350/67487
# Progress: 7360/67487
#   ✓ Progress saved (7360 mappings)
# Progress: 7370/67487
# Progress: 7380/67487
#   ✓ Progress saved (7380 mappings)
# Progress: 7390/67487
# Progress: 7400/67487
#   ✓ Progress saved (7400 mappings)
# Progress: 7410/67487
# Progress: 7420/67487
#   ✓ Progress saved (7420 mappings)
# Progress: 7430/67487
# Progress: 7440/67487
#   ✓ Progress saved (7440 mappings)
# Progress: 7450/67487
# Progress: 7460/67487
#   ✓ Progress saved (7460 mappings)
# Progress: 7470/67487
# Progress: 7480/67487
#   ✓ Progress saved (7480 mappings)
# Progress: 7490/67487
# Progress: 7500/67487
#   ✓ Progress saved (7500 mappings)
# Progress: 7510/67487
# Progress: 7520/67487
#   ✓ Progress saved (7520 mappings)
# Progress: 7530/67487
# Progress: 7540/67487
#   ✓ Progress saved (7540 mappings)
# Progress: 7550/67487
# Progress: 7560/67487
#   ✓ Progress saved (7560 mappings)
# Progress: 7570/67487
# Progress: 7580/67487
#   ✓ Progress saved (7580 mappings)
# Progress: 7590/67487
# Progress: 7600/67487
#   ✓ Progress saved (7600 mappings)
# Progress: 7610/67487
# Progress: 7620/67487
#   ✓ Progress saved (7620 mappings)
# Progress: 7630/67487
# Progress: 7640/67487
#   ✓ Progress saved (7640 mappings)
# Progress: 7650/67487
# Progress: 7660/67487
#   ✓ Progress saved (7660 mappings)
# Progress: 7670/67487
# Progress: 7680/67487
#   ✓ Progress saved (7680 mappings)
# Progress: 7690/67487
# Progress: 7700/67487
#   ✓ Progress saved (7700 mappings)
# Progress: 7710/67487
# Progress: 7720/67487
#   ✓ Progress saved (7720 mappings)
# Progress: 7730/67487
# Progress: 7740/67487
#   ✓ Progress saved (7740 mappings)
# Progress: 7750/67487
# Progress: 7760/67487
#   ✓ Progress saved (7760 mappings)
# Progress: 7770/67487
# Progress: 7780/67487
#   ✓ Progress saved (7780 mappings)
# Progress: 7790/67487
# Progress: 7800/67487
#   ✓ Progress saved (7800 mappings)
# Progress: 7810/67487
# Progress: 7820/67487
#   ✓ Progress saved (7820 mappings)
# Progress: 7830/67487
# Progress: 7840/67487
#   ✓ Progress saved (7840 mappings)
# Progress: 7850/67487
# Progress: 7860/67487
#   ✓ Progress saved (7860 mappings)
# Progress: 7870/67487
# Progress: 7880/67487
#   ✓ Progress saved (7880 mappings)
# Progress: 7890/67487
# Progress: 7900/67487
#   ✓ Progress saved (7900 mappings)
# Progress: 7910/67487
# Progress: 7920/67487
#   ✓ Progress saved (7920 mappings)
# Progress: 7930/67487
# Progress: 7940/67487
#   ✓ Progress saved (7940 mappings)
# Progress: 7950/67487
# Progress: 7960/67487
#   ✓ Progress saved (7960 mappings)
# Progress: 7970/67487
# Progress: 7980/67487
#   ✓ Progress saved (7980 mappings)
# Progress: 7990/67487
# Progress: 8000/67487
#   ✓ Progress saved (8000 mappings)
# Progress: 8010/67487
# Progress: 8020/67487
#   ✓ Progress saved (8020 mappings)
# Progress: 8030/67487
# Progress: 8040/67487
#   ✓ Progress saved (8040 mappings)
# Progress: 8050/67487
# Progress: 8060/67487
#   ✓ Progress saved (8060 mappings)
# Progress: 8070/67487
# Progress: 8080/67487
#   ✓ Progress saved (8080 mappings)
# Progress: 8090/67487
# Progress: 8100/67487
#   ✓ Progress saved (8100 mappings)
# Progress: 8110/67487
# Progress: 8120/67487
#   ✓ Progress saved (8120 mappings)
# Progress: 8130/67487
# Progress: 8140/67487
#   ✓ Progress saved (8140 mappings)
# Progress: 8150/67487
# Progress: 8160/67487
#   ✓ Progress saved (8160 mappings)
# Progress: 8170/67487
# Progress: 8180/67487
#   ✓ Progress saved (8180 mappings)
# Progress: 8190/67487
# Progress: 8200/67487
#   ✓ Progress saved (8200 mappings)
# Progress: 8210/67487
# Progress: 8220/67487
#   ✓ Progress saved (8220 mappings)
# Progress: 8230/67487
# Progress: 8240/67487
#   ✓ Progress saved (8240 mappings)
# Progress: 8250/67487
# Progress: 8260/67487
#   ✓ Progress saved (8260 mappings)
# Progress: 8270/67487
# Progress: 8280/67487
#   ✓ Progress saved (8280 mappings)
# Progress: 8290/67487
# Progress: 8300/67487
#   ✓ Progress saved (8300 mappings)
# Progress: 8310/67487
# Progress: 8320/67487
#   ✓ Progress saved (8320 mappings)
# Progress: 8330/67487
# Progress: 8340/67487
#   ✓ Progress saved (8340 mappings)
# Progress: 8350/67487
# Progress: 8360/67487
#   ✓ Progress saved (8360 mappings)
# Progress: 8370/67487
# Progress: 8380/67487
#   ✓ Progress saved (8380 mappings)
# Progress: 8390/67487
# Progress: 8400/67487
#   ✓ Progress saved (8400 mappings)
# Progress: 8410/67487
# Progress: 8420/67487
#   ✓ Progress saved (8420 mappings)
# Progress: 8430/67487
# Progress: 8440/67487
#   ✓ Progress saved (8440 mappings)
# Progress: 8450/67487
# Progress: 8460/67487
#   ✓ Progress saved (8460 mappings)
# Progress: 8470/67487
# Progress: 8480/67487
#   ✓ Progress saved (8480 mappings)
# Progress: 8490/67487
# Progress: 8500/67487
#   ✓ Progress saved (8500 mappings)
# Progress: 8510/67487
# Progress: 8520/67487
#   ✓ Progress saved (8520 mappings)
# Progress: 8530/67487
# Progress: 8540/67487
#   ✓ Progress saved (8540 mappings)
# Progress: 8550/67487
# Progress: 8560/67487
#   ✓ Progress saved (8560 mappings)
# Progress: 8570/67487
# Progress: 8580/67487
#   ✓ Progress saved (8580 mappings)
# Progress: 8590/67487
# Progress: 8600/67487
#   ✓ Progress saved (8600 mappings)
# Progress: 8610/67487
# Progress: 8620/67487
#   ✓ Progress saved (8620 mappings)
# Progress: 8630/67487
# Progress: 8640/67487
#   ✓ Progress saved (8640 mappings)
# Progress: 8650/67487
# Progress: 8660/67487
#   ✓ Progress saved (8660 mappings)
# Progress: 8670/67487
# Progress: 8680/67487
#   ✓ Progress saved (8680 mappings)
# Progress: 8690/67487
# Progress: 8700/67487
#   ✓ Progress saved (8700 mappings)
# Progress: 8710/67487
# Progress: 8720/67487
#   ✓ Progress saved (8720 mappings)
# Progress: 8730/67487
# Progress: 8740/67487
#   ✓ Progress saved (8740 mappings)
# Progress: 8750/67487
# Progress: 8760/67487
#   ✓ Progress saved (8760 mappings)
# Progress: 8770/67487
# Progress: 8780/67487
#   ✓ Progress saved (8780 mappings)
# Progress: 8790/67487
# Progress: 8800/67487
#   ✓ Progress saved (8800 mappings)
# Progress: 8810/67487
# Progress: 8820/67487
#   ✓ Progress saved (8820 mappings)
# Progress: 8830/67487
# Progress: 8840/67487
#   ✓ Progress saved (8840 mappings)
# Progress: 8850/67487
# Progress: 8860/67487
#   ✓ Progress saved (8860 mappings)
# Progress: 8870/67487
# Progress: 8880/67487
#   ✓ Progress saved (8880 mappings)
# Progress: 8890/67487
# Progress: 8900/67487
#   ✓ Progress saved (8900 mappings)
# Progress: 8910/67487
# Progress: 8920/67487
#   ✓ Progress saved (8920 mappings)
# Progress: 8930/67487
# Progress: 8940/67487
#   ✓ Progress saved (8940 mappings)
# Progress: 8950/67487
# Progress: 8960/67487
#   ✓ Progress saved (8960 mappings)
# Progress: 8970/67487
# Progress: 8980/67487
#   ✓ Progress saved (8980 mappings)
# Progress: 8990/67487
# Progress: 9000/67487
#   ✓ Progress saved (9000 mappings)
# Progress: 9010/67487
# Progress: 9020/67487
#   ✓ Progress saved (9020 mappings)
# Progress: 9030/67487
# Progress: 9040/67487
#   ✓ Progress saved (9040 mappings)
# Progress: 9050/67487
# Progress: 9060/67487
#   ✓ Progress saved (9060 mappings)
# Progress: 9070/67487
# Progress: 9080/67487
#   ✓ Progress saved (9080 mappings)
# Progress: 9090/67487
# Progress: 9100/67487
#   ✓ Progress saved (9100 mappings)
# Progress: 9110/67487
# Progress: 9120/67487
#   ✓ Progress saved (9120 mappings)
# Progress: 9130/67487
# Progress: 9140/67487
#   ✓ Progress saved (9140 mappings)
# Progress: 9150/67487
# Progress: 9160/67487
#   ✓ Progress saved (9160 mappings)
# Progress: 9170/67487
# Progress: 9180/67487
#   ✓ Progress saved (9180 mappings)
# Progress: 9190/67487
# Progress: 9200/67487
#   ✓ Progress saved (9200 mappings)
# Progress: 9210/67487
# Progress: 9220/67487
#   ✓ Progress saved (9220 mappings)
# Progress: 9230/67487
# Progress: 9240/67487
#   ✓ Progress saved (9240 mappings)
# Progress: 9250/67487
# Progress: 9260/67487
#   ✓ Progress saved (9260 mappings)
# Progress: 9270/67487
# Progress: 9280/67487
#   ✓ Progress saved (9280 mappings)
# Progress: 9290/67487
# Progress: 9300/67487
#   ✓ Progress saved (9300 mappings)
# Progress: 9310/67487
# Progress: 9320/67487
#   ✓ Progress saved (9320 mappings)
# Progress: 9330/67487
# Progress: 9340/67487
#   ✓ Progress saved (9340 mappings)
# Progress: 9350/67487
# Progress: 9360/67487
#   ✓ Progress saved (9360 mappings)
# Progress: 9370/67487
# Progress: 9380/67487
#   ✓ Progress saved (9380 mappings)
# Progress: 9390/67487
# Progress: 9400/67487
#   ✓ Progress saved (9400 mappings)
# Progress: 9410/67487
# Progress: 9420/67487
#   ✓ Progress saved (9420 mappings)
# Progress: 9430/67487
# Progress: 9440/67487
#   ✓ Progress saved (9440 mappings)
# Progress: 9450/67487
# Progress: 9460/67487
#   ✓ Progress saved (9460 mappings)
# Progress: 9470/67487
# Progress: 9480/67487
#   ✓ Progress saved (9480 mappings)
# Progress: 9490/67487
# Progress: 9500/67487
#   ✓ Progress saved (9500 mappings)
# Progress: 9510/67487
# Progress: 9520/67487
#   ✓ Progress saved (9520 mappings)
# Progress: 9530/67487
# Progress: 9540/67487
#   ✓ Progress saved (9540 mappings)
# Progress: 9550/67487
# Progress: 9560/67487
#   ✓ Progress saved (9560 mappings)
# Progress: 9570/67487
# Progress: 9580/67487
#   ✓ Progress saved (9580 mappings)
# Progress: 9590/67487
# Progress: 9600/67487
#   ✓ Progress saved (9600 mappings)
# Progress: 9610/67487
# Progress: 9620/67487
#   ✓ Progress saved (9620 mappings)
# Progress: 9630/67487
# Progress: 9640/67487
#   ✓ Progress saved (9640 mappings)
# Progress: 9650/67487
# Progress: 9660/67487
#   ✓ Progress saved (9660 mappings)
# Progress: 9670/67487
# Progress: 9680/67487
#   ✓ Progress saved (9680 mappings)
# Progress: 9690/67487
# Progress: 9700/67487
#   ✓ Progress saved (9700 mappings)
# Progress: 9710/67487
# Progress: 9720/67487
#   ✓ Progress saved (9720 mappings)
# Progress: 9730/67487
# Progress: 9740/67487
#   ✓ Progress saved (9740 mappings)
# Progress: 9750/67487
# Progress: 9760/67487
#   ✓ Progress saved (9760 mappings)
# Progress: 9770/67487
# Progress: 9780/67487
#   ✓ Progress saved (9780 mappings)
# Progress: 9790/67487
# Progress: 9800/67487
#   ✓ Progress saved (9800 mappings)
# Progress: 9810/67487
# Progress: 9820/67487
#   ✓ Progress saved (9820 mappings)
# Progress: 9830/67487
# Progress: 9840/67487
#   ✓ Progress saved (9840 mappings)
# Progress: 9850/67487
# Progress: 9860/67487
#   ✓ Progress saved (9860 mappings)
# Progress: 9870/67487
# Progress: 9880/67487
#   ✓ Progress saved (9880 mappings)
# Progress: 9890/67487
# Progress: 9900/67487
#   ✓ Progress saved (9900 mappings)
# Progress: 9910/67487
# Progress: 9920/67487
#   ✓ Progress saved (9920 mappings)
# Progress: 9930/67487
# Progress: 9940/67487
#   ✓ Progress saved (9940 mappings)
# Progress: 9950/67487
# Progress: 9960/67487
#   ✓ Progress saved (9960 mappings)
# Progress: 9970/67487
# Progress: 9980/67487
#   ✓ Progress saved (9980 mappings)
# Progress: 9990/67487
# Progress: 10000/67487
#   ✓ Progress saved (10000 mappings)
# Progress: 10010/67487
# Progress: 10020/67487
#   ✓ Progress saved (10020 mappings)
# Progress: 10030/67487
# Progress: 10040/67487
#   ✓ Progress saved (10040 mappings)
# Progress: 10050/67487
# Progress: 10060/67487
#   ✓ Progress saved (10060 mappings)
# Progress: 10070/67487
# Progress: 10080/67487
#   ✓ Progress saved (10080 mappings)
# Progress: 10090/67487
# Progress: 10100/67487
#   ✓ Progress saved (10100 mappings)
# Progress: 10110/67487
# Progress: 10120/67487
#   ✓ Progress saved (10120 mappings)
# Progress: 10130/67487
# Progress: 10140/67487
#   ✓ Progress saved (10140 mappings)
# Progress: 10150/67487
# Progress: 10160/67487
#   ✓ Progress saved (10160 mappings)
# Progress: 10170/67487
# Progress: 10180/67487
#   ✓ Progress saved (10180 mappings)
# Progress: 10190/67487
# Progress: 10200/67487
#   ✓ Progress saved (10200 mappings)
# Progress: 10210/67487
# Progress: 10220/67487
#   ✓ Progress saved (10220 mappings)
# Progress: 10230/67487
# Progress: 10240/67487
#   ✓ Progress saved (10240 mappings)
# Progress: 10250/67487
# Progress: 10260/67487
#   ✓ Progress saved (10260 mappings)
# Progress: 10270/67487
# Progress: 10280/67487
#   ✓ Progress saved (10280 mappings)
# Progress: 10290/67487
# Progress: 10300/67487
#   ✓ Progress saved (10300 mappings)
# Progress: 10310/67487
# Progress: 10320/67487
#   ✓ Progress saved (10320 mappings)
# Progress: 10330/67487
# Progress: 10340/67487
#   ✓ Progress saved (10340 mappings)
# Progress: 10350/67487
# Progress: 10360/67487
#   ✓ Progress saved (10360 mappings)
# Progress: 10370/67487
# Progress: 10380/67487
#   ✓ Progress saved (10380 mappings)
# Progress: 10390/67487
# Progress: 10400/67487
#   ✓ Progress saved (10400 mappings)
# Progress: 10410/67487
# Progress: 10420/67487
#   ✓ Progress saved (10420 mappings)
# Progress: 10430/67487
# Progress: 10440/67487
#   ✓ Progress saved (10440 mappings)
# Progress: 10450/67487
# Progress: 10460/67487
#   ✓ Progress saved (10460 mappings)
# Progress: 10470/67487
# Progress: 10480/67487
#   ✓ Progress saved (10480 mappings)
# Progress: 10490/67487
# Progress: 10500/67487
#   ✓ Progress saved (10500 mappings)
# Progress: 10510/67487
# Progress: 10520/67487
#   ✓ Progress saved (10520 mappings)
# Progress: 10530/67487
# Progress: 10540/67487
#   ✓ Progress saved (10540 mappings)
# Progress: 10550/67487
# Progress: 10560/67487
#   ✓ Progress saved (10560 mappings)
# Progress: 10570/67487
# Progress: 10580/67487
#   ✓ Progress saved (10580 mappings)
# Progress: 10590/67487
# Progress: 10600/67487
#   ✓ Progress saved (10600 mappings)
# Progress: 10610/67487
# Progress: 10620/67487
#   ✓ Progress saved (10620 mappings)
# Progress: 10630/67487
# Progress: 10640/67487
#   ✓ Progress saved (10640 mappings)
# Progress: 10650/67487
# Progress: 10660/67487
#   ✓ Progress saved (10660 mappings)
# Progress: 10670/67487
# Progress: 10680/67487
#   ✓ Progress saved (10680 mappings)
# Progress: 10690/67487
# Progress: 10700/67487
#   ✓ Progress saved (10700 mappings)
# Progress: 10710/67487
# Progress: 10720/67487
#   ✓ Progress saved (10720 mappings)
# Progress: 10730/67487
# Progress: 10740/67487
#   ✓ Progress saved (10740 mappings)
# Progress: 10750/67487
# Progress: 10760/67487
#   ✓ Progress saved (10760 mappings)
# Progress: 10770/67487
# Progress: 10780/67487
#   ✓ Progress saved (10780 mappings)
# Progress: 10790/67487
# Progress: 10800/67487
#   ✓ Progress saved (10800 mappings)
# Progress: 10810/67487
# Progress: 10820/67487
#   ✓ Progress saved (10820 mappings)
# Progress: 10830/67487
# Progress: 10840/67487
#   ✓ Progress saved (10840 mappings)
# Progress: 10850/67487
# Progress: 10860/67487
#   ✓ Progress saved (10860 mappings)
# Progress: 10870/67487
# Progress: 10880/67487
#   ✓ Progress saved (10880 mappings)
# Progress: 10890/67487
# Progress: 10900/67487
#   ✓ Progress saved (10900 mappings)
# Progress: 10910/67487
# Progress: 10920/67487
#   ✓ Progress saved (10920 mappings)
# Progress: 10930/67487
# Progress: 10940/67487
#   ✓ Progress saved (10940 mappings)
# Progress: 10950/67487
# Progress: 10960/67487
#   ✓ Progress saved (10960 mappings)
# Progress: 10970/67487
# Progress: 10980/67487
#   ✓ Progress saved (10980 mappings)
# Progress: 10990/67487
# Progress: 11000/67487
#   ✓ Progress saved (11000 mappings)
# Progress: 11010/67487
# Progress: 11020/67487
#   ✓ Progress saved (11020 mappings)
# Progress: 11030/67487
# Progress: 11040/67487
#   ✓ Progress saved (11040 mappings)
# Progress: 11050/67487
# Progress: 11060/67487
#   ✓ Progress saved (11060 mappings)
# Progress: 11070/67487
# Progress: 11080/67487
#   ✓ Progress saved (11080 mappings)
# Progress: 11090/67487
# Progress: 11100/67487
#   ✓ Progress saved (11100 mappings)
# Progress: 11110/67487
# Progress: 11120/67487
#   ✓ Progress saved (11120 mappings)
# Progress: 11130/67487
# Progress: 11140/67487
#   ✓ Progress saved (11140 mappings)
# Progress: 11150/67487
# Progress: 11160/67487
#   ✓ Progress saved (11160 mappings)
# Progress: 11170/67487
# Progress: 11180/67487
#   ✓ Progress saved (11180 mappings)
# Progress: 11190/67487
# Progress: 11200/67487
#   ✓ Progress saved (11200 mappings)
# Progress: 11210/67487
# Progress: 11220/67487
#   ✓ Progress saved (11220 mappings)
# Progress: 11230/67487
# Progress: 11240/67487
#   ✓ Progress saved (11240 mappings)
# Progress: 11250/67487
# Progress: 11260/67487
#   ✓ Progress saved (11260 mappings)
# Progress: 11270/67487
# Progress: 11280/67487
#   ✓ Progress saved (11280 mappings)
# Progress: 11290/67487
# Progress: 11300/67487
#   ✓ Progress saved (11300 mappings)
# Progress: 11310/67487
# Progress: 11320/67487
#   ✓ Progress saved (11320 mappings)
# Progress: 11330/67487
# Progress: 11340/67487
#   ✓ Progress saved (11340 mappings)
# Progress: 11350/67487
# Progress: 11360/67487
#   ✓ Progress saved (11360 mappings)
# Progress: 11370/67487
# Progress: 11380/67487
#   ✓ Progress saved (11380 mappings)
# Progress: 11390/67487
# Progress: 11400/67487
#   ✓ Progress saved (11400 mappings)
# Progress: 11410/67487
# Progress: 11420/67487
#   ✓ Progress saved (11420 mappings)
# Progress: 11430/67487
# Progress: 11440/67487
#   ✓ Progress saved (11440 mappings)
# Progress: 11450/67487
# Progress: 11460/67487
#   ✓ Progress saved (11460 mappings)
# Progress: 11470/67487
# Progress: 11480/67487
#   ✓ Progress saved (11480 mappings)
# Progress: 11490/67487
# Progress: 11500/67487
#   ✓ Progress saved (11500 mappings)
# Progress: 11510/67487
# Progress: 11520/67487
#   ✓ Progress saved (11520 mappings)
# Progress: 11530/67487
# Progress: 11540/67487
#   ✓ Progress saved (11540 mappings)
# Progress: 11550/67487
# Progress: 11560/67487
#   ✓ Progress saved (11560 mappings)
# Progress: 11570/67487
# Progress: 11580/67487
#   ✓ Progress saved (11580 mappings)
# Progress: 11590/67487
# Progress: 11600/67487
#   ✓ Progress saved (11600 mappings)
# Progress: 11610/67487
# Progress: 11620/67487
#   ✓ Progress saved (11620 mappings)
# Progress: 11630/67487
# Progress: 11640/67487
# ...
# Progress: 14110/67487
# Progress: 14120/67487
#   ✓ Progress saved (14120 mappings)
# Progress: 14130/67487
# Progress: 14140/67487
#   ✓ Progress saved (14140 mappings)
# Progress: 14150/67487
# Progress: 14160/67487
#   ✓ Progress saved (14160 mappings)
# Progress: 14170/67487
# Progress: 14180/67487
#   ✓ Progress saved (14180 mappings)
# Progress: 14190/67487
# Progress: 14200/67487
#   ✓ Progress saved (14200 mappings)
# Progress: 14210/67487
# Progress: 14220/67487
#   ✓ Progress saved (14220 mappings)
# Progress: 14230/67487
# Progress: 14240/67487
#   ✓ Progress saved (14240 mappings)
# Progress: 14250/67487
# Progress: 14260/67487
#   ✓ Progress saved (14260 mappings)
# Progress: 14270/67487
# Progress: 14280/67487
#   ✓ Progress saved (14280 mappings)
# Progress: 14290/67487
# Progress: 14300/67487
#   ✓ Progress saved (14300 mappings)
# Progress: 14310/67487
# Progress: 14320/67487
#   ✓ Progress saved (14320 mappings)
# Progress: 14330/67487
# Progress: 14340/67487
#   ✓ Progress saved (14340 mappings)
# Progress: 14350/67487
# Progress: 14360/67487
#   ✓ Progress saved (14360 mappings)
# Progress: 14370/67487
# Progress: 14380/67487
#   ✓ Progress saved (14380 mappings)
# Progress: 14390/67487
# Progress: 14400/67487
#   ✓ Progress saved (14400 mappings)
# Progress: 14410/67487
# Progress: 14420/67487
#   ✓ Progress saved (14420 mappings)
# Progress: 14430/67487
# Progress: 14440/67487
#   ✓ Progress saved (14440 mappings)
# Progress: 14450/67487
# Progress: 14460/67487
#   ✓ Progress saved (14460 mappings)
# Progress: 14470/67487
# Progress: 14480/67487
#   ✓ Progress saved (14480 mappings)
# Progress: 14490/67487
# Progress: 14500/67487
#   ✓ Progress saved (14500 mappings)
# Progress: 14510/67487
# Progress: 14520/67487
#   ✓ Progress saved (14520 mappings)
# Progress: 14530/67487
# Progress: 14540/67487
#   ✓ Progress saved (14540 mappings)
# Progress: 14550/67487
# Progress: 14560/67487
#   ✓ Progress saved (14560 mappings)
# Progress: 14570/67487
# Progress: 14580/67487
#   ✓ Progress saved (14580 mappings)
# Progress: 14590/67487
# Progress: 14600/67487
#   ✓ Progress saved (14600 mappings)
# Progress: 14610/67487
# Progress: 14620/67487
#   ✓ Progress saved (14620 mappings)
# Progress: 14630/67487
# Progress: 14640/67487
#   ✓ Progress saved (14640 mappings)
# Progress: 14650/67487
# Progress: 14660/67487
#   ✓ Progress saved (14660 mappings)
# Progress: 14670/67487
# Progress: 14680/67487
#   ✓ Progress saved (14680 mappings)
# Progress: 14690/67487
# Progress: 14700/67487
#   ✓ Progress saved (14700 mappings)
# Progress: 14710/67487
# Progress: 14720/67487
#   ✓ Progress saved (14720 mappings)
# Progress: 14730/67487
# Progress: 14740/67487
#   ✓ Progress saved (14740 mappings)
# Progress: 14750/67487
# Progress: 14760/67487
#   ✓ Progress saved (14760 mappings)
# Progress: 14770/67487
# Progress: 14780/67487
#   ✓ Progress saved (14780 mappings)
# Progress: 14790/67487
# Progress: 14800/67487
#   ✓ Progress saved (14800 mappings)
# Progress: 14810/67487
# Progress: 14820/67487
#   ✓ Progress saved (14820 mappings)
# Progress: 14830/67487
# Progress: 14840/67487
#   ✓ Progress saved (14840 mappings)
# Progress: 14850/67487
# Progress: 14860/67487
#   ✓ Progress saved (14860 mappings)
# Progress: 14870/67487
# Progress: 14880/67487
#   ✓ Progress saved (14880 mappings)
# Progress: 14890/67487
# Progress: 14900/67487
#   ✓ Progress saved (14900 mappings)
# Progress: 14910/67487
# Progress: 14920/67487
#   ✓ Progress saved (14920 mappings)
# Progress: 14930/67487
# Progress: 14940/67487
#   ✓ Progress saved (14940 mappings)
# Progress: 14950/67487
# Progress: 14960/67487
#   ✓ Progress saved (14960 mappings)
# Progress: 14970/67487
# Progress: 14980/67487
#   ✓ Progress saved (14980 mappings)
# Progress: 14990/67487
# Progress: 15000/67487
#   ✓ Progress saved (15000 mappings)
# Progress: 15010/67487
# Progress: 15020/67487
#   ✓ Progress saved (15020 mappings)
# Progress: 15030/67487
# Progress: 15040/67487
#   ✓ Progress saved (15040 mappings)
# Progress: 15050/67487
# Progress: 15060/67487
#   ✓ Progress saved (15060 mappings)
# Progress: 15070/67487
# Progress: 15080/67487
#   ✓ Progress saved (15080 mappings)
# Progress: 15090/67487
# Progress: 15100/67487
#   ✓ Progress saved (15100 mappings)
# Progress: 15110/67487
# Progress: 15120/67487
#   ✓ Progress saved (15120 mappings)
# Progress: 15130/67487
# Progress: 15140/67487
#   ✓ Progress saved (15140 mappings)
# Progress: 15150/67487
# Progress: 15160/67487
#   ✓ Progress saved (15160 mappings)
# Progress: 15170/67487
# Progress: 15180/67487
#   ✓ Progress saved (15180 mappings)
# Progress: 15190/67487
# Progress: 15200/67487
#   ✓ Progress saved (15200 mappings)
# Progress: 15210/67487
# Progress: 15220/67487
#   ✓ Progress saved (15220 mappings)
# Progress: 15230/67487
# Progress: 15240/67487
#   ✓ Progress saved (15240 mappings)
# Progress: 15250/67487
# Progress: 15260/67487
#   ✓ Progress saved (15260 mappings)
# Progress: 15270/67487
# Progress: 15280/67487
#   ✓ Progress saved (15280 mappings)
# Progress: 15290/67487
# Progress: 15300/67487
#   ✓ Progress saved (15300 mappings)
# Progress: 15310/67487
# Progress: 15320/67487
#   ✓ Progress saved (15320 mappings)
# Progress: 15330/67487
# Progress: 15340/67487
#   ✓ Progress saved (15340 mappings)
# Progress: 15350/67487
# Progress: 15360/67487
#   ✓ Progress saved (15360 mappings)
# Progress: 15370/67487
# Progress: 15380/67487
#   ✓ Progress saved (15380 mappings)
# Progress: 15390/67487
# Progress: 15400/67487
#   ✓ Progress saved (15400 mappings)
# Progress: 15410/67487
# Progress: 15420/67487
#   ✓ Progress saved (15420 mappings)
# Progress: 15430/67487
# Progress: 15440/67487
#   ✓ Progress saved (15440 mappings)
# Progress: 15450/67487
# Progress: 15460/67487
#   ✓ Progress saved (15460 mappings)
# Progress: 15470/67487
# Progress: 15480/67487
#   ✓ Progress saved (15480 mappings)
# Progress: 15490/67487
# Progress: 15500/67487
#   ✓ Progress saved (15500 mappings)
# Progress: 15510/67487
# Progress: 15520/67487
#   ✓ Progress saved (15520 mappings)
# Progress: 15530/67487
# Progress: 15540/67487
#   ✓ Progress saved (15540 mappings)
# Progress: 15550/67487
# Progress: 15560/67487
#   ✓ Progress saved (15560 mappings)
# Progress: 15570/67487
# Progress: 15580/67487
#   ✓ Progress saved (15580 mappings)
# Progress: 15590/67487
# Progress: 15600/67487
#   ✓ Progress saved (15600 mappings)
# Progress: 15610/67487
# Progress: 15620/67487
#   ✓ Progress saved (15620 mappings)
# Progress: 15630/67487
# Progress: 15640/67487
#   ✓ Progress saved (15640 mappings)
# Progress: 15650/67487
# Progress: 15660/67487
#   ✓ Progress saved (15660 mappings)
# Progress: 15670/67487
# Progress: 15680/67487
#   ✓ Progress saved (15680 mappings)
# Progress: 15690/67487
# Progress: 15700/67487
#   ✓ Progress saved (15700 mappings)
# Progress: 15710/67487
# Progress: 15720/67487
#   ✓ Progress saved (15720 mappings)
# Progress: 15730/67487
# Progress: 15740/67487
#   ✓ Progress saved (15740 mappings)
# Progress: 15750/67487
# Progress: 15760/67487
#   ✓ Progress saved (15760 mappings)
# Progress: 15770/67487
# Progress: 15780/67487
#   ✓ Progress saved (15780 mappings)
# Progress: 15790/67487
# Progress: 15800/67487
#   ✓ Progress saved (15800 mappings)
# Progress: 15810/67487
# Progress: 15820/67487
#   ✓ Progress saved (15820 mappings)
# Progress: 15830/67487
# Progress: 15840/67487
#   ✓ Progress saved (15840 mappings)
# Progress: 15850/67487
# Progress: 15860/67487
#   ✓ Progress saved (15860 mappings)
# Progress: 15870/67487
# Progress: 15880/67487
#   ✓ Progress saved (15880 mappings)
# Progress: 15890/67487
# Progress: 15900/67487
#   ✓ Progress saved (15900 mappings)
# Progress: 15910/67487
# Progress: 15920/67487
#   ✓ Progress saved (15920 mappings)
# Progress: 15930/67487
# Progress: 15940/67487
#   ✓ Progress saved (15940 mappings)
# Progress: 15950/67487
# Progress: 15960/67487
#   ✓ Progress saved (15960 mappings)
# Progress: 15970/67487
# Progress: 15980/67487
#   ✓ Progress saved (15980 mappings)
# Progress: 15990/67487
# Progress: 16000/67487
#   ✓ Progress saved (16000 mappings)
# Progress: 16010/67487
# Progress: 16020/67487
#   ✓ Progress saved (16020 mappings)
# Progress: 16030/67487
# Progress: 16040/67487
#   ✓ Progress saved (16040 mappings)
# Progress: 16050/67487
# Progress: 16060/67487
#   ✓ Progress saved (16060 mappings)
# Progress: 16070/67487
# Progress: 16080/67487
#   ✓ Progress saved (16080 mappings)
# Progress: 16090/67487
# Progress: 16100/67487
#   ✓ Progress saved (16100 mappings)
# Progress: 16110/67487
# Progress: 16120/67487
#   ✓ Progress saved (16120 mappings)
# Progress: 16130/67487
# Progress: 16140/67487
#   ✓ Progress saved (16140 mappings)
# Progress: 16150/67487
# Progress: 16160/67487
#   ✓ Progress saved (16160 mappings)
# Progress: 16170/67487
# Progress: 16180/67487
#   ✓ Progress saved (16180 mappings)
# Progress: 16190/67487
# Progress: 16200/67487
#   ✓ Progress saved (16200 mappings)
# Progress: 16210/67487
# Progress: 16220/67487
#   ✓ Progress saved (16220 mappings)
# Progress: 16230/67487
# Progress: 16240/67487
#   ✓ Progress saved (16240 mappings)
# Progress: 16250/67487
# Progress: 16260/67487
#   ✓ Progress saved (16260 mappings)
# Progress: 16270/67487
# Progress: 16280/67487
#   ✓ Progress saved (16280 mappings)
# Progress: 16290/67487
# Progress: 16300/67487
#   ✓ Progress saved (16300 mappings)
# Progress: 16310/67487
# Progress: 16320/67487
#   ✓ Progress saved (16320 mappings)
# Progress: 16330/67487
# Progress: 16340/67487
#   ✓ Progress saved (16340 mappings)
# Progress: 16350/67487
# Progress: 16360/67487
#   ✓ Progress saved (16360 mappings)
# Progress: 16370/67487
# Progress: 16380/67487
#   ✓ Progress saved (16380 mappings)
# Progress: 16390/67487
# Progress: 16400/67487
#   ✓ Progress saved (16400 mappings)
# Progress: 16410/67487
# Progress: 16420/67487
#   ✓ Progress saved (16420 mappings)
# Progress: 16430/67487
# Progress: 16440/67487
#   ✓ Progress saved (16440 mappings)
# Progress: 16450/67487
# Progress: 16460/67487
#   ✓ Progress saved (16460 mappings)
# Progress: 16470/67487
# Progress: 16480/67487
#   ✓ Progress saved (16480 mappings)
# Progress: 16490/67487
# Progress: 16500/67487
#   ✓ Progress saved (16500 mappings)
# Progress: 16510/67487
# Progress: 16520/67487
#   ✓ Progress saved (16520 mappings)
# Progress: 16530/67487
# Progress: 16540/67487
#   ✓ Progress saved (16540 mappings)
# Progress: 16550/67487
# Progress: 16560/67487
#   ✓ Progress saved (16560 mappings)
# Progress: 16570/67487
# Progress: 16580/67487
#   ✓ Progress saved (16580 mappings)
# Progress: 16590/67487
# Progress: 16600/67487
#   ✓ Progress saved (16600 mappings)
# Progress: 16610/67487
# Progress: 16620/67487
#   ✓ Progress saved (16620 mappings)
# Progress: 16630/67487
# Progress: 16640/67487
#   ✓ Progress saved (16640 mappings)
# Progress: 16650/67487
# Progress: 16660/67487
#   ✓ Progress saved (16660 mappings)
# Progress: 16670/67487
# Progress: 16680/67487
#   ✓ Progress saved (16680 mappings)
# Progress: 16690/67487
# Progress: 16700/67487
#   ✓ Progress saved (16700 mappings)
# Progress: 16710/67487
# Progress: 16720/67487
#   ✓ Progress saved (16720 mappings)
# Progress: 16730/67487
# Progress: 16740/67487
#   ✓ Progress saved (16740 mappings)
# Progress: 16750/67487
# Progress: 16760/67487
#   ✓ Progress saved (16760 mappings)
# Progress: 16770/67487
# Progress: 16780/67487
#   ✓ Progress saved (16780 mappings)
# Progress: 16790/67487
# Progress: 16800/67487
#   ✓ Progress saved (16800 mappings)
# Progress: 16810/67487
# Progress: 16820/67487
#   ✓ Progress saved (16820 mappings)
# Progress: 16830/67487
# Progress: 16840/67487
#   ✓ Progress saved (16840 mappings)
# Progress: 16850/67487
# Progress: 16860/67487
#   ✓ Progress saved (16860 mappings)
# Progress: 16870/67487
# Progress: 16880/67487
#   ✓ Progress saved (16880 mappings)
# Progress: 16890/67487
# Progress: 16900/67487
#   ✓ Progress saved (16900 mappings)
# Progress: 16910/67487
# Progress: 16920/67487
#   ✓ Progress saved (16920 mappings)
# Progress: 16930/67487
# Progress: 16940/67487
#   ✓ Progress saved (16940 mappings)
# Progress: 16950/67487
# Progress: 16960/67487
#   ✓ Progress saved (16960 mappings)
# Progress: 16970/67487
# Progress: 16980/67487
#   ✓ Progress saved (16980 mappings)
# Progress: 16990/67487
# Progress: 17000/67487
#   ✓ Progress saved (17000 mappings)
# Progress: 17010/67487
# Progress: 17020/67487
#   ✓ Progress saved (17020 mappings)
# Progress: 17030/67487
# Progress: 17040/67487
#   ✓ Progress saved (17040 mappings)
# Progress: 17050/67487
# Progress: 17060/67487
#   ✓ Progress saved (17060 mappings)
# Progress: 17070/67487
# Progress: 17080/67487
#   ✓ Progress saved (17080 mappings)
# Progress: 17090/67487
# Progress: 17100/67487
#   ✓ Progress saved (17100 mappings)
# Progress: 17110/67487
# Progress: 17120/67487
#   ✓ Progress saved (17120 mappings)
# Progress: 17130/67487
# Progress: 17140/67487
#   ✓ Progress saved (17140 mappings)
# Progress: 17150/67487
# Progress: 17160/67487
#   ✓ Progress saved (17160 mappings)
# Progress: 17170/67487
# Progress: 17180/67487
#   ✓ Progress saved (17180 mappings)
# Progress: 17190/67487
# Progress: 17200/67487
#   ✓ Progress saved (17200 mappings)
# Progress: 17210/67487
# Progress: 17220/67487
#   ✓ Progress saved (17220 mappings)
# Progress: 17230/67487
# Progress: 17240/67487
#   ✓ Progress saved (17240 mappings)
# Progress: 17250/67487
# Progress: 17260/67487
#   ✓ Progress saved (17260 mappings)
# Progress: 17270/67487
# Progress: 17280/67487
#   ✓ Progress saved (17280 mappings)
# Progress: 17290/67487
# Progress: 17300/67487
#   ✓ Progress saved (17300 mappings)
# Progress: 17310/67487
# Progress: 17320/67487
#   ✓ Progress saved (17320 mappings)
# Progress: 17330/67487
# Progress: 17340/67487
#   ✓ Progress saved (17340 mappings)
# Progress: 17350/67487
# Progress: 17360/67487
#   ✓ Progress saved (17360 mappings)
# Progress: 17370/67487
# Progress: 17380/67487
#   ✓ Progress saved (17380 mappings)
# Progress: 17390/67487
# Progress: 17400/67487
#   ✓ Progress saved (17400 mappings)
# Progress: 17410/67487
# Progress: 17420/67487
#   ✓ Progress saved (17420 mappings)
# Progress: 17430/67487
# Progress: 17440/67487
#   ✓ Progress saved (17440 mappings)
# Progress: 17450/67487
# Progress: 17460/67487
#   ✓ Progress saved (17460 mappings)
# Progress: 17470/67487
# Progress: 17480/67487
#   ✓ Progress saved (17480 mappings)
# Progress: 17490/67487
# Progress: 17500/67487
#   ✓ Progress saved (17500 mappings)
# Progress: 17510/67487
# Progress: 17520/67487
#   ✓ Progress saved (17520 mappings)
# Progress: 17530/67487
# Progress: 17540/67487
#   ✓ Progress saved (17540 mappings)
# Progress: 17550/67487
# Progress: 17560/67487
#   ✓ Progress saved (17560 mappings)
# Progress: 17570/67487
# Progress: 17580/67487
#   ✓ Progress saved (17580 mappings)
# Progress: 17590/67487
# Progress: 17600/67487
#   ✓ Progress saved (17600 mappings)
# Progress: 17610/67487
# Progress: 17620/67487
#   ✓ Progress saved (17620 mappings)
# Progress: 17630/67487
# Progress: 17640/67487
#   ✓ Progress saved (17640 mappings)
# Progress: 17650/67487
# Progress: 17660/67487
#   ✓ Progress saved (17660 mappings)
# Progress: 17670/67487
# Progress: 17680/67487
#   ✓ Progress saved (17680 mappings)
# Progress: 17690/67487
# Progress: 17700/67487
#   ✓ Progress saved (17700 mappings)
# Progress: 17710/67487
# Progress: 17720/67487
#   ✓ Progress saved (17720 mappings)
# Progress: 17730/67487
# Progress: 17740/67487
#   ✓ Progress saved (17740 mappings)
# Progress: 17750/67487
# Progress: 17760/67487
#   ✓ Progress saved (17760 mappings)
# Progress: 17770/67487
# Progress: 17780/67487
#   ✓ Progress saved (17780 mappings)
# Progress: 17790/67487
# Progress: 17800/67487
#   ✓ Progress saved (17800 mappings)
# Progress: 17810/67487
# Progress: 17820/67487
#   ✓ Progress saved (17820 mappings)
# Progress: 17830/67487
# Progress: 17840/67487
#   ✓ Progress saved (17840 mappings)
# Progress: 17850/67487
# Progress: 17860/67487
#   ✓ Progress saved (17860 mappings)
# Progress: 17870/67487
# Progress: 17880/67487
#   ✓ Progress saved (17880 mappings)
# Progress: 17890/67487
# Progress: 17900/67487
#   ✓ Progress saved (17900 mappings)
# Progress: 17910/67487
# Progress: 17920/67487
#   ✓ Progress saved (17920 mappings)
# Progress: 17930/67487
# Progress: 17940/67487
#   ✓ Progress saved (17940 mappings)
# Progress: 17950/67487
# Progress: 17960/67487
#   ✓ Progress saved (17960 mappings)
# Progress: 17970/67487
# Progress: 17980/67487
#   ✓ Progress saved (17980 mappings)
# Progress: 17990/67487
# Progress: 18000/67487
#   ✓ Progress saved (18000 mappings)
# Progress: 18010/67487
# Progress: 18020/67487
#   ✓ Progress saved (18020 mappings)
# Progress: 18030/67487
# Progress: 18040/67487
#   ✓ Progress saved (18040 mappings)
# Progress: 18050/67487
# Progress: 18060/67487
#   ✓ Progress saved (18060 mappings)
# Progress: 18070/67487
# Progress: 18080/67487
#   ✓ Progress saved (18080 mappings)
# Progress: 18090/67487
# Progress: 18100/67487
#   ✓ Progress saved (18100 mappings)

# %% [markdown]
# ## Add UniProt IDs to DataFrame

# %%
# Add chain-specific UniProt IDs to the dataframe
df['pdb_chain_key'] = df['pdb_id'] + '_' + df['receptor_chain']
df['uniprot_ids'] = df['pdb_chain_key'].map(pdb_chain_to_uniprot_mapping)

# Convert list to string for easier viewing
df['uniprot_ids_str'] = df['uniprot_ids'].apply(lambda x: ', '.join(x) if x else '')

print("Sample data with chain-specific UniProt IDs:")
df[['system_id', 'pdb_id', 'receptor_chain', 'uniprot_ids_str']].head(20)

# %%
# Summary statistics
print("Summary Statistics:")
print(f"Total systems: {len(df)}")
print(f"Systems with UniProt IDs: {df['uniprot_ids_str'].astype(bool).sum()}")
print(f"Systems without UniProt IDs: {(~df['uniprot_ids_str'].astype(bool)).sum()}")
print(f"\nUnique PDB IDs: {df['pdb_id'].nunique()}")
print(f"Unique PDB + Chain combinations: {len(unique_pdb_chain_combos)}")
print(f"Unique UniProt IDs found: {len(set([uid for uids in df['uniprot_ids'].dropna() for uid in uids if uids]))}")

# Show some examples where the same PDB has different chains with different UniProt IDs
print("\n" + "="*60)
print("Example: Same PDB, Different Chains → Different UniProt IDs")
print("="*60)
sample_pdb = df[df['uniprot_ids_str'] != '']['pdb_id'].iloc[0]
same_pdb_different_chains = df[df['pdb_id'] == sample_pdb][['pdb_id', 'receptor_chain', 'uniprot_ids_str']].drop_duplicates()
print(same_pdb_different_chains.head(10))

# %% [markdown]
# ## Save Results

# %%
# Save the enhanced dataframe
output_file = 'data/annotation_table_with_uniprot.parquet'
df.to_parquet(output_file)
print(f"✓ Saved to: {output_file}")

# Save the PDB+Chain to UniProt mapping as JSON
import json
mapping_file = 'data/pdb_chain_to_uniprot_mapping.json'
with open(mapping_file, 'w') as f:
    json.dump(pdb_chain_to_uniprot_mapping, f, indent=2)
print(f"✓ Saved chain-specific mapping to: {mapping_file}")

# Also save a summary CSV for quick reference
summary_df = unique_pdb_chain_combos.copy()
summary_df['pdb_chain_key'] = summary_df['pdb_id'] + '_' + summary_df['receptor_chain']
summary_df['uniprot_ids'] = summary_df['pdb_chain_key'].map(pdb_chain_to_uniprot_mapping)
summary_df['uniprot_ids_str'] = summary_df['uniprot_ids'].apply(lambda x: ', '.join(x) if x else '')
summary_csv = 'data/pdb_chain_uniprot_summary.csv'
summary_df[['pdb_id', 'receptor_chain', 'uniprot_ids_str']].to_csv(summary_csv, index=False)
print(f"✓ Saved summary to: {summary_csv}")

# %%
# Display final summary
print("\n" + "="*70)
print("FINAL SUMMARY - Chain-Specific UniProt Mapping")
print("="*70)
print(f"Total PLINDER systems: {len(df)}")
print(f"Unique PDB IDs: {df['pdb_id'].nunique()}")
print(f"Unique PDB + Chain combinations: {len(unique_pdb_chain_combos)}")
print(f"Combinations with UniProt mapping: {sum(1 for uniprots in pdb_chain_to_uniprot_mapping.values() if uniprots)}")
print(f"Total unique UniProt IDs found: {len(set([uid for uids in df['uniprot_ids'].dropna() for uid in uids if uids]))}")

print("\n" + "="*70)
print("WHY CHAIN-SPECIFIC MAPPING MATTERS FOR ChEMBL")
print("="*70)
print("✓ Each PLINDER system specifies a receptor CHAIN")
print("✓ Different chains in the same PDB can be different proteins")
print("✓ Each protein (chain) has its own UniProt ID")
print("✓ ChEMBL data is linked to specific UniProt IDs")
print("✓ Therefore: Must map PDB+Chain → UniProt, not just PDB → UniProt")

print("\nOutput files:")
print(f"  1. {output_file}")
print(f"  2. {mapping_file}")
print(f"  3. {summary_csv}")

print("\n" + "="*70)
print("NEXT STEPS FOR ChEMBL RETRIEVAL")
print("="*70)
print("Use the 'uniprot_ids' column (chain-specific) to query ChEMBL,")
print("not just the PDB ID. This ensures you get activities for the")
print("correct protein target that corresponds to your receptor chain.")
