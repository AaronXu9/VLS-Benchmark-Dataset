# %%
import os
import glob
import pandas as pd
import tqdm 

def load_all_chembl_activities(base_dir="/mnt/katritch_lab2/aoxu/VLS_benchmark/chembl_affinity/"):
    
    paths = glob.glob(f"{base_dir}/uniprot_*/*_chembl_activities_filtered.parquet")

    dfs = []
    #print(len(paths))
    for path in tqdm.tqdm(paths[:]):
        uniprot_dir = os.path.basename(os.path.dirname(path))   # e.g. "uniprot_P60842"
        uniprot_id = uniprot_dir.split("_", 1)[1]               # "P60842"

        df = pd.read_parquet(path)
        df["uniprot_id"] = uniprot_id
        dfs.append(df)

    if not dfs:
        return pd.DataFrame()

    return pd.concat(dfs, ignore_index=True)

df_all = load_all_chembl_activities()
# Out:
# 100%|██████████| 837/837 [00:05<00:00, 141.25it/s]

# %%
contained_uniprotid = (df_all['uniprot_id'].unique().tolist())

# %% [markdown]
# # Pdbids

# %%
uniprot_pdbfiles_df = pd.read_csv(
    "pdb_chain_uniprot.tsv",
    sep="\t",
    comment="#",
    na_values=["None"],
    compression="infer",
    dtype={
        "PDB": "string",
        "CHAIN": "string",
        "SP_PRIMARY": "string",
    },
)
uniprot_pdbfiles_df = uniprot_pdbfiles_df.loc[uniprot_pdbfiles_df['SP_PRIMARY'].isin(contained_uniprotid)]
# Out:
# /tmp/ipykernel_40898/3654004186.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   uniprot_pdbfiles_df = pd.read_csv(

# %%
uniprot_pdbfiles_df.columns
# Out:
# Index(['PDB', 'CHAIN', 'SP_PRIMARY', 'RES_BEG', 'RES_END', 'PDB_BEG',
#        'PDB_END', 'SP_BEG', 'SP_END'],
#       dtype='object')

# %% [markdown]
# # Mapping the uniprotid to pdbid

# %%
# assuming df has columns: 'PDB', 'CHAIN', 'SP_PRIMARY'

# optional: normalize IDs
uniprot_pdbfiles_df["PDB"] = uniprot_pdbfiles_df["PDB"].str.upper()
uniprot_pdbfiles_df["SP_PRIMARY"] = uniprot_pdbfiles_df["SP_PRIMARY"].str.upper()

uniprot_to_pdb = (
    uniprot_pdbfiles_df.dropna(subset=["SP_PRIMARY", "PDB"])
      .groupby("SP_PRIMARY")["PDB"]
      .apply(lambda s: set(s))
      .to_dict()
)

# %% [markdown]
# # CCD and smi

# %%
ccd_smi_df = pd.read_csv(
    "Components-smiles-stereo-oe.smi",
    sep="\t",
    names = ['Smiles', "CID", "name"]
)

# %%
dict_ccd_smi = dict(zip(ccd_smi_df["CID"], ccd_smi_df["Smiles"]))

# %% [markdown]
# # ccd to list of pdbid

# %%
ccd_pdbid_df =  pd.read_csv(
    "interacting_chains_with_ligand_functions.tsv",
    sep="\t",

)

# %%
dict_pdbid_ccd = (
    ccd_pdbid_df.dropna(subset=["PDBID", "LigandID"])
      .groupby("PDBID")["LigandID"]
      .apply(lambda s: set(s))
      .to_dict()
)
dict_pdbid_ccd = {k.upper():v for k,v in dict_pdbid_ccd.items()}

# %% [markdown]
# # Clustering the active ligands by similarity to pdb ligand
# - [ ] within each uniprotid get all the actives and all CCD smiles in corresponding pdbid
# - [ ] if similarity < 0.1, 0.3, 0.5,0.7,0.9 we reject the ligand from consideration.

# %%
import itertools
import tqdm
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem import AllChem, rdFingerprintGenerator
from rdkit import DataStructs

morgan_gen = rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=2048)

threshold_distance = 0.3  # you choose

uniprot_min_dist_dict = {}        # {uniprot_id: {smi_active: min_distance}}


for i_uniprotid, i_list_pdbid in tqdm.tqdm(uniprot_to_pdb.items()):


    i_ccd_among_all_contained_pdbid = []
    for i_pdbid in i_list_pdbid:
        try:
            i_ccd_among_all_contained_pdbid.append(dict_pdbid_ccd[i_pdbid])
        except KeyError:
            pass
            #print(f"{i_pdbid} not exist dict_pdbid_ccd")
    i_ccd_among_all_contained_pdbid = list(itertools.chain.from_iterable(i_ccd_among_all_contained_pdbid))



    i_smi_among_all_contained_pdbid = []
    for i_ccd in i_ccd_among_all_contained_pdbid:
        try:
            i_smi_among_all_contained_pdbid.append(dict_ccd_smi[i_ccd])
        except KeyError:
            pass
            #print(f"{i_ccd} not exist in dict_ccd_smi")



    i_actives_in_uniprotid_df = df_all.loc[df_all['uniprot_id'] == i_uniprotid]
    i_smi_actives = i_actives_in_uniprotid_df['canonical_smiles'].unique().tolist()


    # RDKit mols
    i_rdmol_from_pdb = [Chem.MolFromSmiles(s) for s in i_smi_among_all_contained_pdbid]
    i_rdmol_from_actives = [Chem.MolFromSmiles(s) for s in i_smi_actives]

    # filter out failed parses, keep aligned lists
    pdb_smi_valid = []
    pdb_mols_valid = []
    for s, m in zip(i_smi_among_all_contained_pdbid, i_rdmol_from_pdb):
        if m is not None:
            pdb_smi_valid.append(s)
            pdb_mols_valid.append(m)

    act_smi_valid = []
    act_mols_valid = []
    for s, m in zip(i_smi_actives, i_rdmol_from_actives):
        if m is not None:
            act_smi_valid.append(s)
            act_mols_valid.append(m)

    if not pdb_mols_valid or not act_mols_valid:
        uniprot_min_dist_dict[i_uniprotid] = {}
        continue

    # ECFP fingerprints
    pdb_fps = [morgan_gen.GetFingerprint(m) for m in pdb_mols_valid]
    act_fps = [morgan_gen.GetFingerprint(m) for m in act_mols_valid]

    # : min Tanimoto distance per active
    smi_to_min_dist = {}
    for smi_a, fp_a in zip(act_smi_valid, act_fps):
        sims = DataStructs.BulkTanimotoSimilarity(fp_a, pdb_fps)
        if sims:
            max_sim = max(sims)
            min_dist = 1.0 - max_sim
        else:
            min_dist = 1.0  # no reference, treat as far
        smi_to_min_dist[smi_a] = min_dist

    uniprot_min_dist_dict[i_uniprotid] = smi_to_min_dist
# Out:
#   0%|          | 0/837 [00:00<?, ?it/s]
#   1%|          | 10/837 [00:00<00:50, 16.45it/s][20:10:32] Explicit valence for atom # 0 Be, 4, is greater than permitted
#   3%|▎         | 23/837 [00:01<00:59, 13.71it/s][20:10:34] Explicit valence for atom # 24 N, 4, is greater than permitted
# [20:10:34] Explicit valence for atom # 25 N, 4, is greater than permitted
#   6%|▋         | 53/837 [00:03<01:04, 12.19it/s][20:10:36] Explicit valence for atom # 54 N, 5, is greater than permitted
# [20:10:36] Explicit valence for atom # 54 N, 5, is greater than permitted
#   8%|▊         | 66/837 [00:04<00:48, 15.91it/s][20:10:37] Explicit valence for atom # 0 B, 4, is greater than permitted
#  11%|█         | 90/837 [00:06<00:39, 18.69it/s][20:10:38] Explicit valence for atom # 0 B, 6, is greater than permitted
# [20:10:38] Explicit valence for atom # 0 B, 4, is greater than permitted
#  11%|█         | 92/837 [00:06<00:44, 16.88it/s][20:10:38] Explicit valence for atom # 0 O, 2, is greater than permitted
# [20:10:38] Explicit valence for atom # 0 O, 2, is greater than permitted
#  13%|█▎        | 107/837 [00:07<00:53, 13.63it/s][20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
#  13%|█▎        | 109/837 [00:07<00:57, 12.63it/s][20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 17 O, 3, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 1 P, 6, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 1 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 1 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 36 Cl, 1, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 36 Cl, 1, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 2 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 5, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:39] Explicit valence for atom # 0 B, 4, is greater than permitted
#  14%|█▍        | 120/837 [00:08<00:40, 17.90it/s][20:10:40] Explicit valence for atom # 20 N, 5, is greater than permitted
#  15%|█▍        | 125/837 [00:08<01:17,  9.14it/s][20:10:41] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:41] Explicit valence for atom # 11 N, 4, is greater than permitted
#  16%|█▌        | 133/837 [00:09<00:57, 12.17it/s][20:10:41] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:41] Explicit valence for atom # 0 B, 4, is greater than permitted
#  16%|█▋        | 138/837 [00:09<00:47, 14.72it/s][20:10:42] Explicit valence for atom # 21 O, 2, is greater than permitted
#  20%|█▉        | 165/837 [00:11<00:56, 11.88it/s][20:10:43] Explicit valence for atom # 28 N, 4, is greater than permitted
#  25%|██▌       | 212/837 [00:14<00:28, 22.27it/s][20:10:46] Explicit valence for atom # 22 O, 3, is greater than permitted
# [20:10:46] Explicit valence for atom # 35 O, 3, is greater than permitted
# [20:10:46] Explicit valence for atom # 24 O, 3, is greater than permitted
# [20:10:46] Explicit valence for atom # 25 O, 3, is greater than permitted
# [20:10:46] Explicit valence for atom # 4 O, 5, is greater than permitted
#  29%|██▉       | 245/837 [00:15<00:30, 19.30it/s][20:10:48] Explicit valence for atom # 10 N, 4, is greater than permitted
#  33%|███▎      | 277/837 [00:17<00:35, 15.60it/s][20:10:49] Explicit valence for atom # 0 B, 4, is greater than permitted
#  34%|███▍      | 283/837 [00:18<00:37, 14.74it/s][20:10:50] Explicit valence for atom # 18 S, 7, is greater than permitted
#  39%|███▉      | 327/837 [00:21<00:31, 16.43it/s][20:10:53] Explicit valence for atom # 0 B, 4, is greater than permitted
#  42%|████▏     | 350/837 [00:23<00:46, 10.48it/s][20:10:55] Explicit valence for atom # 15 N, 4, is greater than permitted
#  44%|████▍     | 371/837 [00:24<00:39, 11.92it/s][20:10:57] Explicit valence for atom # 3 N, 4, is greater than permitted
#  46%|████▋     | 389/837 [00:25<00:28, 15.86it/s][20:10:58] Explicit valence for atom # 34 O, 4, is greater than permitted
#  47%|████▋     | 396/837 [00:26<00:24, 18.05it/s][20:10:58] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:10:58] Explicit valence for atom # 54 N, 5, is greater than permitted
# [20:10:58] Explicit valence for atom # 54 N, 5, is greater than permitted
#  53%|█████▎    | 444/837 [00:29<00:20, 19.13it/s][20:11:02] Explicit valence for atom # 41 O, 3, is greater than permitted
# [20:11:02] Explicit valence for atom # 25 O, 3, is greater than permitted
#  54%|█████▍    | 454/837 [00:30<00:20, 18.90it/s][20:11:02] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:11:02] Explicit valence for atom # 15 N, 4, is greater than permitted
#  55%|█████▍    | 457/837 [00:30<00:21, 17.32it/s][20:11:02] Explicit valence for atom # 15 N, 4, is greater than permitted
#  55%|█████▍    | 460/837 [00:30<00:22, 16.63it/s][20:11:03] Explicit valence for atom # 30 O, 3, is greater than permitted
# [20:11:03] Explicit valence for atom # 28 O, 3, is greater than permitted
#  62%|██████▏   | 515/837 [00:34<00:20, 15.54it/s][20:11:06] Explicit valence for atom # 28 N, 4, is greater than permitted
#  62%|██████▏   | 523/837 [00:34<00:15, 19.90it/s][20:11:07] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:11:07] Explicit valence for atom # 0 B, 4, is greater than permitted
#  65%|██████▍   | 540/837 [00:36<00:20, 14.30it/s][20:11:08] Explicit valence for atom # 0 B, 6, is greater than permitted
#  66%|██████▋   | 555/837 [00:37<00:22, 12.41it/s][20:11:09] Explicit valence for atom # 15 N, 4, is greater than permitted
#  67%|██████▋   | 557/837 [00:37<00:23, 11.79it/s][20:11:09] Explicit valence for atom # 28 N, 4, is greater than permitted
#  69%|██████▉   | 578/837 [00:39<00:15, 16.51it/s][20:11:11] Explicit valence for atom # 36 O, 3, is greater than permitted
# [20:11:11] Explicit valence for atom # 30 O, 3, is greater than permitted
#  69%|██████▉   | 581/837 [00:39<00:14, 17.86it/s][20:11:11] Explicit valence for atom # 10 N, 4, is greater than permitted
#  70%|███████   | 587/837 [00:39<00:17, 14.30it/s][20:11:12] Explicit valence for atom # 0 B, 4, is greater than permitted
#  73%|███████▎  | 608/837 [00:41<00:11, 19.16it/s][20:11:13] Explicit valence for atom # 11 N, 4, is greater than permitted
# [20:11:13] Explicit valence for atom # 11 N, 4, is greater than permitted
# [20:11:13] Explicit valence for atom # 11 N, 4, is greater than permitted
# [20:11:13] Explicit valence for atom # 11 N, 4, is greater than permitted
#  79%|███████▉  | 661/837 [00:43<00:09, 18.77it/s][20:11:15] Explicit valence for atom # 26 N, 4, is greater than permitted
#  80%|███████▉  | 669/837 [00:44<00:09, 18.19it/s][20:11:16] Explicit valence for atom # 14 N, 4, is greater than permitted
#  86%|████████▋ | 723/837 [00:46<00:05, 20.81it/s][20:11:19] Explicit valence for atom # 0 B, 4, is greater than permitted
# [20:11:19] Explicit valence for atom # 45 N, 4, is greater than permitted
#  92%|█████████▏| 772/837 [00:49<00:02, 23.45it/s][20:11:21] Explicit valence for atom # 25 N, 5, is greater than permitted
#  94%|█████████▎| 783/837 [00:49<00:01, 30.00it/s][20:11:22] Explicit valence for atom # 24 O, 3, is greater than permitted
#  97%|█████████▋| 814/837 [00:51<00:01, 14.72it/s][20:11:23] Explicit valence for atom # 21 N, 4, is greater than permitted
# 100%|██████████| 837/837 [00:53<00:00, 15.75it/s]

# %%
import pandas as pd

rows = [
    (uniprot_id, smi_active, min_dist)
    for uniprot_id, smi_dict in uniprot_min_dist_dict.items()
    for smi_active, min_dist in smi_dict.items()
]

df_uniprotid_smiactives_mindist = pd.DataFrame(rows, columns=["uniprot_id", "smi_active", "min_distance_from_pdb_ligand"])

# %%
df_uniprotid_smiactives_mindist.to_csv("/mnt/katritch_lab2/aoxu/VLS_benchmark/df_uniprotid_smiactives_mindist.csv")

# %% [markdown]
# # smi actives that is not supported by pdb structure will have large distance

# %%
df_uniprotid_smiactives_mindist.loc[df_uniprotid_smiactives_mindist["min_distance_from_pdb_ligand"] > 0.9]
# Out:
#        uniprot_id                                         smi_active  \
# 645        O00206  Cc1nn(Cc2ccccc2Cl)c(C)c1CN(C)CC(O)CCOc1cccc2[n...
# 649        O00206        COc1ccccc1OCCNCC(O)COc1cccc2[nH]c3ccccc3c12
# 651        O00206  OC(CNc1ccc(-c2ccccc2)cc1)COc1cccc2[nH]c3ccccc3c12
# 652        O00206  OC(CNc1ccc2c(c1)-c1ccccc1C2)COc1cccc2[nH]c3ccc...
# 654        O00206       OC(CNc1ccc2ccccc2c1)COc1cccc2[nH]c3ccccc3c12
# ...           ...                                                ...
# 279966     Q9Y6K1  O=C1[C@@H]2CC=CC[C@@H]2C(c2cccc(OCCCCCOc3ccc(-...
# 279967     Q9Y6K1  O=C1[C@@H]2CC=CC[C@@H]2C(c2cccc(OC/C=C\COc3ccc...
# 279968     Q9Y6K1  O=C1[C@@H]2CC=CC[C@@H]2C(c2cccc(OC/C=C/COc3ccc...
# 279969     Q9Y6K1  O=C(COc1cccc(C2=NN(C3CCCCCC3)C(=O)[C@@H]3CC=CC...
# 279970     Q9Y6K1  O=c1c2ccccc2c(-c2cccc(OCCCCOc3ccc(-c4nn[nH]n4)...
#
#         min_distance_from_pdb_ligand
# 645                         0.901235
# 649                         0.907692
# 651                         0.903226
# 652                         0.929577
# 654                         0.923077
# ...                              ...
# 279966                      0.916667
# 279967                      0.917431
# 279968                      0.917431
# 279969                      0.900901
# 279970                      0.924528
#
# [9622 rows x 3 columns]
