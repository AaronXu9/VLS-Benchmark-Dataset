# %% [markdown]
# # PLINDER System Filtering Pipeline
#
# This notebook filters PLINDER annotation data based on structural quality, experimental criteria, and interaction relevance to select meaningful protein-ligand systems for analysis.
#
# ## Filtering Criteria:
# 1. **Experimental Method**: X-ray crystallography only
# 2. **Bioassembly**: First bioassembly only
# 3. **Chain Limits**: ≤5 ligand chains, ≤5 protein chains
# 4. **Covalent Ligands**: Exclude systems with covalent ligands
# 5. **Ligand Types**: Exclude cofactors/oligopeptides/nucleotides/saccharides
# 6. **X-ray Validation**: Resolution, R-factors, coordinates, clashes, contacts
# 7. **Interaction Statistics**: 3-50 PLIP interactions, 5-100 pocket residues
# 8. **Molecular Weight**: 200-800 Da for largest ligand

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from collections import OrderedDict

# Set visualization style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
# %matplotlib inline

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## Load Annotation Data

# %%
# Load the annotation table
annotation_path = Path('data/annotation_table.parquet')

if not annotation_path.exists():
    print(f"❌ File not found: {annotation_path}")
    print("Please ensure annotation_table.parquet is in the data/ directory")
else:
    df = pd.read_parquet(annotation_path)
    print(f"✓ Loaded annotation table: {annotation_path}")
    print(f"  Shape: {df.shape}")
    print(f"  Columns: {len(df.columns)}")
    print(f"  Memory usage: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# ✓ Loaded annotation table: data/annotation_table.parquet
#   Shape: (1357906, 743)
#   Columns: 743
#   Memory usage: 34998.08 MB

# %% [markdown]
# ## Initial Data Overview

# %%
# Display initial statistics
print("="*80)
print("INITIAL DATA OVERVIEW")
print("="*80)
print(f"Total systems: {len(df):,}")
print(f"\nColumn names ({len(df.columns)}):")
for i, col in enumerate(df.columns, 1):
    print(f"  {i:3d}. {col}")

print(f"\nFirst few rows:")
display(df.head(3))

print(f"\nData types summary:")
print(df.dtypes.value_counts())

# Initialize filtering statistics tracker
filtering_stats = OrderedDict()
filtering_stats['Initial'] = len(df)
# Out:
# ================================================================================
# INITIAL DATA OVERVIEW
# ================================================================================
# Total systems: 1,357,906
#
# Column names (743):
#     1. entry_pdb_id
#     2. entry_release_date
#     3. entry_oligomeric_state
#     4. entry_determination_method
#     5. entry_keywords
#     6. entry_pH
#     7. entry_resolution
#     8. entry_validation_resolution
#     9. entry_validation_rfree
#    10. entry_validation_r
#    11. entry_validation_clashscore
#    12. entry_validation_percent_rama_outliers
#    13. entry_validation_percent_rota_outliers
#    14. entry_validation_data_completeness
#    15. entry_validation_percent_RSRZ_outliers
#    16. entry_validation_atom_count
#    17. entry_validation_molprobity
#    18. entry_validation_mean_b_factor
#    19. entry_validation_median_b_factor
#    20. entry_validation_pdbx_resolution
#    21. entry_validation_pdbx_reflns_resolution
#    22. entry_validation_meanI_over_sigI_obs
#    23. entry_validation_r_minus_rfree
#    24. entry_pass_validation_criteria
#    25. system_biounit_id
#    26. system_protein_chains_asym_id
#    27. system_id_no_biounit
#    28. system_ligand_chains
#    29. system_num_pocket_residues
#    30. system_proper_num_pocket_residues
#    31. system_num_interactions
#    32. system_proper_num_interactions
#    33. system_num_unique_interactions
#    34. system_proper_num_unique_interactions
#    35. system_num_covalent_ligands
#    36. system_proper_num_covalent_ligands
#    37. system_id
#    38. system_type
#    39. system_has_kinase_inhibitor
#    40. system_has_binding_affinity
#    41. system_num_protein_chains
#    42. system_proper_num_protein_chains
#    43. system_num_ligand_chains
#    44. system_proper_num_ligand_chains
#    45. system_num_crystal_contacted_residues
#    46. system_num_atoms_with_crystal_contacts
#    47. system_num_heavy_atoms
#    48. system_num_resolved_heavy_atoms
#    49. system_ligand_max_qed
#    50. system_ligand_max_molecular_weight
#    51. system_proper_ligand_max_molecular_weight
#    52. system_num_unresolved_heavy_atoms
#    53. system_fraction_atoms_with_crystal_contacts
#    54. system_pocket_CATH
#    55. system_pocket_SCOP2B
#    56. system_pocket_Pfam
#    57. system_pocket_UniProt
#    58. system_pocket_ECOD
#    59. system_pocket_ECOD_t_name
#    60. system_ligand_validation_num_residues
#    61. system_ligand_validation_num_processed_residues
#    62. system_ligand_validation_percent_processed_residues
#    63. system_ligand_validation_average_rsr
#    64. system_ligand_validation_average_rsrz
#    65. system_ligand_validation_average_rscc
#    66. system_ligand_validation_average_occupancy
#    67. system_ligand_validation_percent_rsr_under_threshold
#    68. system_ligand_validation_percent_rscc_over_threshold
#    69. system_ligand_validation_percent_occupancy_over_threshold
#    70. system_ligand_validation_average_b_factor
#    71. system_ligand_validation_unknown_residue_count
#    72. system_ligand_validation_atom_count
#    73. system_ligand_validation_heavy_atom_count
#    74. system_ligand_validation_num_unresolved_heavy_atoms
#    75. system_ligand_validation_max_alt_count
#    76. system_ligand_validation_percent_outliers_geometry
#    77. system_ligand_validation_percent_outliers_density
#    78. system_ligand_validation_percent_outliers_chirality
#    79. system_ligand_validation_percent_outliers_clashes
#    80. system_pocket_validation_num_residues
#    81. system_pocket_validation_num_processed_residues
#    82. system_pocket_validation_percent_processed_residues
#    83. system_pocket_validation_average_rsr
#    84. system_pocket_validation_average_rsrz
#    85. system_pocket_validation_average_rscc
#    86. system_pocket_validation_average_occupancy
#    87. system_pocket_validation_percent_rsr_under_threshold
#    88. system_pocket_validation_percent_rscc_over_threshold
#    89. system_pocket_validation_percent_occupancy_over_threshold
#    90. system_pocket_validation_average_b_factor
#    91. system_pocket_validation_unknown_residue_count
#    92. system_pocket_validation_atom_count
#    93. system_pocket_validation_heavy_atom_count
#    94. system_pocket_validation_num_unresolved_heavy_atoms
#    95. system_pocket_validation_max_alt_count
#    96. system_pocket_validation_percent_outliers_geometry
#    97. system_pocket_validation_percent_outliers_density
#    98. system_pocket_validation_percent_outliers_chirality
#    99. system_pocket_validation_percent_outliers_clashes
#   100. system_pass_validation_criteria
#   101. system_protein_chains_auth_id
#   102. system_protein_chains_entity_id
#   103. system_protein_chains_length
#   104. system_protein_chains_num_unresolved_residues
#   105. system_protein_chains_validation_num_residues
#   106. system_protein_chains_validation_num_processed_residues
#   107. system_protein_chains_validation_percent_processed_residues
#   108. system_protein_chains_validation_average_rsr
#   109. system_protein_chains_validation_average_rsrz
#   110. system_protein_chains_validation_average_rscc
#   111. system_protein_chains_validation_average_occupancy
#   112. system_protein_chains_validation_percent_rsr_under_threshold
#   113. system_protein_chains_validation_percent_rscc_over_threshold
#   114. system_protein_chains_validation_percent_occupancy_over_threshold
#   115. system_protein_chains_validation_average_b_factor
#   116. system_protein_chains_validation_unknown_residue_count
#   117. system_protein_chains_validation_atom_count
#   118. system_protein_chains_validation_heavy_atom_count
#   119. system_protein_chains_validation_num_unresolved_heavy_atoms
#   120. system_protein_chains_validation_max_alt_count
#   121. system_protein_chains_validation_percent_outliers_geometry
#   122. system_protein_chains_validation_percent_outliers_density
#   123. system_protein_chains_validation_percent_outliers_chirality
#   124. system_protein_chains_validation_percent_outliers_clashes
#   125. system_ligand_chains_asym_id
#   126. system_ligand_chains_auth_id
#   127. system_ligand_chains_entity_id
#   128. system_ligand_chains_length
#   129. system_ligand_chains_num_unresolved_residues
#   130. system_ligand_chains_validation_num_residues
#   131. system_ligand_chains_validation_num_processed_residues
#   132. system_ligand_chains_validation_percent_processed_residues
#   133. system_ligand_chains_validation_average_rsr
#   134. system_ligand_chains_validation_average_rsrz
#   135. system_ligand_chains_validation_average_rscc
#   136. system_ligand_chains_validation_average_occupancy
#   137. system_ligand_chains_validation_percent_rsr_under_threshold
#   138. system_ligand_chains_validation_percent_rscc_over_threshold
#   139. system_ligand_chains_validation_percent_occupancy_over_threshold
#   140. system_ligand_chains_validation_average_b_factor
#   141. system_ligand_chains_validation_unknown_residue_count
#   142. system_ligand_chains_validation_atom_count
#   143. system_ligand_chains_validation_heavy_atom_count
#   144. system_ligand_chains_validation_num_unresolved_heavy_atoms
#   145. system_ligand_chains_validation_max_alt_count
#   146. system_ligand_chains_validation_percent_outliers_geometry
#   147. system_ligand_chains_validation_percent_outliers_density
#   148. system_ligand_chains_validation_percent_outliers_chirality
#   149. system_ligand_chains_validation_percent_outliers_clashes
#   150. ligand_asym_id
#   151. ligand_instance
#   152. ligand_ccd_code
#   153. ligand_plip_type
#   154. ligand_bird_id
#   155. ligand_centroid
#   156. ligand_smiles
#   157. ligand_resolved_smiles
#   158. ligand_rdkit_canonical_smiles
#   159. ligand_molecular_weight
#   160. ligand_crippen_clogp
#   161. ligand_num_rot_bonds
#   162. ligand_num_hbd
#   163. ligand_num_hba
#   164. ligand_num_rings
#   165. ligand_num_heavy_atoms
#   166. ligand_is_covalent
#   167. ligand_covalent_linkages
#   168. ligand_num_neighboring_ppi_atoms_within_4A_of_gap
#   169. ligand_num_neighboring_ppi_atoms_within_8A_of_gap
#   170. ligand_num_missing_ppi_interface_residues
#   171. ligand_num_pli_atoms_within_4A_of_gap
#   172. ligand_num_pli_atoms_within_8A_of_gap
#   173. ligand_num_missing_pli_interface_residues
#   174. ligand_num_resolved_heavy_atoms
#   175. ligand_num_unresolved_heavy_atoms
#   176. ligand_tpsa
#   177. ligand_qed
#   178. ligand_is_ion
#   179. ligand_is_lipinski
#   180. ligand_is_fragment
#   181. ligand_is_oligo
#   182. ligand_is_cofactor
#   183. ligand_in_artifact_list
#   184. ligand_is_artifact
#   185. ligand_is_other
#   186. ligand_is_invalid
#   187. ligand_unique_ccd_code
#   188. ligand_protein_chains_asym_id
#   189. ligand_num_interacting_residues
#   190. ligand_num_neighboring_residues
#   191. ligand_is_proper
#   192. ligand_num_interactions
#   193. ligand_num_unique_interactions
#   194. ligand_num_crystal_contacted_residues
#   195. ligand_num_atoms_with_crystal_contacts
#   196. ligand_fraction_atoms_with_crystal_contacts
#   197. ligand_num_pocket_residues
#   198. ligand_id
#   199. ligand_instance_chain
#   200. ligand_is_kinase_inhibitor
#   201. ligand_binding_affinity
#   202. ligand_posebusters_mol_pred_loaded
#   203. ligand_posebusters_mol_true_loaded
#   204. ligand_posebusters_mol_cond_loaded
#   205. ligand_posebusters_sanitization
#   206. ligand_posebusters_all_atoms_connected
#   207. ligand_posebusters_molecular_formula
#   208. ligand_posebusters_molecular_bonds
#   209. ligand_posebusters_double_bond_stereochemistry
#   210. ligand_posebusters_tetrahedral_chirality
#   211. ligand_posebusters_bond_angles
#   212. ligand_posebusters_aromatic_ring_flatness
#   213. ligand_posebusters_double_bond_flatness
#   214. ligand_posebusters_internal_energy
#   215. ligand_posebusters_protein-ligand_maximum_distance
#   216. ligand_posebusters_minimum_distance_to_protein
#   217. ligand_posebusters_minimum_distance_to_organic_cofactors
#   218. ligand_posebusters_minimum_distance_to_inorganic_cofactors
#   219. ligand_posebusters_minimum_distance_to_waters
#   220. ligand_posebusters_volume_overlap_with_protein
#   221. ligand_posebusters_volume_overlap_with_organic_cofactors
#   222. ligand_posebusters_volume_overlap_with_inorganic_cofactors
#   223. ligand_posebusters_volume_overlap_with_waters
#   224. ligand_posebusters_rmsd_≤_2å
#   225. ligand_posebusters_passes_valence_checks
#   226. ligand_posebusters_passes_kekulization
#   227. ligand_posebusters_inchi_crystal_valid
#   228. ligand_posebusters_inchi_docked_valid
#   229. ligand_posebusters_inchi_crystal
#   230. ligand_posebusters_inchi_docked
#   231. ligand_posebusters_inchi_overall
#   232. ligand_posebusters_inchi_version
#   233. ligand_posebusters_stereochemistry_preserved
#   234. ligand_posebusters_hydrogens
#   235. ligand_posebusters_net_charge
#   236. ligand_posebusters_protons
#   237. ligand_posebusters_stereo_sp3
#   238. ligand_posebusters_stereo_sp3_inverted
#   239. ligand_posebusters_stereo_type
#   240. ligand_posebusters_number_bonds
#   241. ligand_posebusters_shortest_bond_relative_length
#   242. ligand_posebusters_longest_bond_relative_length
#   243. ligand_posebusters_number_short_outlier_bonds
#   244. ligand_posebusters_number_angles
#   245. ligand_posebusters_most_extreme_relative_angle
#   246. ligand_posebusters_number_noncov_pairs
#   247. ligand_posebusters_shortest_noncovalent_relative_distance
#   248. ligand_posebusters_number_clashes
#   249. ligand_posebusters_number_valid_bonds
#   250. ligand_posebusters_number_valid_angles
#   251. ligand_posebusters_number_valid_noncov_pairs
#   252. ligand_posebusters_number_aromatic_rings_checked
#   253. ligand_posebusters_number_aromatic_rings_pass
#   254. ligand_posebusters_aromatic_ring_maximum_distance_from_plane
#   255. ligand_posebusters_double_bond_maximum_distance_from_plane
#   256. ligand_posebusters_ensemble_avg_energy
#   257. ligand_posebusters_mol_pred_energy
#   258. ligand_posebusters_energy_ratio
#   259. ligand_posebusters_smallest_distance_protein
#   260. ligand_posebusters_most_extreme_ligand_atom_id_protein
#   261. ligand_posebusters_most_extreme_protein_atom_id_protein
#   262. ligand_posebusters_most_extreme_ligand_element_protein
#   263. ligand_posebusters_most_extreme_protein_element_protein
#   264. ligand_posebusters_most_extreme_ligand_vdw_protein
#   265. ligand_posebusters_most_extreme_protein_vdw_protein
#   266. ligand_posebusters_most_extreme_sum_radii_protein
#   267. ligand_posebusters_most_extreme_distance_protein
#   268. ligand_posebusters_most_extreme_sum_radii_scaled_protein
#   269. ligand_posebusters_most_extreme_relative_distance_protein
#   270. ligand_posebusters_smallest_distance_organic_cofactors
#   271. ligand_posebusters_smallest_distance_inorganic_cofactors
#   272. ligand_posebusters_smallest_distance_waters
#   273. ligand_posebusters_volume_overlap_protein
#   274. ligand_posebusters_volume_overlap_organic_cofactors
#   275. ligand_posebusters_volume_overlap_inorganic_cofactors
#   276. ligand_posebusters_volume_overlap_waters
#   277. ligand_interactions
#   278. ligand_auth_id
#   279. ligand_protein_chains_auth_id
#   280. ligand_protein_chains_entity_id
#   281. ligand_protein_chains_length
#   282. ligand_protein_chains_num_unresolved_residues
#   283. ligand_protein_chains_validation_num_residues
#   284. ligand_protein_chains_validation_num_processed_residues
#   285. ligand_protein_chains_validation_percent_processed_residues
#   286. ligand_protein_chains_validation_average_rsr
#   287. ligand_protein_chains_validation_average_rsrz
#   288. ligand_protein_chains_validation_average_rscc
#   289. ligand_protein_chains_validation_average_occupancy
#   290. ligand_protein_chains_validation_percent_rsr_under_threshold
#   291. ligand_protein_chains_validation_percent_rscc_over_threshold
#   292. ligand_protein_chains_validation_percent_occupancy_over_threshold
#   293. ligand_protein_chains_validation_average_b_factor
#   294. ligand_protein_chains_validation_unknown_residue_count
#   295. ligand_protein_chains_validation_atom_count
#   296. ligand_protein_chains_validation_heavy_atom_count
#   297. ligand_protein_chains_validation_num_unresolved_heavy_atoms
#   298. ligand_protein_chains_validation_max_alt_count
#   299. ligand_protein_chains_validation_percent_outliers_geometry
#   300. ligand_protein_chains_validation_percent_outliers_density
#   301. ligand_protein_chains_validation_percent_outliers_chirality
#   302. ligand_protein_chains_validation_percent_outliers_clashes
#   303. ligand_interacting_residues
#   304. ligand_neighboring_residues
#   305. ligand_posebusters_bond_lengths
#   306. ligand_posebusters_internal_steric_clash
#   307. ligand_posebusters_not_too_far_away_waters
#   308. ligand_posebusters_most_extreme_ligand_atom_id_waters
#   309. ligand_posebusters_most_extreme_protein_atom_id_waters
#   310. ligand_posebusters_most_extreme_ligand_element_waters
#   311. ligand_posebusters_most_extreme_protein_element_waters
#   312. ligand_posebusters_most_extreme_ligand_vdw_waters
#   313. ligand_posebusters_most_extreme_protein_vdw_waters
#   314. ligand_posebusters_most_extreme_sum_radii_waters
#   315. ligand_posebusters_most_extreme_distance_waters
#   316. ligand_posebusters_most_extreme_sum_radii_scaled_waters
#   317. ligand_posebusters_most_extreme_relative_distance_waters
#   318. ligand_posebusters_num_pairwise_clashes_protein
#   319. ligand_posebusters_most_extreme_clash_protein
#   320. ligand_posebusters_kabsch_rmsd
#   321. ligand_neighboring_ligand_chains_asym_id
#   322. ligand_neighboring_ligand_chains_auth_id
#   323. ligand_neighboring_ligand_chains_entity_id
#   324. ligand_neighboring_ligand_chains_length
#   325. ligand_neighboring_ligand_chains_num_unresolved_residues
#   326. ligand_neighboring_ligand_chains_validation_num_residues
#   327. ligand_neighboring_ligand_chains_validation_num_processed_residues
#   328. ligand_neighboring_ligand_chains_validation_percent_processed_residues
#   329. ligand_neighboring_ligand_chains_validation_average_rsr
#   330. ligand_neighboring_ligand_chains_validation_average_rsrz
#   331. ligand_neighboring_ligand_chains_validation_average_rscc
#   332. ligand_neighboring_ligand_chains_validation_average_occupancy
#   333. ligand_neighboring_ligand_chains_validation_percent_rsr_under_threshold
#   334. ligand_neighboring_ligand_chains_validation_percent_rscc_over_threshold
#   335. ligand_neighboring_ligand_chains_validation_percent_occupancy_over_threshold
#   336. ligand_neighboring_ligand_chains_validation_average_b_factor
#   337. ligand_neighboring_ligand_chains_validation_unknown_residue_count
#   338. ligand_neighboring_ligand_chains_validation_atom_count
#   339. ligand_neighboring_ligand_chains_validation_heavy_atom_count
#   340. ligand_neighboring_ligand_chains_validation_num_unresolved_heavy_atoms
#   341. ligand_neighboring_ligand_chains_validation_max_alt_count
#   342. ligand_neighboring_ligand_chains_validation_percent_outliers_geometry
#   343. ligand_neighboring_ligand_chains_validation_percent_outliers_density
#   344. ligand_neighboring_ligand_chains_validation_percent_outliers_chirality
#   345. ligand_neighboring_ligand_chains_validation_percent_outliers_clashes
#   346. ligand_posebusters_number_outlier_angles
#   347. ligand_posebusters_number_double_bonds_checked
#   348. ligand_posebusters_number_double_bonds_pass
#   349. ligand_interacting_ligand_chains_asym_id
#   350. ligand_interacting_ligand_chains_auth_id
#   351. ligand_interacting_ligand_chains_entity_id
#   352. ligand_interacting_ligand_chains_length
#   353. ligand_interacting_ligand_chains_num_unresolved_residues
#   354. ligand_interacting_ligand_chains_validation_num_residues
#   355. ligand_interacting_ligand_chains_validation_num_processed_residues
#   356. ligand_interacting_ligand_chains_validation_percent_processed_residues
#   357. ligand_interacting_ligand_chains_validation_average_rsr
#   358. ligand_interacting_ligand_chains_validation_average_rsrz
#   359. ligand_interacting_ligand_chains_validation_average_rscc
#   360. ligand_interacting_ligand_chains_validation_average_occupancy
#   361. ligand_interacting_ligand_chains_validation_percent_rsr_under_threshold
#   362. ligand_interacting_ligand_chains_validation_percent_rscc_over_threshold
#   363. ligand_interacting_ligand_chains_validation_percent_occupancy_over_threshold
#   364. ligand_interacting_ligand_chains_validation_average_b_factor
#   365. ligand_interacting_ligand_chains_validation_unknown_residue_count
#   366. ligand_interacting_ligand_chains_validation_atom_count
#   367. ligand_interacting_ligand_chains_validation_heavy_atom_count
#   368. ligand_interacting_ligand_chains_validation_num_unresolved_heavy_atoms
#   369. ligand_interacting_ligand_chains_validation_max_alt_count
#   370. ligand_interacting_ligand_chains_validation_percent_outliers_geometry
#   371. ligand_interacting_ligand_chains_validation_percent_outliers_density
#   372. ligand_interacting_ligand_chains_validation_percent_outliers_chirality
#   373. ligand_interacting_ligand_chains_validation_percent_outliers_clashes
#   374. system_pocket_SCOP2
#   375. ligand_posebusters_not_too_far_away_organic_cofactors
#   376. ligand_posebusters_most_extreme_ligand_atom_id_organic_cofactors
#   377. ligand_posebusters_most_extreme_protein_atom_id_organic_cofactors
#   378. ligand_posebusters_most_extreme_ligand_element_organic_cofactors
#   379. ligand_posebusters_most_extreme_protein_element_organic_cofactors
#   380. ligand_posebusters_most_extreme_ligand_vdw_organic_cofactors
#   381. ligand_posebusters_most_extreme_protein_vdw_organic_cofactors
#   382. ligand_posebusters_most_extreme_sum_radii_organic_cofactors
#   383. ligand_posebusters_most_extreme_distance_organic_cofactors
#   384. ligand_posebusters_most_extreme_sum_radii_scaled_organic_cofactors
#   385. ligand_posebusters_most_extreme_relative_distance_organic_cofactors
#   386. ligand_posebusters_not_too_far_away_inorganic_cofactors
#   387. ligand_posebusters_most_extreme_ligand_atom_id_inorganic_cofactors
#   388. ligand_posebusters_most_extreme_protein_atom_id_inorganic_cofactors
#   389. ligand_posebusters_most_extreme_ligand_element_inorganic_cofactors
#   390. ligand_posebusters_most_extreme_protein_element_inorganic_cofactors
#   391. ligand_posebusters_most_extreme_ligand_vdw_inorganic_cofactors
#   392. ligand_posebusters_most_extreme_protein_vdw_inorganic_cofactors
#   393. ligand_posebusters_most_extreme_sum_radii_inorganic_cofactors
#   394. ligand_posebusters_most_extreme_distance_inorganic_cofactors
#   395. ligand_posebusters_most_extreme_sum_radii_scaled_inorganic_cofactors
#   396. ligand_posebusters_most_extreme_relative_distance_inorganic_cofactors
#   397. system_pocket_PANTHER
#   398. ligand_posebusters_num_pairwise_clashes_organic_cofactors
#   399. ligand_posebusters_most_extreme_clash_organic_cofactors
#   400. ligand_posebusters_num_pairwise_clashes_inorganic_cofactors
#   401. ligand_posebusters_most_extreme_clash_inorganic_cofactors
#   402. ligand_posebusters_num_pairwise_clashes_waters
#   403. ligand_posebusters_most_extreme_clash_waters
#   404. system_pocket_kinase_name
#   405. ligand_posebusters_number_long_outlier_bonds
#   406. ligand_is_rdkit_loadable
#   407. ligand_is_rdkit_loadable_with_fix
#   408. ligand_is_obabel_loadable
#   409. ligand_is_obabel_loadable_with_rdkit_fix
#   410. ligand_matches_smiles_atom_num
#   411. ligand_positions_correct
#   412. ligand_loadbable_via_biotite
#   413. ligand_molvs_validation
#   414. ligand_rdkit_validation
#   415. complex_loadbable_via_biotite
#   416. ligand_protein_neighbor_still_preserved_complex
#   417. all_ligand_chains_present
#   418. all_protein_chains_present
#   419. pli_qcov__50__community
#   420. pli_qcov__70__community
#   421. pli_qcov__95__community
#   422. pli_qcov__100__community
#   423. pli_qcov__50__weak__component
#   424. pli_qcov__70__weak__component
#   425. pli_qcov__95__weak__component
#   426. pli_qcov__100__weak__component
#   427. pli_qcov__50__strong__component
#   428. pli_qcov__70__strong__component
#   429. pli_qcov__95__strong__component
#   430. pli_qcov__100__strong__component
#   431. pli_unique_qcov__0__community
#   432. pli_unique_qcov__50__community
#   433. pli_unique_qcov__70__community
#   434. pli_unique_qcov__95__community
#   435. pli_unique_qcov__100__community
#   436. pli_unique_qcov__0__weak__component
#   437. pli_unique_qcov__50__weak__component
#   438. pli_unique_qcov__70__weak__component
#   439. pli_unique_qcov__95__weak__component
#   440. pli_unique_qcov__100__weak__component
#   441. pli_unique_qcov__0__strong__component
#   442. pli_unique_qcov__50__strong__component
#   443. pli_unique_qcov__70__strong__component
#   444. pli_unique_qcov__95__strong__component
#   445. pli_unique_qcov__100__strong__component
#   446. pocket_fident__50__community
#   447. pocket_fident__70__community
#   448. pocket_fident__95__community
#   449. pocket_fident__100__community
#   450. pocket_fident__50__weak__component
#   451. pocket_fident__70__weak__component
#   452. pocket_fident__95__weak__component
#   453. pocket_fident__100__weak__component
#   454. pocket_fident__50__strong__component
#   455. pocket_fident__70__strong__component
#   456. pocket_fident__95__strong__component
#   457. pocket_fident__100__strong__component
#   458. pocket_fident_qcov__50__community
#   459. pocket_fident_qcov__70__community
#   460. pocket_fident_qcov__95__community
#   461. pocket_fident_qcov__100__community
#   462. pocket_fident_qcov__50__weak__component
#   463. pocket_fident_qcov__70__weak__component
#   464. pocket_fident_qcov__95__weak__component
#   465. pocket_fident_qcov__100__weak__component
#   466. pocket_fident_qcov__50__strong__component
#   467. pocket_fident_qcov__70__strong__component
#   468. pocket_fident_qcov__95__strong__component
#   469. pocket_fident_qcov__100__strong__component
#   470. pocket_lddt__50__community
#   471. pocket_lddt__70__community
#   472. pocket_lddt__95__community
#   473. pocket_lddt__100__community
#   474. pocket_lddt__50__weak__component
#   475. pocket_lddt__70__weak__component
#   476. pocket_lddt__95__weak__component
#   477. pocket_lddt__100__weak__component
#   478. pocket_lddt__50__strong__component
#   479. pocket_lddt__70__strong__component
#   480. pocket_lddt__95__strong__component
#   481. pocket_lddt__100__strong__component
#   482. pocket_lddt_qcov__50__community
#   483. pocket_lddt_qcov__70__community
#   484. pocket_lddt_qcov__95__community
#   485. pocket_lddt_qcov__100__community
#   486. pocket_lddt_qcov__50__weak__component
#   487. pocket_lddt_qcov__70__weak__component
#   488. pocket_lddt_qcov__95__weak__component
#   489. pocket_lddt_qcov__100__weak__component
#   490. pocket_lddt_qcov__50__strong__component
#   491. pocket_lddt_qcov__70__strong__component
#   492. pocket_lddt_qcov__95__strong__component
#   493. pocket_lddt_qcov__100__strong__component
#   494. pocket_qcov__50__community
#   495. pocket_qcov__70__community
#   496. pocket_qcov__95__community
#   497. pocket_qcov__100__community
#   498. pocket_qcov__50__weak__component
#   499. pocket_qcov__70__weak__component
#   500. pocket_qcov__95__weak__component
#   501. pocket_qcov__100__weak__component
#   502. pocket_qcov__50__strong__component
#   503. pocket_qcov__70__strong__component
#   504. pocket_qcov__95__strong__component
#   505. pocket_qcov__100__strong__component
#   506. protein_fident_max__50__community
#   507. protein_fident_max__70__community
#   508. protein_fident_max__95__community
#   509. protein_fident_max__100__community
#   510. protein_fident_max__50__weak__component
#   511. protein_fident_max__70__weak__component
#   512. protein_fident_max__95__weak__component
#   513. protein_fident_max__100__weak__component
#   514. protein_fident_max__50__strong__component
#   515. protein_fident_max__70__strong__component
#   516. protein_fident_max__95__strong__component
#   517. protein_fident_max__100__strong__component
#   518. protein_fident_qcov_max__50__community
#   519. protein_fident_qcov_max__70__community
#   520. protein_fident_qcov_max__95__community
#   521. protein_fident_qcov_max__100__community
#   522. protein_fident_qcov_max__50__weak__component
#   523. protein_fident_qcov_max__70__weak__component
#   524. protein_fident_qcov_max__95__weak__component
#   525. protein_fident_qcov_max__100__weak__component
#   526. protein_fident_qcov_max__50__strong__component
#   527. protein_fident_qcov_max__70__strong__component
#   528. protein_fident_qcov_max__95__strong__component
#   529. protein_fident_qcov_max__100__strong__component
#   530. protein_fident_qcov_weighted_max__50__community
#   531. protein_fident_qcov_weighted_max__70__community
#   532. protein_fident_qcov_weighted_max__95__community
#   533. protein_fident_qcov_weighted_max__100__community
#   534. protein_fident_qcov_weighted_max__50__weak__component
#   535. protein_fident_qcov_weighted_max__70__weak__component
#   536. protein_fident_qcov_weighted_max__95__weak__component
#   537. protein_fident_qcov_weighted_max__100__weak__component
#   538. protein_fident_qcov_weighted_max__50__strong__component
#   539. protein_fident_qcov_weighted_max__70__strong__component
#   540. protein_fident_qcov_weighted_max__95__strong__component
#   541. protein_fident_qcov_weighted_max__100__strong__component
#   542. protein_fident_qcov_weighted_sum__50__community
#   543. protein_fident_qcov_weighted_sum__70__community
#   544. protein_fident_qcov_weighted_sum__95__community
#   545. protein_fident_qcov_weighted_sum__100__community
#   546. protein_fident_qcov_weighted_sum__50__weak__component
#   547. protein_fident_qcov_weighted_sum__70__weak__component
#   548. protein_fident_qcov_weighted_sum__95__weak__component
#   549. protein_fident_qcov_weighted_sum__100__weak__component
#   550. protein_fident_qcov_weighted_sum__50__strong__component
#   551. protein_fident_qcov_weighted_sum__70__strong__component
#   552. protein_fident_qcov_weighted_sum__95__strong__component
#   553. protein_fident_qcov_weighted_sum__100__strong__component
#   554. protein_fident_weighted_max__50__community
#   555. protein_fident_weighted_max__70__community
#   556. protein_fident_weighted_max__95__community
#   557. protein_fident_weighted_max__100__community
#   558. protein_fident_weighted_max__50__weak__component
#   559. protein_fident_weighted_max__70__weak__component
#   560. protein_fident_weighted_max__95__weak__component
#   561. protein_fident_weighted_max__100__weak__component
#   562. protein_fident_weighted_max__50__strong__component
#   563. protein_fident_weighted_max__70__strong__component
#   564. protein_fident_weighted_max__95__strong__component
#   565. protein_fident_weighted_max__100__strong__component
#   566. protein_fident_weighted_sum__50__community
#   567. protein_fident_weighted_sum__70__community
#   568. protein_fident_weighted_sum__95__community
#   569. protein_fident_weighted_sum__100__community
#   570. protein_fident_weighted_sum__50__weak__component
#   571. protein_fident_weighted_sum__70__weak__component
#   572. protein_fident_weighted_sum__95__weak__component
#   573. protein_fident_weighted_sum__100__weak__component
#   574. protein_fident_weighted_sum__50__strong__component
#   575. protein_fident_weighted_sum__70__strong__component
#   576. protein_fident_weighted_sum__95__strong__component
#   577. protein_fident_weighted_sum__100__strong__component
#   578. protein_lddt_max__70__community
#   579. protein_lddt_max__95__community
#   580. protein_lddt_max__100__community
#   581. protein_lddt_max__70__weak__component
#   582. protein_lddt_max__95__weak__component
#   583. protein_lddt_max__100__weak__component
#   584. protein_lddt_max__70__strong__component
#   585. protein_lddt_max__95__strong__component
#   586. protein_lddt_max__100__strong__component
#   587. protein_lddt_qcov_max__50__community
#   588. protein_lddt_qcov_max__70__community
#   589. protein_lddt_qcov_max__95__community
#   590. protein_lddt_qcov_max__100__community
#   591. protein_lddt_qcov_max__50__weak__component
#   592. protein_lddt_qcov_max__70__weak__component
#   593. protein_lddt_qcov_max__95__weak__component
#   594. protein_lddt_qcov_max__100__weak__component
#   595. protein_lddt_qcov_max__50__strong__component
#   596. protein_lddt_qcov_max__70__strong__component
#   597. protein_lddt_qcov_max__95__strong__component
#   598. protein_lddt_qcov_max__100__strong__component
#   599. protein_lddt_qcov_weighted_max__50__community
#   600. protein_lddt_qcov_weighted_max__70__community
#   601. protein_lddt_qcov_weighted_max__95__community
#   602. protein_lddt_qcov_weighted_max__100__community
#   603. protein_lddt_qcov_weighted_max__50__weak__component
#   604. protein_lddt_qcov_weighted_max__70__weak__component
#   605. protein_lddt_qcov_weighted_max__95__weak__component
#   606. protein_lddt_qcov_weighted_max__100__weak__component
#   607. protein_lddt_qcov_weighted_max__50__strong__component
#   608. protein_lddt_qcov_weighted_max__70__strong__component
#   609. protein_lddt_qcov_weighted_max__95__strong__component
#   610. protein_lddt_qcov_weighted_max__100__strong__component
#   611. protein_lddt_qcov_weighted_sum__50__community
#   612. protein_lddt_qcov_weighted_sum__70__community
#   613. protein_lddt_qcov_weighted_sum__95__community
#   614. protein_lddt_qcov_weighted_sum__100__community
#   615. protein_lddt_qcov_weighted_sum__50__weak__component
#   616. protein_lddt_qcov_weighted_sum__70__weak__component
#   617. protein_lddt_qcov_weighted_sum__95__weak__component
#   618. protein_lddt_qcov_weighted_sum__100__weak__component
#   619. protein_lddt_qcov_weighted_sum__50__strong__component
#   620. protein_lddt_qcov_weighted_sum__70__strong__component
#   621. protein_lddt_qcov_weighted_sum__95__strong__component
#   622. protein_lddt_qcov_weighted_sum__100__strong__component
#   623. protein_lddt_weighted_max__70__community
#   624. protein_lddt_weighted_max__95__community
#   625. protein_lddt_weighted_max__100__community
#   626. protein_lddt_weighted_max__70__weak__component
#   627. protein_lddt_weighted_max__95__weak__component
#   628. protein_lddt_weighted_max__100__weak__component
#   629. protein_lddt_weighted_max__70__strong__component
#   630. protein_lddt_weighted_max__95__strong__component
#   631. protein_lddt_weighted_max__100__strong__component
#   632. protein_lddt_weighted_sum__50__community
#   633. protein_lddt_weighted_sum__70__community
#   634. protein_lddt_weighted_sum__95__community
#   635. protein_lddt_weighted_sum__100__community
#   636. protein_lddt_weighted_sum__50__weak__component
#   637. protein_lddt_weighted_sum__70__weak__component
#   638. protein_lddt_weighted_sum__95__weak__component
#   639. protein_lddt_weighted_sum__100__weak__component
#   640. protein_lddt_weighted_sum__50__strong__component
#   641. protein_lddt_weighted_sum__70__strong__component
#   642. protein_lddt_weighted_sum__95__strong__component
#   643. protein_lddt_weighted_sum__100__strong__component
#   644. protein_qcov_weighted_sum__100__community
#   645. protein_qcov_weighted_sum__100__weak__component
#   646. protein_qcov_weighted_sum__100__strong__component
#   647. protein_seqsim_max__70__community
#   648. protein_seqsim_max__95__community
#   649. protein_seqsim_max__100__community
#   650. protein_seqsim_max__70__weak__component
#   651. protein_seqsim_max__95__weak__component
#   652. protein_seqsim_max__100__weak__component
#   653. protein_seqsim_max__70__strong__component
#   654. protein_seqsim_max__95__strong__component
#   655. protein_seqsim_max__100__strong__component
#   656. protein_seqsim_qcov_max__50__community
#   657. protein_seqsim_qcov_max__70__community
#   658. protein_seqsim_qcov_max__95__community
#   659. protein_seqsim_qcov_max__100__community
#   660. protein_seqsim_qcov_max__50__weak__component
#   661. protein_seqsim_qcov_max__70__weak__component
#   662. protein_seqsim_qcov_max__95__weak__component
#   663. protein_seqsim_qcov_max__100__weak__component
#   664. protein_seqsim_qcov_max__50__strong__component
#   665. protein_seqsim_qcov_max__70__strong__component
#   666. protein_seqsim_qcov_max__95__strong__component
#   667. protein_seqsim_qcov_max__100__strong__component
#   668. protein_seqsim_qcov_weighted_max__50__community
#   669. protein_seqsim_qcov_weighted_max__70__community
#   670. protein_seqsim_qcov_weighted_max__95__community
#   671. protein_seqsim_qcov_weighted_max__100__community
#   672. protein_seqsim_qcov_weighted_max__50__weak__component
#   673. protein_seqsim_qcov_weighted_max__70__weak__component
#   674. protein_seqsim_qcov_weighted_max__95__weak__component
#   675. protein_seqsim_qcov_weighted_max__100__weak__component
#   676. protein_seqsim_qcov_weighted_max__50__strong__component
#   677. protein_seqsim_qcov_weighted_max__70__strong__component
#   678. protein_seqsim_qcov_weighted_max__95__strong__component
#   679. protein_seqsim_qcov_weighted_max__100__strong__component
#   680. protein_seqsim_qcov_weighted_sum__50__community
#   681. protein_seqsim_qcov_weighted_sum__70__community
#   682. protein_seqsim_qcov_weighted_sum__95__community
#   683. protein_seqsim_qcov_weighted_sum__100__community
#   684. protein_seqsim_qcov_weighted_sum__50__weak__component
#   685. protein_seqsim_qcov_weighted_sum__70__weak__component
#   686. protein_seqsim_qcov_weighted_sum__95__weak__component
#   687. protein_seqsim_qcov_weighted_sum__100__weak__component
#   688. protein_seqsim_qcov_weighted_sum__50__strong__component
#   689. protein_seqsim_qcov_weighted_sum__70__strong__component
#   690. protein_seqsim_qcov_weighted_sum__95__strong__component
#   691. protein_seqsim_qcov_weighted_sum__100__strong__component
#   692. protein_seqsim_weighted_max__70__community
#   693. protein_seqsim_weighted_max__95__community
#   694. protein_seqsim_weighted_max__100__community
#   695. protein_seqsim_weighted_max__70__weak__component
#   696. protein_seqsim_weighted_max__95__weak__component
#   697. protein_seqsim_weighted_max__100__weak__component
#   698. protein_seqsim_weighted_max__70__strong__component
#   699. protein_seqsim_weighted_max__95__strong__component
#   700. protein_seqsim_weighted_max__100__strong__component
#   701. protein_seqsim_weighted_sum__50__community
#   702. protein_seqsim_weighted_sum__70__community
#   703. protein_seqsim_weighted_sum__95__community
#   704. protein_seqsim_weighted_sum__100__community
#   705. protein_seqsim_weighted_sum__50__weak__component
#   706. protein_seqsim_weighted_sum__70__weak__component
#   707. protein_seqsim_weighted_sum__95__weak__component
#   708. protein_seqsim_weighted_sum__100__weak__component
#   709. protein_seqsim_weighted_sum__50__strong__component
#   710. protein_seqsim_weighted_sum__70__strong__component
#   711. protein_seqsim_weighted_sum__95__strong__component
#   712. protein_seqsim_weighted_sum__100__strong__component
#   713. tanimoto_similarity_max__30__community
#   714. tanimoto_similarity_max__50__community
#   715. tanimoto_similarity_max__70__community
#   716. tanimoto_similarity_max__95__community
#   717. tanimoto_similarity_max__100__community
#   718. tanimoto_similarity_max__30__weak__component
#   719. tanimoto_similarity_max__50__weak__component
#   720. tanimoto_similarity_max__70__weak__component
#   721. tanimoto_similarity_max__95__weak__component
#   722. tanimoto_similarity_max__100__weak__component
#   723. tanimoto_similarity_max__30__strong__component
#   724. tanimoto_similarity_max__50__strong__component
#   725. tanimoto_similarity_max__70__strong__component
#   726. tanimoto_similarity_max__95__strong__component
#   727. tanimoto_similarity_max__100__strong__component
#   728. uniqueness
#   729. biounit_num_ligands
#   730. biounit_num_unique_ccd_codes
#   731. biounit_num_proper_ligands
#   732. system_ligand_has_lipinski
#   733. system_ligand_has_cofactor
#   734. system_ligand_has_fragment
#   735. system_ligand_has_oligo
#   736. system_ligand_has_artifact
#   737. system_ligand_has_other
#   738. system_ligand_has_covalent
#   739. system_ligand_has_invalid
#   740. system_ligand_has_ion
#   741. system_protein_chains_total_length
#   742. system_unique_ccd_codes
#   743. system_proper_unique_ccd_codes
#
# First few rows:
#   entry_pdb_id entry_release_date entry_oligomeric_state  \
# 0         3grt         1997-02-12                dimeric
# 1         3grt         1997-02-12                dimeric
# 2         3grt         1997-02-12                dimeric
#
#   entry_determination_method  entry_keywords entry_pH  entry_resolution  \
# 0          X-RAY DIFFRACTION  OXIDOREDUCTASE      8.0               2.5
# 1          X-RAY DIFFRACTION  OXIDOREDUCTASE      8.0               2.5
# 2          X-RAY DIFFRACTION  OXIDOREDUCTASE      8.0               2.5
#
#    entry_validation_resolution  entry_validation_rfree  entry_validation_r  \
# 0                          2.5                     NaN                0.17
# 1                          2.5                     NaN                0.17
# 2                          2.5                     NaN                0.17
#
#    ...  system_ligand_has_fragment  system_ligand_has_oligo  \
# 0  ...                       False                    False
# 1  ...                       False                     True
# 2  ...                       False                    False
#
#    system_ligand_has_artifact  system_ligand_has_other  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
#
#    system_ligand_has_covalent  system_ligand_has_invalid  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
#
#    system_ligand_has_ion  system_protein_chains_total_length  \
# 0                  False                                 922
# 1                  False                                 922
# 2                  False                                 922
#
#    system_unique_ccd_codes  system_proper_unique_ccd_codes
# 0                      FAD                             FAD
# 1                      TS2                             TS2
# 2                      FAD                             FAD
#
# [3 rows x 743 columns]
# Data types summary:
# object     541
# float64    135
# int64       42
# bool        25
# Name: count, dtype: int64

# %% [markdown]
# ## Key Columns from PLINDER Documentation
#
# Based on the PLINDER documentation (https://plinder-org.github.io/plinder/), here are the key columns we'll use:
#
# ### Entry-Level (PDB):
# - `entry_pdb_id`: PDB ID
# - `entry_determination_method`: Experimental method (e.g., "X-RAY DIFFRACTION")
# - `entry_resolution`: Resolution in Angstroms
# - `entry_rfree`: R-free factor
# - `entry_r`: R-factor
# - `entry_clashscore`: Clashscore
# - `entry_oligomeric_state`: Oligomeric state
#
# ### System-Level:
# - `system_id`: PLINDER system ID (format: pdb__bioassembly__receptor_chains__ligand_chains)
# - `system_num_protein_chains`: Number of protein chains
# - `system_num_ligand_chains`: Number of ligand chains
# - `system_pocket_num_residues`: Number of pocket residues (within 6Å of ligand)
# - `system_num_interactions`: Number of protein-ligand interactions (PLIP)
#
# ### Ligand-Level (arrays per ligand):
# - `ligand_is_covalent`: Array of booleans for covalent binding
# - `ligand_is_cofactor`: Array of booleans for cofactors
# - `ligand_is_ion`: Array of booleans for ions
# - `ligand_is_artifact`: Array of booleans for artifacts
# - `ligand_is_proper`: Array of booleans for "proper" ligands
# - `ligand_max_molecular_weight`: Maximum molecular weight among ligands
#
# ### Validation (for proper ligands):
# - `system_proper_num_interactions`: PLIP interactions for proper ligands only
# - `system_proper_pocket_num_residues`: Pocket residues for proper ligands only
# - `system_proper_ligand_max_molecular_weight`: Max MW of proper ligands
# - `system_pass_validation_criteria`: Boolean for crystal quality
# - `system_pass_statistics_criteria`: Boolean for statistics criteria
#
# Note: Many ligand columns are arrays (list[bool], list[float]) because each system can have multiple ligands.

# %%
# Display first few rows and key column info
print("=" * 80)
print("ANNOTATION TABLE OVERVIEW")
print("=" * 80)
print(f"Shape: {df.shape[0]:,} systems × {df.shape[1]} columns")
print(f"\nFirst system ID: {df['system_id'].iloc[0]}")
print(f"System ID format: <pdb>__<bioassembly>__<receptor_chains>__<ligand_chains>")
print(f"\nColumn categories:")
print(f"  - Entry (PDB-level): {sum(1 for c in df.columns if c.startswith('entry_'))} columns")
print(f"  - System-level: {sum(1 for c in df.columns if c.startswith('system_'))} columns")
print(f"  - Ligand-level: {sum(1 for c in df.columns if c.startswith('ligand_'))} columns")
print(f"  - Protein chains: {sum(1 for c in df.columns if 'protein_chains' in c)} columns")
print(f"  - Biounit: {sum(1 for c in df.columns if 'biounit' in c)} columns")

# Check key filtering columns exist
key_cols = [
    'entry_determination_method', 'entry_resolution', 'entry_rfree', 'entry_r',
    'entry_clashscore', 'system_num_protein_chains', 'system_num_ligand_chains',
    'ligand_is_covalent', 'ligand_is_cofactor', 'system_proper_num_interactions',
    'system_proper_pocket_num_residues', 'system_proper_ligand_max_molecular_weight'
]

print(f"\n{'=' * 80}")
print("KEY FILTERING COLUMNS AVAILABILITY")
print('=' * 80)
for col in key_cols:
    exists = col in df.columns
    status = "✓" if exists else "✗"
    print(f"{status} {col}")
    if exists and df[col].dtype in ['object', 'bool']:
        unique = df[col].nunique()
        print(f"    → {unique:,} unique values, {df[col].isna().sum():,} nulls")
        if unique <= 10:
            print(f"    → Values: {df[col].unique()[:10]}")
# Out:
# ================================================================================
# ANNOTATION TABLE OVERVIEW
# ================================================================================
# Shape: 1,357,906 systems × 743 columns
#
# First system ID: 3grt__1__1.A_2.A__1.B
# System ID format: <pdb>__<bioassembly>__<receptor_chains>__<ligand_chains>
#
# Column categories:
#   - Entry (PDB-level): 24 columns
#   - System-level: 140 columns
#   - Ligand-level: 263 columns
#   - Protein chains: 54 columns
#   - Biounit: 5 columns
#
# ================================================================================
# KEY FILTERING COLUMNS AVAILABILITY
# ================================================================================
# ✓ entry_determination_method
#     → 9 unique values, 0 nulls
#     → Values: ['X-RAY DIFFRACTION' 'SOLUTION NMR' 'ELECTRON MICROSCOPY'
#  'ELECTRON CRYSTALLOGRAPHY' 'NEUTRON DIFFRACTION' 'SOLID-STATE NMR'
#  'SOLUTION SCATTERING' 'FIBER DIFFRACTION' 'POWDER DIFFRACTION']
# ✓ entry_resolution
# ✗ entry_rfree
# ✗ entry_r
# ✗ entry_clashscore
# ✓ system_num_protein_chains
# ✓ system_num_ligand_chains
# ✓ ligand_is_covalent
#     → 2 unique values, 0 nulls
#     → Values: [False  True]
# ✓ ligand_is_cofactor
#     → 2 unique values, 0 nulls
#     → Values: [ True False]
# ✓ system_proper_num_interactions
# ✗ system_proper_pocket_num_residues
# ✓ system_proper_ligand_max_molecular_weight

# %% [markdown]
# ## Filter 1: Experimental Method (X-ray Crystallography)

# %%
# # Filter by experimental method - use PLINDER column: entry_determination_method
# print("Filter 1: X-ray Crystallography Only")
# print("-" * 80)

# # Initialize filtering stats
# filtering_stats = OrderedDict()
# filtering_stats['Initial'] = len(df)

# # Check and apply filter
# if 'entry_determination_method' in df.columns:
#     print(f"Available methods:")
#     for method, count in df['entry_determination_method'].value_counts().head(10).items():
#         print(f"  {method}: {count:,}")
    
#     before = len(df)
#     # Filter for X-ray diffraction (common variants: "X-RAY DIFFRACTION", "X-RAY")
#     df = df[df['entry_determination_method'].str.upper().str.contains('X-RAY', na=False)].copy()
#     after = len(df)
#     removed = before - after
#     print(f"\n✓ Kept {after:,} systems ({after/before*100:.1f}%)")
#     print(f"✗ Removed {removed:,} systems ({removed/before*100:.1f}%)")
#     filtering_stats['After X-ray filter'] = after
# else:
#     print("⚠ Warning: 'entry_determination_method' column not found. Skipping this filter.")
#     filtering_stats['After X-ray filter'] = len(df)

# %%
df['entry_determination_method'].unique()
# Out:
# array(['X-RAY DIFFRACTION', 'SOLUTION NMR', 'ELECTRON MICROSCOPY',
#        'ELECTRON CRYSTALLOGRAPHY', 'NEUTRON DIFFRACTION',
#        'SOLID-STATE NMR', 'SOLUTION SCATTERING', 'FIBER DIFFRACTION',
#        'POWDER DIFFRACTION'], dtype=object)

# %% [markdown]
# ## Filter 2: First Bioassembly Only

# %%
# Filter by bioassembly - use system_id format: pdb__bioassembly__receptor__ligand
print("\nFilter 2: First Bioassembly Only")
print("-" * 80)

before = len(df)

# PLINDER system_id format: <pdb>__<bioassembly>__<receptor_chains>__<ligand_chains>
# Extract bioassembly number (second field after splitting by __)
if 'system_id' in df.columns:
    # Extract bioassembly number from system_id
    bioassembly_nums = df['system_id'].str.split('__').str[1].astype(int)
    print(f"Bioassembly distribution: {bioassembly_nums.value_counts().sort_index().head()}")
    
    # Keep only bioassembly 1
    df = df[bioassembly_nums == 1].copy()
    after = len(df)
    removed = before - after
    print(f"\n✓ Kept {after:,} systems from bioassembly 1 ({after/before*100:.1f}%)")
    print(f"✗ Removed {removed:,} systems from other bioassemblies ({removed/before*100:.1f}%)")
    filtering_stats['After bioassembly filter'] = after
else:
    print("⚠ Warning: 'system_id' column not found. Skipping this filter.")
    filtering_stats['After bioassembly filter'] = len(df)
# Out:
# Filter 2: First Bioassembly Only
# --------------------------------------------------------------------------------
# Bioassembly distribution: system_id
# 1    755858
# 2    195311
# 3     41819
# 4     22633
# 5      7732
# Name: count, dtype: int64
# Bioassembly distribution: system_id
# 1    755858
# 2    195311
# 3     41819
# 4     22633
# 5      7732
# Name: count, dtype: int64
#
# ✓ Kept 755,858 systems from bioassembly 1 (72.2%)
# ✗ Removed 290,432 systems from other bioassemblies (27.8%)
#
# ✓ Kept 755,858 systems from bioassembly 1 (72.2%)
# ✗ Removed 290,432 systems from other bioassemblies (27.8%)

# %% [markdown]
# ## Filter 3: Chain Count Limits (≤5 ligand chains, ≤5 protein chains)

# %%
# Filter by chain counts - use PLINDER columns: system_num_ligand_chains, system_num_protein_chains
print("\nFilter 3: Chain Count Limits (≤5 each)")
print("-" * 80)

before = len(df)
removed_ligand = 0
removed_protein = 0

# Filter ligand chains
if 'system_num_ligand_chains' in df.columns:
    print(f"Ligand chain distribution:")
    for count, num in df['system_num_ligand_chains'].value_counts().sort_index().head(10).items():
        print(f"  {count} chains: {num:,} systems")
    temp = df[df['system_num_ligand_chains'] <= 5].copy()
    removed_ligand = len(df) - len(temp)
    df = temp
    print(f"  ✓ Kept systems with ≤5 ligand chains: {len(df):,}")
    print(f"  ✗ Removed {removed_ligand:,} systems")
else:
    print("⚠ Warning: 'system_num_ligand_chains' column not found")

# Filter protein chains
if 'system_num_protein_chains' in df.columns:
    print(f"\nProtein chain distribution:")
    for count, num in df['system_num_protein_chains'].value_counts().sort_index().head(10).items():
        print(f"  {count} chains: {num:,} systems")
    temp = df[df['system_num_protein_chains'] <= 5].copy()
    removed_protein = len(df) - len(temp)
    df = temp
    print(f"  ✓ Kept systems with ≤5 protein chains: {len(df):,}")
    print(f"  ✗ Removed {removed_protein:,} systems")
else:
    print("⚠ Warning: 'system_num_protein_chains' column not found")

after = len(df)
total_removed = before - after
print(f"\n{'='*80}")
print(f"Total removed by chain limits: {total_removed:,} ({total_removed/before*100:.1f}%)")
print(f"Remaining systems: {after:,}")
filtering_stats['After chain limits'] = after
# Out:
# Filter 3: Chain Count Limits (≤5 each)
# --------------------------------------------------------------------------------
# Ligand chain distribution:
#   1 chains: 809,509 systems
#   2 chains: 248,916 systems
#   3 chains: 107,613 systems
#   4 chains: 45,856 systems
#   5 chains: 17,065 systems
#   6 chains: 11,646 systems
#   7 chains: 3,731 systems
#   8 chains: 4,696 systems
#   9 chains: 3,717 systems
#   10 chains: 3,830 systems
#   ✓ Kept systems with ≤5 ligand chains: 1,228,959
#   ✗ Removed 128,947 systems
#
# Protein chain distribution:
#   1 chains: 845,528 systems
#   2 chains: 303,054 systems
#   3 chains: 60,458 systems
#   4 chains: 12,799 systems
#   5 chains: 4,019 systems
#   6 chains: 2,734 systems
#   7 chains: 91 systems
#   8 chains: 100 systems
#   9 chains: 12 systems
#   10 chains: 131 systems
#   ✓ Kept systems with ≤5 protein chains: 1,225,858
#   ✗ Removed 3,101 systems
#
# ================================================================================
# Total removed by chain limits: 132,048 (9.7%)
# Remaining systems: 1,225,858

# %% [markdown]
# ## Filter 4: Exclude Covalent Ligands

# %%
# Filter covalent ligands - use PLINDER column: ligand_is_covalent (array of bool)
print("\nFilter 4: Exclude Covalent Ligands")
print("-" * 80)

before = len(df)

if 'ligand_is_covalent' in df.columns:
    # ligand_is_covalent is an array of booleans (one per ligand in the system)
    # Exclude systems where ANY ligand is covalent
    # Check if any value in the array is True
    has_covalent = df['ligand_is_covalent'].apply(lambda x: any(x) if isinstance(x, (list, np.ndarray)) and len(x) > 0 else False)
    
    print(f"Systems with covalent ligands: {has_covalent.sum():,}")
    print(f"Systems without covalent ligands: {(~has_covalent).sum():,}")
    
    df = df[~has_covalent].copy()
    after = len(df)
    removed = before - after
    print(f"\n✓ Kept {after:,} non-covalent systems ({after/before*100:.1f}%)")
    print(f"✗ Removed {removed:,} systems with covalent ligands ({removed/before*100:.1f}%)")
    filtering_stats['After covalent filter'] = after
else:
    print("⚠ Warning: 'ligand_is_covalent' column not found. Skipping this filter.")
    filtering_stats['After covalent filter'] = len(df)
# Out:
# Filter 4: Exclude Covalent Ligands
# --------------------------------------------------------------------------------
# Systems with covalent ligands: 0
# Systems without covalent ligands: 696,639
# Systems with covalent ligands: 0
# Systems without covalent ligands: 696,639
#
# ✓ Kept 696,639 non-covalent systems (100.0%)
# ✗ Removed 0 systems with covalent ligands (0.0%)
#
# ✓ Kept 696,639 non-covalent systems (100.0%)
# ✗ Removed 0 systems with covalent ligands (0.0%)

# %% [markdown]
# ## Filter 5: Exclude Unwanted Ligand Types (Cofactors/Oligopeptides/Nucleotides/Saccharides)

# %%
# Filter unwanted ligand types - use PLINDER columns: ligand_is_cofactor, ligand_is_proper
print("\nFilter 5: Exclude Unwanted Ligand Types")
print("-" * 80)
print("Excluding: cofactors, ions, artifacts (keeping only 'proper' ligands)")

before = len(df)

# PLINDER provides ligand_is_proper which flags ligands that are:
# - NOT ions
# - NOT artifacts  
# - NOT unwanted ligand types
# Strategy: Keep systems that have at least one "proper" ligand

if 'ligand_is_proper' in df.columns:
    # Check the data type of ligand_is_proper
    if df['ligand_is_proper'].dtype == 'object':
        # It's an array/list of booleans (one per ligand)
        # Keep systems where at least one ligand is "proper"
        has_proper_ligand = df['ligand_is_proper'].apply(
            lambda x: any(x) if isinstance(x, (list, np.ndarray)) and len(x) > 0 else False
        )
    elif df['ligand_is_proper'].dtype == 'bool':
        # It's a simple boolean column
        has_proper_ligand = df['ligand_is_proper']
    else:
        print(f"⚠ Warning: Unexpected dtype for ligand_is_proper: {df['ligand_is_proper'].dtype}")
        has_proper_ligand = df['ligand_is_proper'].astype(bool)
    
    print(f"Systems with at least one proper ligand: {has_proper_ligand.sum():,}")
    print(f"Systems without proper ligands: {(~has_proper_ligand).sum():,}")
    
    if has_proper_ligand.sum() == 0:
        print("\n❌ WARNING: No systems have proper ligands! Check if:")
        print("   1. The ligand_is_proper column has the expected structure")
        print("   2. Previous filters may have removed all systems with proper ligands")
        print("   3. The annotation table is correct")
        print("\n⚠ Skipping this filter to avoid removing all data")
        filtering_stats['After ligand type filter'] = len(df)
    else:
        df = df[has_proper_ligand].copy()
        after = len(df)
        removed = before - after
        print(f"\n✓ Kept {after:,} systems with proper ligands ({after/before*100:.1f}%)")
        print(f"✗ Removed {removed:,} systems (only ions/artifacts/cofactors) ({removed/before*100:.1f}%)")
        filtering_stats['After ligand type filter'] = after
        
elif 'ligand_is_cofactor' in df.columns:
    # Alternative: filter out systems where ALL ligands are cofactors
    print("Using ligand_is_cofactor column (ligand_is_proper not found)")
    
    if df['ligand_is_cofactor'].dtype == 'object':
        # Array of booleans - check if ALL ligands are cofactors
        all_cofactors = df['ligand_is_cofactor'].apply(
            lambda x: all(x) if isinstance(x, (list, np.ndarray)) and len(x) > 0 else False
        )
    else:
        all_cofactors = df['ligand_is_cofactor']
    
    print(f"Systems where ALL ligands are cofactors: {all_cofactors.sum():,}")
    
    df = df[~all_cofactors].copy()
    after = len(df)
    removed = before - after
    print(f"\n✓ Kept {after:,} systems ({after/before*100:.1f}%)")
    print(f"✗ Removed {removed:,} systems with only cofactors ({removed/before*100:.1f}%)")
    filtering_stats['After ligand type filter'] = after
else:
    print("⚠ Warning: Neither 'ligand_is_proper' nor 'ligand_is_cofactor' column found.")
    print("   Skipping this filter - will keep all current systems.")
    filtering_stats['After ligand type filter'] = len(df)
# Out:
# Filter 5: Exclude Unwanted Ligand Types
# --------------------------------------------------------------------------------
# Excluding: cofactors, ions, artifacts (keeping only 'proper' ligands)
# Systems with at least one proper ligand: 533,706
# Systems without proper ligands: 692,152
#
# ✓ Kept 533,706 systems with proper ligands (43.5%)
# ✗ Removed 692,152 systems (only ions/artifacts/cofactors) (56.5%)

# %% [markdown]
# ## Filter 6: X-ray Validation Criteria
#
# Apply multiple X-ray quality filters:
# - Resolution ≤ 3.2 Å ✅
# - R-factor ≤ 0.4
# - Rfree ≤ 0.45
# - R - Rfree ≤ 0.05
# - Complete coordinates for heavy atoms
# - No alternative configurations
# - No clash outliers
# - No crystal contacts

# %%
# X-ray validation filters - use PLINDER entry_* columns
print("\nFilter 6: X-ray Validation Criteria")
print("-" * 80)

before = len(df)
xray_stats = {}

# 6.1 Resolution ≤ 3.2 Å
if 'entry_resolution' in df.columns:
    print(f"Resolution statistics:")
    print(f"  Range: [{df['entry_resolution'].min():.2f}, {df['entry_resolution'].max():.2f}] Å")
    print(f"  Mean: {df['entry_resolution'].mean():.2f} Å")
    print(f"  Median: {df['entry_resolution'].median():.2f} Å")
    temp_before = len(df)
    df = df[df['entry_resolution'] <= 3.2].copy()
    removed = temp_before - len(df)
    xray_stats['resolution'] = removed
    print(f"  ✓ Resolution ≤ 3.2 Å: kept {len(df):,}, removed {removed:,}")
else:
    print("  ⚠ 'entry_resolution' column not found")

# # 6.2 R-factor ≤ 0.4
# if 'entry_r' in df.columns:
#     print(f"\nR-factor statistics:")
#     print(f"  Range: [{df['entry_r'].min():.3f}, {df['entry_r'].max():.3f}]")
#     print(f"  Mean: {df['entry_r'].mean():.3f}")
#     temp_before = len(df)
#     df = df[df['entry_r'] <= 0.4].copy()
#     removed = temp_before - len(df)
#     xray_stats['r_factor'] = removed
#     print(f"  ✓ R-factor ≤ 0.4: kept {len(df):,}, removed {removed:,}")
# else:
#     print("\n  ⚠ 'entry_r' column not found")

# # 6.3 Rfree ≤ 0.45
# if 'entry_rfree' in df.columns:
#     print(f"\nRfree statistics:")
#     print(f"  Range: [{df['entry_rfree'].min():.3f}, {df['entry_rfree'].max():.3f}]")
#     print(f"  Mean: {df['entry_rfree'].mean():.3f}")
#     temp_before = len(df)
#     df = df[df['entry_rfree'] <= 0.45].copy()
#     removed = temp_before - len(df)
#     xray_stats['r_free'] = removed
#     print(f"  ✓ Rfree ≤ 0.45: kept {len(df):,}, removed {removed:,}")
# else:
#     print("\n  ⚠ 'entry_rfree' column not found")

# # 6.4 R - Rfree ≤ 0.05
# if 'entry_r' in df.columns and 'entry_rfree' in df.columns:
#     r_diff = df['entry_rfree'] - df['entry_r']
#     print(f"\nRfree - R statistics:")
#     print(f"  Range: [{r_diff.min():.3f}, {r_diff.max():.3f}]")
#     print(f"  Mean: {r_diff.mean():.3f}")
#     temp_before = len(df)
#     df = df[r_diff <= 0.05].copy()
#     removed = temp_before - len(df)
#     xray_stats['r_diff'] = removed
#     print(f"  ✓ Rfree - R ≤ 0.05: kept {len(df):,}, removed {removed:,}")

# # 6.5 Clashscore filter (optional but good quality indicator)
# if 'entry_clashscore' in df.columns:
#     print(f"\nClashscore statistics:")
#     print(f"  Range: [{df['entry_clashscore'].min():.2f}, {df['entry_clashscore'].max():.2f}]")
#     print(f"  Median: {df['entry_clashscore'].median():.2f}")
#     # Typical threshold: clashscore < 20 or 40 for good structures
#     # Let's use a generous threshold for now
#     temp_before = len(df)
#     df = df[df['entry_clashscore'] < 40].copy()
#     removed = temp_before - len(df)
#     xray_stats['clashscore'] = removed
#     print(f"  ✓ Clashscore < 40: kept {len(df):,}, removed {removed:,}")

# # Note: Columns for complete coords, alt conformations, crystal contacts
# # may be in ligand-specific columns (arrays) - will check those if needed
# # For now, we use the system_pass_validation_criteria which aggregates many checks

# if 'system_pass_validation_criteria' in df.columns:
#     print(f"\nUsing PLINDER's pre-computed validation criteria:")
#     print(f"  Systems passing validation: {df['system_pass_validation_criteria'].sum():,}")
#     print(f"  Systems failing validation: {(~df['system_pass_validation_criteria']).sum():,}")
#     temp_before = len(df)
#     df = df[df['system_pass_validation_criteria']].copy()
#     removed = temp_before - len(df)
#     xray_stats['plinder_validation'] = removed
#     print(f"  ✓ Pass PLINDER validation: kept {len(df):,}, removed {removed:,}")
# else:
#     print("\n  ⚠ 'system_pass_validation_criteria' column not found")

# after = len(df)
# total_removed = before - after
# print(f"\n{'='*80}")
# print(f"Total removed by X-ray validation: {total_removed:,} ({total_removed/before*100:.1f}%)")
# print(f"Breakdown by criterion: {xray_stats}")
# filtering_stats['After X-ray validation'] = after
# Out:
# Filter 6: X-ray Validation Criteria
# --------------------------------------------------------------------------------
# Resolution statistics:
#   Range: [0.64, 37.00] Å
#   Mean: 2.33 Å
#   Median: 2.20 Å
#   ✓ Resolution ≤ 3.2 Å: kept 366,658, removed 167,048

# %% [markdown]
# ## Filter 7: Interaction Statistics (3-50 PLIP interactions, 5-100 pocket residues)

# %%
# Filter by interaction statistics - use PLINDER system_proper_* columns
print("\nFilter 7: Interaction Statistics")
print("-" * 80)
print("Using system_proper_* columns (metrics for 'proper' ligands only)")

before = len(df)
interaction_stats = {}

# 7.1 PLIP interactions (3-50) for proper ligands
if 'system_proper_num_interactions' in df.columns:
    print(f"\nPLIP interactions (proper ligands only):")
    print(f"  Range: [{df['system_proper_num_interactions'].min()}, {df['system_proper_num_interactions'].max()}]")
    print(f"  Mean: {df['system_proper_num_interactions'].mean():.1f}")
    print(f"  Median: {df['system_proper_num_interactions'].median():.0f}")
    
    # Show distribution
    print(f"  Distribution (binned):")
    bins = [0, 3, 10, 20, 50, 100, df['system_proper_num_interactions'].max()]
    labels = ['<3', '3-10', '10-20', '20-50', '50-100', '>100']
    counts = pd.cut(df['system_proper_num_interactions'], bins=bins, labels=labels).value_counts().sort_index()
    for label, count in counts.items():
        print(f"    {label}: {count:,} systems")
    
    temp_before = len(df)
    df = df[(df['system_proper_num_interactions'] >= 3) & (df['system_proper_num_interactions'] <= 50)].copy()
    removed = temp_before - len(df)
    interaction_stats['plip'] = removed
    print(f"  ✓ 3-50 PLIP interactions: kept {len(df):,}, removed {removed:,}")
else:
    print("  ⚠ 'system_proper_num_interactions' column not found")

# 7.2 Pocket residues (5-100) for proper ligands
if 'system_proper_pocket_num_residues' in df.columns:
    print(f"\nPocket residues (proper ligands only):")
    print(f"  Range: [{df['system_proper_pocket_num_residues'].min()}, {df['system_proper_pocket_num_residues'].max()}]")
    print(f"  Mean: {df['system_proper_pocket_num_residues'].mean():.1f}")
    print(f"  Median: {df['system_proper_pocket_num_residues'].median():.0f}")
    
    # Show distribution
    print(f"  Distribution (binned):")
    bins = [0, 5, 20, 50, 100, 200, df['system_proper_pocket_num_residues'].max()]
    labels = ['<5', '5-20', '20-50', '50-100', '100-200', '>200']
    counts = pd.cut(df['system_proper_pocket_num_residues'], bins=bins, labels=labels).value_counts().sort_index()
    for label, count in counts.items():
        print(f"    {label}: {count:,} systems")
    
    temp_before = len(df)
    df = df[(df['system_proper_pocket_num_residues'] >= 5) & (df['system_proper_pocket_num_residues'] <= 100)].copy()
    removed = temp_before - len(df)
    interaction_stats['pocket_residues'] = removed
    print(f"  ✓ 5-100 pocket residues: kept {len(df):,}, removed {removed:,}")
else:
    print("  ⚠ 'system_proper_pocket_num_residues' column not found")

after = len(df)
total_removed = before - after
print(f"\n{'='*80}")
print(f"Total removed by interaction stats: {total_removed:,} ({total_removed/before*100:.1f}%)")
print(f"Breakdown: {interaction_stats}")
filtering_stats['After interaction stats'] = after
# Out:
# Filter 7: Interaction Statistics
# --------------------------------------------------------------------------------
# Using system_proper_* columns (metrics for 'proper' ligands only)
#
# PLIP interactions (proper ligands only):
#   Range: [0, 722]
#   Mean: 14.8
#   Median: 12
#   Distribution (binned):
#     <3: 42,973 systems
#     3-10: 105,978 systems
#     10-20: 118,821 systems
#     20-50: 88,026 systems
#     50-100: 3,675 systems
#     >100: 111 systems
#   ✓ 3-50 PLIP interactions: kept 327,144, removed 39,514
#   ⚠ 'system_proper_pocket_num_residues' column not found
#
# ================================================================================
# Total removed by interaction stats: 39,514 (10.8%)
# Breakdown: {'plip': 39514}

# %% [markdown]
# ## Filter 8: Ligand Molecular Weight (200-800 Da)

# %%
# Filter by molecular weight - use PLINDER column: system_proper_ligand_max_molecular_weight
print("\nFilter 8: Ligand Molecular Weight (200-800 Da)")
print("-" * 80)
print("Using system_proper_ligand_max_molecular_weight (max MW of proper ligands)")

before = len(df)

if 'system_proper_ligand_max_molecular_weight' in df.columns:
    print(f"\nMolecular weight statistics:")
    print(f"  Range: [{df['system_proper_ligand_max_molecular_weight'].min():.1f}, {df['system_proper_ligand_max_molecular_weight'].max():.1f}] Da")
    print(f"  Mean: {df['system_proper_ligand_max_molecular_weight'].mean():.1f} Da")
    print(f"  Median: {df['system_proper_ligand_max_molecular_weight'].median():.1f} Da")
    print(f"  Percentiles:")
    print(f"    25%: {df['system_proper_ligand_max_molecular_weight'].quantile(0.25):.1f} Da")
    print(f"    50%: {df['system_proper_ligand_max_molecular_weight'].quantile(0.50):.1f} Da")
    print(f"    75%: {df['system_proper_ligand_max_molecular_weight'].quantile(0.75):.1f} Da")
    
    # Show distribution
    print(f"  Distribution (binned):")
    bins = [0, 200, 300, 400, 500, 600, 800, 1000, df['system_proper_ligand_max_molecular_weight'].max()]
    labels = ['<200', '200-300', '300-400', '400-500', '500-600', '600-800', '800-1000', '>1000']
    counts = pd.cut(df['system_proper_ligand_max_molecular_weight'], bins=bins, labels=labels).value_counts().sort_index()
    for label, count in counts.items():
        print(f"    {label} Da: {count:,} systems")
    
    df = df[(df['system_proper_ligand_max_molecular_weight'] >= 350) & 
            (df['system_proper_ligand_max_molecular_weight'] <= 600)].copy()
    after = len(df)
    removed = before - after
    print(f"\n✓ Kept {after:,} systems with MW 200-800 Da ({after/before*100:.1f}%)")
    print(f"✗ Removed {removed:,} systems ({removed/before*100:.1f}%)")
    filtering_stats['After MW filter'] = after
else:
    print("⚠ Warning: 'system_proper_ligand_max_molecular_weight' column not found. Skipping this filter.")
    filtering_stats['After MW filter'] = len(df)
# Out:
# Filter 8: Ligand Molecular Weight (200-800 Da)
# --------------------------------------------------------------------------------
# Using system_proper_ligand_max_molecular_weight (max MW of proper ligands)
#
# Molecular weight statistics:
#   Range: [68.0, 3450.5] Da
#   Mean: 490.7 Da
#   Median: 427.0 Da
#   Percentiles:
#     25%: 290.0 Da
#     50%: 427.0 Da
#     75%: 616.2 Da
#   Distribution (binned):
#     <200 Da: 37,704 systems
#     200-300 Da: 47,515 systems
#     300-400 Da: 54,418 systems
#     400-500 Da: 54,689 systems
#     500-600 Da: 34,414 systems
#     600-800 Da: 72,619 systems
#     800-1000 Da: 11,696 systems
#     >1000 Da: 14,089 systems
#
# ✓ Kept 114,537 systems with MW 200-800 Da (35.0%)
# ✗ Removed 212,607 systems (65.0%)

# %% [markdown]
# ## Filtering Summary

# %%
# Display filtering summary
print("\n" + "="*80)
print("FILTERING SUMMARY")
print("="*80)

# Create summary DataFrame
summary_data = []
steps = list(filtering_stats.keys())
counts = list(filtering_stats.values())

for i in range(len(steps)):
    if i == 0:
        removed = 0
        pct_removed = 0
        pct_of_initial = 100
    else:
        removed = counts[i-1] - counts[i]
        pct_removed = (removed / counts[i-1] * 100) if counts[i-1] > 0 else 0
        pct_of_initial = (counts[i] / counts[0] * 100) if counts[0] > 0 else 0
    
    summary_data.append({
        'Step': steps[i],
        'Remaining': f"{counts[i]:,}",
        'Removed': f"{removed:,}",
        '% Removed': f"{pct_removed:.1f}%",
        '% of Initial': f"{pct_of_initial:.1f}%"
    })

summary_df = pd.DataFrame(summary_data)
print(summary_df.to_string(index=False))

print("\n" + "="*80)
print(f"Initial systems: {counts[0]:,}")
print(f"Final systems: {counts[-1]:,}")
print(f"Total removed: {counts[0] - counts[-1]:,} ({(counts[0] - counts[-1])/counts[0]*100:.1f}%)")
print(f"Retention rate: {counts[-1]/counts[0]*100:.1f}%")
print("="*80)
# Out:
# ================================================================================
# FILTERING SUMMARY
# ================================================================================
#                     Step Remaining Removed % Removed % of Initial
#                  Initial 1,357,906       0      0.0%       100.0%
#       After chain limits 1,225,858 132,048      9.7%        90.3%
# After ligand type filter   533,706 692,152     56.5%        39.3%
#  After interaction stats   327,144 206,562     38.7%        24.1%
#          After MW filter   114,537 212,607     65.0%         8.4%
#
# ================================================================================
# Initial systems: 1,357,906
# Final systems: 114,537
# Total removed: 1,243,369 (91.6%)
# Retention rate: 8.4%
# ================================================================================

# %% [markdown]
# ## Visualizations
#
# Create comprehensive visualizations of the filtering pipeline.

# %%
# Visualization 1: Waterfall chart
fig, ax = plt.subplots(figsize=(14, 8))

steps = list(filtering_stats.keys())
counts = list(filtering_stats.values())

# Create bar chart
bars = ax.bar(range(len(steps)), counts, color=['#3498db' if i == 0 else '#2ecc71' if i == len(steps)-1 else '#95a5a6' for i in range(len(steps))],
              edgecolor='black', linewidth=1.5, alpha=0.8)

# Add value labels
for i, (bar, count) in enumerate(zip(bars, counts)):
    height = bar.get_height()
    pct = (count / counts[0] * 100) if counts[0] > 0 else 0
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{count:,}\n({pct:.1f}%)',
            ha='center', va='bottom', fontsize=9, fontweight='bold')

# Formatting
ax.set_xticks(range(len(steps)))
ax.set_xticklabels([s.replace('After ', '') for s in steps], rotation=45, ha='right', fontsize=10)
ax.set_ylabel('Number of Systems', fontsize=12, fontweight='bold')
ax.set_xlabel('Filtering Step', fontsize=12, fontweight='bold')
ax.set_title(f'PLINDER Filtering Pipeline: {counts[0]:,} → {counts[-1]:,} Systems ({counts[-1]/counts[0]*100:.1f}% retained)', 
             fontsize=14, fontweight='bold', pad=20)
ax.grid(True, alpha=0.3, axis='y')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{int(x):,}'))

plt.tight_layout()
plt.show()

# %%
# Visualization 2: Systems removed at each step
fig, ax = plt.subplots(figsize=(14, 7))

removed_counts = []
removed_labels = []

for i in range(1, len(counts)):
    removed = counts[i-1] - counts[i]
    removed_counts.append(removed)
    removed_labels.append(steps[i].replace('After ', ''))

# Sort by removal count
sorted_data = sorted(zip(removed_counts, removed_labels), reverse=True)
removed_counts_sorted, removed_labels_sorted = zip(*sorted_data)

bars = ax.barh(range(len(removed_counts_sorted)), removed_counts_sorted, 
               color='#e74c3c', alpha=0.7, edgecolor='black', linewidth=1.5)

# Add value labels
for i, (bar, count) in enumerate(zip(bars, removed_counts_sorted)):
    width = bar.get_width()
    pct = (count / counts[0] * 100) if counts[0] > 0 else 0
    ax.text(width, bar.get_y() + bar.get_height()/2.,
            f'  {count:,} ({pct:.1f}%)',
            ha='left', va='center', fontsize=10, fontweight='bold')

ax.set_yticks(range(len(removed_labels_sorted)))
ax.set_yticklabels(removed_labels_sorted, fontsize=11)
ax.set_xlabel('Number of Systems Removed', fontsize=12, fontweight='bold')
ax.set_title('Systems Removed by Each Filter (Sorted)', fontsize=14, fontweight='bold', pad=20)
ax.grid(True, alpha=0.3, axis='x')
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{int(x):,}'))
ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# Visualization 3: Pie chart of retention
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Overall retention
retained = counts[-1]
removed_total = counts[0] - counts[-1]
sizes = [retained, removed_total]
labels = [f'Retained\n{retained:,}\n({retained/counts[0]*100:.1f}%)', 
          f'Removed\n{removed_total:,}\n({removed_total/counts[0]*100:.1f}%)']
colors = ['#2ecc71', '#e74c3c']
explode = (0.05, 0.05)

ax1.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='',
        startangle=90, textprops={'fontsize': 12, 'fontweight': 'bold'})
ax1.set_title('Overall Retention vs Removal', fontsize=14, fontweight='bold', pad=20)

# Breakdown of removed systems by filter
removed_by_filter = []
filter_names = []
for i in range(1, len(counts)):
    removed = counts[i-1] - counts[i]
    if removed > 0:
        removed_by_filter.append(removed)
        filter_names.append(steps[i].replace('After ', '').replace(' filter', ''))

if removed_by_filter:
    ax2.pie(removed_by_filter, labels=filter_names, autopct='%1.1f%%',
            startangle=90, textprops={'fontsize': 9})
    ax2.set_title('Breakdown of Removed Systems by Filter', fontsize=14, fontweight='bold', pad=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Export Filtered Data

# %%
# Save filtered data
output_dir = Path('data')
output_dir.mkdir(parents=True, exist_ok=True)

# Save filtered annotation table
filtered_output = output_dir / 'annotation_table_filtered.parquet'
df.to_parquet(filtered_output, index=False)
print(f"✓ Saved filtered annotation table to: {filtered_output}")
print(f"  Shape: {df.shape}")
print(f"  Size: {filtered_output.stat().st_size / 1024**2:.2f} MB")

# Save filtering statistics
stats_output = output_dir / 'filtering_statistics.csv'
summary_df.to_csv(stats_output, index=False)
print(f"✓ Saved filtering statistics to: {stats_output}")

# Save text summary
summary_output = output_dir / 'filtering_summary.txt'
with open(summary_output, 'w') as f:
    f.write("="*80 + "\n")
    f.write("PLINDER SYSTEM FILTERING SUMMARY\n")
    f.write("="*80 + "\n\n")
    f.write(f"Initial systems: {counts[0]:,}\n")
    f.write(f"Final systems: {counts[-1]:,}\n")
    f.write(f"Total removed: {counts[0] - counts[-1]:,} ({(counts[0] - counts[-1])/counts[0]*100:.1f}%)\n")
    f.write(f"Retention rate: {counts[-1]/counts[0]*100:.1f}%\n\n")
    f.write("Filtering steps:\n")
    f.write("-"*80 + "\n")
    f.write(summary_df.to_string(index=False))
    f.write("\n" + "="*80 + "\n")

print(f"✓ Saved summary report to: {summary_output}")

print(f"\n{'='*80}")
print("EXPORT COMPLETE")
print(f"{'='*80}")
# Out:
# ✓ Saved filtered annotation table to: data/annotation_table_filtered.parquet
#   Shape: (114537, 743)
#   Size: 159.72 MB
# ✓ Saved filtering statistics to: data/filtering_statistics.csv
# ✓ Saved summary report to: data/filtering_summary.txt
#
# ================================================================================
# EXPORT COMPLETE
# ================================================================================

# %% [markdown]
# ## Final Dataset Statistics

# %%
# Display final dataset statistics
print("\n" + "="*80)
print("FINAL FILTERED DATASET STATISTICS")
print("="*80)

print(f"\nTotal systems: {len(df):,}")

# Count unique values in key columns
if 'system_id' in df.columns:
    print(f"Unique system IDs: {df['system_id'].nunique():,}")

# Check for PDB-related columns
pdb_cols = [col for col in df.columns if 'pdb' in col.lower()]
if pdb_cols:
    print(f"PDB-related columns: {pdb_cols}")
    if len(pdb_cols) > 0:
        print(f"Unique PDB entries: {df[pdb_cols[0]].nunique():,}")

# Resolution statistics (if available)
if 'resolution' in df.columns:
    print(f"\nResolution statistics:")
    print(f"  Min: {df['resolution'].min():.2f} Å")
    print(f"  Max: {df['resolution'].max():.2f} Å")
    print(f"  Mean: {df['resolution'].mean():.2f} Å")
    print(f"  Median: {df['resolution'].median():.2f} Å")

# Molecular weight statistics (if available)
mw_cols = [col for col in df.columns if 'molecular_weight' in col.lower() or 'mw' in col.lower()]
if mw_cols:
    col = mw_cols[0]
    print(f"\nMolecular weight statistics ({col}):")
    print(f"  Min: {df[col].min():.1f} Da")
    print(f"  Max: {df[col].max():.1f} Da")
    print(f"  Mean: {df[col].mean():.1f} Da")
    print(f"  Median: {df[col].median():.1f} Da")

# Interaction statistics (if available)
if 'num_plip_interactions' in df.columns or 'plip_interaction_count' in df.columns:
    col = 'num_plip_interactions' if 'num_plip_interactions' in df.columns else 'plip_interaction_count'
    print(f"\nPLIP interaction statistics:")
    print(f"  Min: {df[col].min()}")
    print(f"  Max: {df[col].max()}")
    print(f"  Mean: {df[col].mean():.1f}")
    print(f"  Median: {df[col].median():.1f}")

if 'num_pocket_residues' in df.columns or 'pocket_residue_count' in df.columns:
    col = 'num_pocket_residues' if 'num_pocket_residues' in df.columns else 'pocket_residue_count'
    print(f"\nPocket residue statistics:")
    print(f"  Min: {df[col].min()}")
    print(f"  Max: {df[col].max()}")
    print(f"  Mean: {df[col].mean():.1f}")
    print(f"  Median: {df[col].median():.1f}")

print("\n" + "="*80)
print(f"Preview of filtered data:")
print("="*80)
display(df.head(10))

print("\n✅ FILTERING PIPELINE COMPLETE!")
print(f"Filtered dataset ready for downstream analysis with {len(df):,} high-quality systems.")
# Out:
# ================================================================================
# FINAL FILTERED DATASET STATISTICS
# ================================================================================
#
# Total systems: 60,983
# Unique system IDs: 54,051
# PDB-related columns: ['entry_pdb_id', 'entry_validation_pdbx_resolution', 'entry_validation_pdbx_reflns_resolution']
# Unique PDB entries: 27,866
#
# Molecular weight statistics (system_ligand_max_molecular_weight):
#   Min: 200.0 Da
#   Max: 1463.1 Da
#   Mean: 465.0 Da
#   Median: 438.2 Da
#
# ================================================================================
# Preview of filtered data:
# ================================================================================
#   Min: 200.0 Da
#   Max: 1463.1 Da
#   Mean: 465.0 Da
#   Median: 438.2 Da
#
# ================================================================================
# Preview of filtered data:
# ================================================================================
#     entry_pdb_id entry_release_date entry_oligomeric_state entry_determination_method                     entry_keywords entry_pH  entry_resolution  entry_validation_resolution  entry_validation_rfree  entry_validation_r  entry_validation_clashscore  entry_validation_percent_rama_outliers  entry_validation_percent_rota_outliers  entry_validation_data_completeness  entry_validation_percent_RSRZ_outliers  entry_validation_atom_count  entry_validation_molprobity  entry_validation_mean_b_factor  entry_validation_median_b_factor  entry_validation_pdbx_resolution  entry_validation_pdbx_reflns_resolution  entry_validation_meanI_over_sigI_obs  entry_validation_r_minus_rfree entry_pass_validation_criteria system_biounit_id system_protein_chains_asym_id system_id_no_biounit system_ligand_chains  system_num_pocket_residues  system_proper_num_pocket_residues  system_num_interactions  system_proper_num_interactions  system_num_unique_interactions  system_proper_num_unique_interactions  \
# 14          4grc         2012-08-24                dimeric          X-RAY DIFFRACTION                     OXIDOREDUCTASE                   2.000000                         2.00                  0.1975              0.1594                         1.63                                    0.00                                    2.19                               99.98                                    0.56                       3200.0                     1.170623                       24.229779                         21.940001                          2.000000                                    2.000                                  4.28                          0.0381                           True                 1                         [1.A]         4grc__A__C_D           [1.C, 1.D]                          43                                 35                       37                              33                              32                                     29
# 16          4grc         2012-08-24                dimeric          X-RAY DIFFRACTION                     OXIDOREDUCTASE                   2.000000                         2.00                  0.1975              0.1594                         1.63                                    0.00                                    2.19                               99.98                                    0.56                       3200.0                     1.170623                       24.229779                         21.940001                          2.000000                                    2.000                                  4.28                          0.0381                           True                 1                         [2.A]         4grc__A__C_D           [2.C, 2.D]                          43                                 35                       34                              32                              30                                     28
# 42          8grd         2022-09-01                dimeric          X-RAY DIFFRACTION                     OXIDOREDUCTASE      5.1          2.699000                         2.70                  0.2418              0.1940                         4.15                                    0.00                                    2.02                               99.36                                    1.84                       5094.0                     1.430235                       50.148192                         47.245001                          2.699000                                    2.699                                   NaN                          0.0478                           True                 1                    [1.A, 1.B]         8grd__A_B__D                [1.D]                          25                                 25                        8                               8                               7                                      7
# 64          2grj         2006-04-24              monomeric          X-RAY DIFFRACTION                        TRANSFERASE      5.2          2.600000                         2.60                  0.2400              0.1900                         4.10                                    0.14                                    1.41                               98.53                                    2.79                      11485.0                     1.307441                       38.033328                         36.470001                          2.600000                                    2.600                                  1.84                          0.0500                           True                 1                         [1.A]           2grj__A__I                [1.I]                          20                                 20                       16                              16                              16                                     16
# 101         7grs         2023-11-14                dimeric          X-RAY DIFFRACTION                      VIRAL PROTEIN      6.5          1.470000                         1.47                  0.2240              0.1863                         3.53                                    0.00                                    0.76                               70.03                                    3.43                       5574.0                     1.143568                       23.666202                         19.700001                          1.470000                                    1.470                                   NaN                          0.0377                           True                 1                         [1.B]           7grs__B__Q                [1.Q]                          18                                 18                        4                               4                               4                                      4
# 105         8grw         2022-09-02                dimeric          X-RAY DIFFRACTION                         CELL CYCLE      8.5          2.400054                         2.40                  0.2377              0.1935                         6.40                                    0.00                                    0.00                               99.22                                    3.74                       4346.0                     1.352630                       46.214273                         40.704830                          2.400054                                    2.400                                   NaN                          0.0442                           True                 1                    [1.A, 1.B]       8grw__A_B__C_D           [1.C, 1.D]                          49                                 31                       28                              22                              26                                     20
# 106         8grw         2022-09-02                dimeric          X-RAY DIFFRACTION                         CELL CYCLE      8.5          2.400054                         2.40                  0.2377              0.1935                         6.40                                    0.00                                    0.00                               99.22                                    3.74                       4346.0                     1.352630                       46.214273                         40.704830                          2.400054                                    2.400                                   NaN                          0.0442                           True                 1                    [1.A, 1.B]         8grw__A_B__E                [1.E]                          39                                 39                       20                              20                              19                                     19
# 134         5grn         2016-08-11              monomeric          X-RAY DIFFRACTION  TRANSFERASE/TRANSFERASE INHIBITOR                   1.770000                         1.77                  0.1793              0.1570                         5.83                                    0.00                                    0.81                               99.83                                    1.40                       2716.0                     1.318484                       22.781880                         19.580000                          1.770000                                    1.750                                   NaN                          0.0223                           True                 1                         [1.A]           5grn__A__B                [1.B]                          33                                 33                       20                              20                              18                                     18
# 151         3gr7         2009-03-25             tetrameric          X-RAY DIFFRACTION                     OXIDOREDUCTASE      6.3          2.300000                         2.30                  0.2230              0.2000                         4.40                                    0.00                                    4.55                               98.18                                    4.56                       5790.0                     1.718398                       29.760021                         27.775001                          2.300000                                    2.300                                  4.80                          0.0230                           True                 1                    [1.A, 2.A]       3gr7__A_A__C_E           [1.C, 1.E]                          46                                 33                       24                              22                              23                                     21
# 153         3gr7         2009-03-25             tetrameric          X-RAY DIFFRACTION                     OXIDOREDUCTASE      6.3          2.300000                         2.30                  0.2230              0.2000                         4.40                                    0.00                                    4.55                               98.18                                    4.56                       5790.0                     1.718398                       29.760021                         27.775001                          2.300000                                    2.300                                  4.80                          0.0230                           True                 1                    [1.B, 2.B]       3gr7__B_B__F_H           [1.F, 1.H]                          46                                 33                       23                              21                              21                                     19
#
#      system_num_covalent_ligands  system_proper_num_covalent_ligands                  system_id system_type  system_has_kinase_inhibitor  system_has_binding_affinity  system_num_protein_chains  system_proper_num_protein_chains  system_num_ligand_chains  system_proper_num_ligand_chains  system_num_crystal_contacted_residues  system_num_atoms_with_crystal_contacts  system_num_heavy_atoms  system_num_resolved_heavy_atoms  system_ligand_max_qed  system_ligand_max_molecular_weight  ...  protein_seqsim_weighted_max__100__community  protein_seqsim_weighted_max__70__weak__component  protein_seqsim_weighted_max__95__weak__component protein_seqsim_weighted_max__100__weak__component protein_seqsim_weighted_max__70__strong__component protein_seqsim_weighted_max__95__strong__component protein_seqsim_weighted_max__100__strong__component protein_seqsim_weighted_sum__50__community protein_seqsim_weighted_sum__70__community  protein_seqsim_weighted_sum__95__community  \
# 14                             0                                   0      4grc__1__1.A__1.C_1.D        holo                        False                        False                          1                                 1                         2                                1                                      0                                       0                      45                               45               0.416598                          616.177293  ...                                           c1                                                c0                                                c0                                                c0                                                 c0                                                 c0                                                 c0                                          c0                                         c1                                          c1
# 16                             0                                   0      4grc__1__2.A__2.C_2.D        holo                        False                        False                          1                                 1                         2                                1                                      0                                       0                      45                               45               0.416598                          616.177293  ...                                           c1                                                c0                                                c0                                                c0                                                 c0                                                 c0                                                 c0                                          c0                                         c1                                          c1
# 42                             0                                   0      8grd__1__1.A_1.B__1.D        holo                         True                        False                          2                                 2                         1                                1                                      0                                       0                      27                               27               0.280791                          427.029415  ...                                        c2760                                             c1727                                             c2300                                             c2574                                              c1777                                              c2306                                              c2597                                        c209                                      c1989                                       c2478
# 64                             0                                   0          2grj__1__1.A__1.I        holo                         True                        False                          1                                 1                         1                                1                                      0                                       0                      27                               27               0.280791                          427.029415  ...                                        c3415                                             c2180                                             c2941                                             c3219                                              c2237                                              c2956                                              c3248                                         c27                                      c2419                                       c3315
# 101                            0                                   0          7grs__1__1.B__1.Q        holo                        False                        False                          1                                 1                         1                                1                                      0                                       0                      14                               14               0.807784                          203.076870  ...                                          c13                                                c0                                                c0                                                c0                                                 c0                                                 c0                                                 c0                                         c31                                        c19                                         c14
# 105                            0                                   0  8grw__1__1.A_1.B__1.C_1.D        holo                        False                        False                          2                                 2                         2                                1                                      0                                       0                      36                               36               0.320362                          443.024330  ...                                        c8368                                                c0                                             c6503                                             c8154                                                 c0                                              c6534                                              c8208                                        c172                                       c501                                       c7697
# 106                            0                                   0      8grw__1__1.A_1.B__1.E        holo                        False                        False                          2                                 2                         1                                1                                      0                                       0                      28                               28               0.228822                          443.024330  ...                                        c8368                                                c0                                             c6503                                             c8154                                                 c0                                              c6534                                              c8208                                        c172                                       c501                                       c7697
# 134                            0                                   0          5grn__1__1.A__1.B        holo                         True                        False                          1                                 1                         1                                1                                      0                                       0                      44                               44               0.210199                          586.280472  ...                                           c7                                                c0                                                c0                                                c0                                                 c0                                                 c0                                                 c0                                          c7                                         c3                                          c5
# 151                            0                                   0  3gr7__1__1.A_2.A__1.C_1.E        holo                        False                        False                          2                                 2                         2                                1                                      0                                       0                      36                               36               0.275922                          456.104615  ...                                        c4864                                              c298                                             c3877                                             c4658                                               c321                                              c3890                                              c4693                                         c11                                       c447                                       c4031
# 153                            0                                   0  3gr7__1__1.B_2.B__1.F_1.H        holo                        False                        False                          2                                 2                         2                                1                                      0                                       0                      36                               36               0.275922                          456.104615  ...                                        c4864                                              c298                                             c3877                                             c4658                                               c321                                              c3890                                              c4693                                         c11                                       c447                                       c4031
#
#      protein_seqsim_weighted_sum__100__community  protein_seqsim_weighted_sum__50__weak__component  protein_seqsim_weighted_sum__70__weak__component  protein_seqsim_weighted_sum__95__weak__component  protein_seqsim_weighted_sum__100__weak__component  protein_seqsim_weighted_sum__50__strong__component  protein_seqsim_weighted_sum__70__strong__component  protein_seqsim_weighted_sum__95__strong__component  protein_seqsim_weighted_sum__100__strong__component  tanimoto_similarity_max__30__community  tanimoto_similarity_max__50__community  tanimoto_similarity_max__70__community  tanimoto_similarity_max__95__community  tanimoto_similarity_max__100__community  tanimoto_similarity_max__30__weak__component  tanimoto_similarity_max__50__weak__component  tanimoto_similarity_max__70__weak__component  tanimoto_similarity_max__95__weak__component  tanimoto_similarity_max__100__weak__component  tanimoto_similarity_max__30__strong__component  tanimoto_similarity_max__50__strong__component  \
# 14                                            c2                                                c0                                                c0                                                c0                                                 c0                                                 c0                                                  c0                                                  c0                                                  c0                                      None                                    None                                    None                                    None                                     None                                          None                                          None                                          None                                          None                                           None                                            None                                            None
# 16                                            c2                                                c0                                                c0                                                c0                                                 c0                                                 c0                                                  c0                                                  c0                                                  c0                                      None                                    None                                    None                                    None                                     None                                          None                                          None                                          None                                          None                                           None                                            None                                            None
# 42                                         c2770                                                c0                                             c1787                                             c2305                                              c2569                                                 c0                                               c2323                                               c4251                                               c4638                                        c2                                      c3                                      c5                                    c100                                    c1722                                            c0                                            c0                                            c1                                           c99                                          c1722                                              c0                                              c0
# 64                                         c3470                                                c0                                             c2210                                             c3134                                              c3253                                                 c0                                               c2720                                               c3673                                               c3701                                        c2                                      c3                                      c5                                    c100                                    c1722                                            c0                                            c0                                            c1                                           c99                                          c1722                                              c0                                              c0
# 101                                          c12                                                c0                                                c0                                                c0                                                 c0                                                 c0                                                  c0                                                  c0                                                  c0                                        c0                                      c0                                   c3052                                  c12338                                   c12299                                            c0                                            c0                                         c3034                                        c12336                                         c12299                                              c0                                              c0
# 105                                        c8123                                                c0                                                c0                                             c7489                                              c7881                                                 c0                                               c3457                                               c9362                                               c9677                                        c2                                      c3                                      c5                                    c264                                   c16046                                            c0                                            c0                                            c1                                          c262                                         c16046                                              c0                                              c0
# 106                                        c8123                                                c0                                                c0                                             c7489                                              c7881                                                 c0                                               c3457                                               c9362                                               c9677                                        c2                                      c3                                      c5                                    c264                                   c16046                                            c0                                            c0                                            c1                                          c262                                         c16046                                              c0                                              c0
# 134                                           c5                                                c0                                                c0                                                c0                                                 c0                                                 c0                                                  c0                                                  c0                                                  c0                                        c0                                      c8                                   c3141                                  c13283                                   c13267                                            c0                                            c0                                         c3123                                        c13281                                         c13267                                              c0                                              c0
# 151                                        c4793                                                c0                                              c313                                             c3846                                              c4562                                                 c0                                               c1202                                               c4584                                               c5328                                        c0                                     c82                                    c475                                  c30026                                   c30469                                            c0                                            c0                                          c459                                        c30024                                         c30469                                              c0                                              c0
# 153                                        c4793                                                c0                                              c313                                             c3846                                              c4562                                                 c0                                               c1202                                               c4584                                               c5328                                        c0                                     c82                                    c475                                  c30026                                   c30469                                            c0                                            c0                                          c459                                        c30024                                         c30469                                              c0                                              c0
#
#      tanimoto_similarity_max__70__strong__component  tanimoto_similarity_max__95__strong__component  tanimoto_similarity_max__100__strong__component              uniqueness  biounit_num_ligands  biounit_num_unique_ccd_codes  biounit_num_proper_ligands  system_ligand_has_lipinski  system_ligand_has_cofactor  system_ligand_has_fragment  system_ligand_has_oligo  system_ligand_has_artifact  system_ligand_has_other  system_ligand_has_covalent  system_ligand_has_invalid  system_ligand_has_ion  system_protein_chains_total_length  system_unique_ccd_codes  system_proper_unique_ccd_codes
# 14                                             None                                            None                                             None    4grc__A__C_D_c118167                    6                             3                           2                        True                        True                        True                    False                        True                    False                       False                      False                  False                                 440                  HEM-PEO                             HEM
# 16                                             None                                            None                                             None    4grc__A__C_D_c151132                    6                             3                           2                        True                        True                        True                    False                        True                    False                       False                      False                  False                                 440                  HEM-PEO                             HEM
# 42                                               c1                                             c99                                            c1722    8grd__A_B__D_c280667                    2                             2                           1                       False                        True                       False                    False                       False                    False                       False                      False                  False                                 691                      ADP                             ADP
# 64                                               c1                                             c99                                            c1722      2grj__A__I_c287601                    2                             2                           2                       False                        True                       False                    False                       False                    False                       False                      False                  False                                 192                      ADP                             ADP
# 101                                           c3034                                          c12336                                           c12299       7grs__B__Q_c83762                    3                             2                           2                        True                       False                       False                    False                       False                    False                       False                      False                  False                                 306                      NT9                             NT9
# 105                                              c1                                            c262                                           c16046  8grw__A_B__C_D_c266023                    3                             2                           2                        True                        True                       False                    False                        True                    False                       False                      False                  False                                 644                  GDP-TRS                             GDP
# 106                                              c1                                            c262                                           c16046    8grw__A_B__E_c265361                    3                             2                           2                       False                        True                       False                    False                       False                    False                       False                      False                  False                                 644                      GDP                             GDP
# 134                                           c3123                                          c13281                                           c13267      5grn__A__B_c100281                    1                             1                           1                       False                       False                       False                    False                       False                    False                       False                      False                  False                                 356                      748                             748
# 151                                            c459                                          c30024                                           c30469  3gr7__A_A__C_E_c289455                    8                             2                           4                       False                        True                       False                    False                        True                     True                       False                      False                  False                                 680                  FMN-SO4                             FMN
# 153                                            c459                                          c30024                                           c30469  3gr7__B_B__F_H_c123311                    8                             2                           4                       False                        True                       False                    False                        True                     True                       False                      False                  False                                 680                  FMN-SO4                             FMN
#
# [10 rows x 743 columns]
# ✅ FILTERING PIPELINE COMPLETE!
# Filtered dataset ready for downstream analysis with 60,983 high-quality systems.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
